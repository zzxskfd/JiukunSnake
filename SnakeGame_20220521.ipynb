# %%
import numpy as np
import gc
import os
import random
from scipy.stats import rankdata
from copy import copy, deepcopy
from time import sleep, time
from colorama import Fore, Style

# from AI import AI0, AI_greedy_1, AI0_rand, AI_greedy_0, AI_new_tree_search
from AI import AI_20220520, AI_20220520_early, AI_reversing
from utils import create_folder, save_json, DIRECTIONS, load_json, key2dir, add_c, search_path_keys

# %%
class Player:
    def __init__(self, num, name=None) -> None:
        if (name is None):
            name = f'Player_{num}'
        self.Name = name
        self.Num = num
        self.Act = 'w'
        # self.LastAct = 'w'
        self.IsDead = False
        self.NowDead = False
        self.Speed = 1
        self.Kill = 0
        self.KillList = []
        self.KilledList = []
        self.SaveLength = 0
        self.Prop = {
            'speed': 0,
            'strong': 0,
            'double': 0,
        }
        # self.del_act = None
        self.Score_len = None
        self.Score_kill = None
        self.Score_time = None
        self.Score = None
        # Addtional params
        self.move_len = 0
        self.total_len = 0
        self.remove_head = False

    def load_game_info(self, loadpath):
        game_info = load_json(loadpath)
        self.__dict__.update(game_info['gameinfo']['Player'][self.Num])

# %%
class Map:
    def __init__(self, num_players, max_time=150) -> None:
        self.Length = 55    # X
        self.Width = 40     # Y
        # TODO Snake initial positions for 4/5 players? Use random when training?
        self.SnakePosition = [[] for _ in range(num_players)]
        if (num_players == 6):
            x0 = int(self.Length / 4)
            y0 = int(self.Width / 3)
            init_pos = [
                [x0, y0], [2 * x0, y0], [3 * x0, y0],
                [x0, y0 * 2], [2 * x0, y0 * 2], [3 * x0, y0 * 2],
            ]
            init_pos = [tuple(p) for p in init_pos]
            random.shuffle(init_pos)
            for i, pos in enumerate(init_pos):
                self.SnakePosition[i] = [pos, add_c(pos, random.choice(DIRECTIONS))]

        self.SugarPosition = set()
        self.WallPosition = set()
        self.PropPosition = [set(), set(), set()]   # speed, strong, double
        self.Time = 0
        self.Score = [None for _ in range(num_players)]
        # Additional parameters
        self.max_time = max_time
        self.wall_gen_ind = 0
        self.all_grids = set([(x, y) for x in range(self.Length) for y in range(self.Width)])
    
    def gen_walls_and_props(self):
        # Generate walls
        if (self.Time % 5 == 0 and (self.Time >= 100 or self.Length * self.Width - len(self.WallPosition) - len(self.SugarPosition) > 400)):
            i = self.wall_gen_ind
            for j in range(self.Width):
                self.WallPosition.add((i, j))
                self.WallPosition.add((self.Length - 1 - i, j))
            for j in range(self.Length):
                self.WallPosition.add((j, i))
                self.WallPosition.add((j, self.Width - 1 - i))
            self.WallPosition = self.vacant_subset(self.WallPosition, wall=False)
            self.wall_gen_ind += 1
        # Generate sugars and props
        if (self.Time == 0):
            # Initial num: 200 sugar, 50/50/50 props
            sugar_num = 200
            prop_num = 50
            poss = self.__gen_uniform_poss__(sugar_num + 3 * prop_num, range_=self.vacant_subset())
            for i in range(3):
                self.PropPosition[i] = set(poss[i*prop_num:(i+1)*prop_num])
            self.SugarPosition = set(poss[3*prop_num:])
        else:
            n_sugar = 200 + self.Time
            r_sugar = 100 + min(self.Time * 10, 200)
            num = max(0, n_sugar - len(self.SugarPosition))
            poss = self.__gen_gauss_poss__(num=num, max_toss_num=r_sugar)
            self.SugarPosition = self.SugarPosition.union(poss)

            # speed, strong, double
            n_props = [60 + int(self.Time * 0.2), 40, 50]
            r_props = [10 + min(self.Time * 10, 100)] * 3
            for i in range(3):
                # speed > strong > double
                num = max(0, n_props[i] - len(self.PropPosition[i]))
                poss = self.__gen_gauss_poss__(num=num, max_toss_num=r_props[i])
                self.PropPosition[i] = self.PropPosition[i].union(poss)

        # Old version
        # if (self.Time == 1):
        #     # When time == 1, generate extra 10 speed props
        #     poss = self.__gen_gauss_poss__(10, range=self.vacant_subset())
        #     self.PropPosition[0] = self.PropPosition[0].union(poss)
        # # Sugar
        # sugar_num = random.choice([1, 1, 1, 1, 2, 2, 3, 3, 4])
        # poss = self.__gen_gauss_poss__(sugar_num)
        # poss = self.vacant_subset(poss)
        # self.SugarPosition = self.SugarPosition.union(poss)
        # # Props
        # for i in range(3):
        #     # speed > strong > double
        #     poss = self.__gen_gauss_poss__(1)
        #     poss = self.vacant_subset(poss)
        #     self.PropPosition[i] = self.PropPosition[i].union(poss)

    def __gen_gauss_poss__(self, num:int, range_:set=None, max_toss_num=2000)->list:
        mu_x = (self.Length - 1) / 2
        mu_y = (self.Width - 1) / 2
        sigma_x = 10
        sigma_y = 10
        # if not enough spaces, return all remaining spaces
        if (range_ is not None and num >= len(range_)):
            poss = list(range_)
            random.shuffle(poss)
            return poss
        poss = set()    # note: use set to avoid equal samples
        for _ in range(max_toss_num):
            if (len(poss) >= num):
                break
            pos = (int(np.round(random.gauss(mu_x, sigma_x))),
                    int(np.round(random.gauss(mu_y, sigma_y))))
            while (not self.is_valid_pos(pos) or (range_ is not None and not pos in range_)):
                pos = (int(np.round(random.gauss(mu_x, sigma_x))),
                    int(np.round(random.gauss(mu_y, sigma_y))))
            poss.add(pos)
        poss = list(poss)
        random.shuffle(poss)
        return poss

    def __gen_uniform_poss__(self, num, range_:set=None, max_toss_num=2000):
        # if not enough spaces, return all remaining spaces
        if (range_ is not None and num >= len(range_)):
            poss = list(range_)
            random.shuffle(poss)
            return poss
        poss = set()    # note: use set to avoid equal samples
        for _ in range(max_toss_num):
            if (len(poss) >= num):
                break
            # note: assuming the outside is wall, do not use in an empty map
            pos = (random.randrange(1, self.Length-1), random.randrange(1, self.Width-1))
            while (range_ is not None and not pos in range_):
                pos = (random.randrange(1, self.Length-1), random.randrange(1, self.Width-1))
            poss.add(pos)
        poss = list(poss)
        random.shuffle(poss)
        return poss

    def time_over(self):
        return self.Time >= self.max_time
    
    def is_valid_pos(self, pos):
        return (0 <= pos[0] <= self.Length - 1) and (0 <= pos[1] <= self.Width - 1)

    def is_valid_poss(self, poss):
        return np.all([self.is_valid_pos(pos) for pos in poss])
    
    def vacant_subset(self, poss=None, wall=True, sugar=True, prop=True, snake=True) -> set:
        if (poss is None):
            poss = self.all_grids
        res = poss.copy()
        if (type(res) != set):
            res = set(res)
        if (snake):
            for snake_poss in self.SnakePosition:
                res -= set(snake_poss)
        if (sugar):
            res -= self.SugarPosition
        if (wall):
            res -= self.WallPosition
        if (prop):
            for i in range(3):
                res -= self.PropPosition[i]
        return res
    
    def load_game_info(self, loadpath, as_set=True):
        game_info = load_json(loadpath)
        self.__dict__.update(game_info['gameinfo']['Map'])
        if (as_set):
            # convert data to set of tuples
            self.SugarPosition = set([tuple(pos) for pos in self.SugarPosition])
            self.WallPosition = set([tuple(pos) for pos in self.WallPosition])
            for i in range(3):
                self.PropPosition[i] = set([tuple(pos) for pos in self.PropPosition[i]])

    def print(self, wall=True, sugar=True, prop=True, snake=True, legend=True, player_names=None):
        wall_char = 'ww'
        sugar_char = '* '
        prop_chars = ['sp', 'st', 'do']   # speed, strong, double
        # prop_chars = [Fore.LIGHTBLUE_EX + c + Style.RESET_ALL for c in prop_chars]
        player_colors = [
            Fore.RED,
            Fore.GREEN,
            Fore.BLUE,
            Fore.YELLOW,
            Fore.CYAN,
            Fore.MAGENTA,
        ]
        snake_head_chars = [player_colors[i]+'@@'+Style.RESET_ALL for i in range(len(self.SnakePosition))]
        snake_body_chars = [player_colors[i]+'OO'+Style.RESET_ALL for i in range(len(self.SnakePosition))]

        board = [['  ' for i in range(self.Width)] for j in range(self.Length)]
        if (wall):
            for pos in self.WallPosition:
                # # Ignore the outer walls
                # if (not self.is_valid_pos(pos)):
                #     continue
                # if (board[pos[0]][pos[1]] != '  '):
                #     print(f'Warning: conflict on {pos[0]}{pos[1]}')
                board[pos[0]][pos[1]] = wall_char
        if (sugar):
            for pos in self.SugarPosition:
                board[pos[0]][pos[1]] = sugar_char
        if (prop):
            for i in range(3):
                for pos in self.PropPosition[i]:
                    board[pos[0]][pos[1]] = prop_chars[i]
        if (snake):
            for i, positions in enumerate(self.SnakePosition):
                if (len(positions) == 0):
                    continue
                pos = positions[0]
                board[pos[0]][pos[1]] = snake_head_chars[i]
                for pos in positions[1:]:
                    board[pos[0]][pos[1]] = snake_body_chars[i]
        board = np.transpose(board)

        if (legend):
            if (player_names is None):
                player_names = [f'Player_{i}' for i in range(len(self.SnakePosition))]
            print('  '.join([player_names[i] + ':' + player_colors[i]+'O'+Style.RESET_ALL for i in range(len(self.SnakePosition))]))
        print('\n'.join(reversed([''.join(row) for row in board])))

# %%
class SnakeGame:
    def __init__(self, player_num:int=None, AIs:list=None) -> None:
        self.reset(player_num=player_num, AIs=AIs)

    def reset(self, player_num:int=None, AIs:list=None):
        assert AIs is not None or player_num is not None
        if (AIs is not None and player_num is not None):
            assert player_num == len(AIs)
        if (player_num is None):
            self.player_num = len(AIs)
        else:
            self.player_num = player_num
        self.AIs = AIs
        self.players = [Player(i) for i in range(self.player_num)]
        self.map = Map(self.player_num)
        self.map.gen_walls_and_props()
        self.__calc_scores__()
        # [20220521]
        self.game_info_history = []

    def get_game_info(self, to_list=True):
        game_info = dict()
        game_info['Player'] = []
        for p in self.players:
            tmp = copy(p.__dict__)
            # tmp = deepcopy(p.__dict__)
            tmp.pop('move_len')
            tmp.pop('total_len')
            tmp.pop('remove_head')
            game_info['Player'].append(tmp)
        game_info['Map'] = copy(self.map.__dict__)
        game_info['Map'].pop('all_grids')
        if (to_list):
            game_info['Map']['WallPosition'] = list(self.map.WallPosition)
            game_info['Map']['SugarPosition'] = list(self.map.SugarPosition)
            game_info['Map']['PropPosition'] = []
            for i in range(3):
                game_info['Map']['PropPosition'].append(list(self.map.PropPosition[i]))

        res = dict()
        res['gameinfo'] = game_info
        res['tableinfo'] = None
        if (to_list):
            save_json(res, 'game_info_tmp.json')
            res = load_json('game_info_tmp.json')
        return res

    def load_game_info(self, game_info_path):
        game_info = load_json(game_info_path)
        self.reset(player_num=len(game_info['gameinfo']['Player']))
        self.map.load_game_info(game_info_path)
        for i in range(self.player_num):
            self.players[i].load_game_info(game_info_path)

    def print(self, cls=True):
        if (cls):
            os.system('cls')
        print(f'Round {self.map.Time}')
        print('Speed:', [player.Speed for player in self.players])
        print('Prop speed:', [player.Prop['speed'] for player in self.players])
        print('Prop strong:', [player.Prop['strong'] for player in self.players])
        print('Prop double:', [player.Prop['double'] for player in self.players])
        self.map.print(player_names=[self.players[i].Name for i in range(self.player_num)])

    def run_till_end(self, time_sleep=0.0, savedir=None, print=True):
        # Run a whole game
        if (savedir is not None):
            create_folder(savedir)
        def print_and_save():
            if (print):
                self.print()
            if (savedir is not None):
                save_json(
                    self.get_game_info(to_list=True),
                    os.path.join(savedir, 'game_info_round_%3d.json' % (self.map.Time))
                )
    
        print_and_save()
        sleep(time_sleep)
        while (self.move_one_round()):
            print_and_save()
            sleep(time_sleep)
        print_and_save()

    def move_one_round(self, AIs=None, acts=None) -> bool:
        # Return true if game is not ended
        if (acts is None):
            if (AIs is None):
                AIs = self.AIs
            game_info = self.get_game_info(to_list=False)
            self.game_info_history.append(game_info)
            # start_time = time()
            acts = self.__ask_for_acts__()
            # global time_elapsed
            # time_elapsed += (time() - start_time)
        self.__move_players__(acts)
        self.__collide__()
        self.__get_props__()
        self.__update_time__()
        self.__calc_scores__()
        self.__confirm_new_snakes__()
        self.map.gen_walls_and_props()

        # for i, AI in enumerate(AIs):
        #     if (AI.__name__ == 'AI_reversing'):
        #         self.players[i].Prop['strong'] = 1000

        if (self.__check_all_dead__()):
            return False
        if (self.map.time_over()):
            self.__kill_all__()
            return False
        return True
    
    def __ask_for_acts__(self):
        acts = []
        for i, AI in enumerate(self.AIs):
            acts.append(AI(i, self.game_info_history))
            # acts.append(AI(i, game_info))
        # with Pool(processes=8) as pool:
        #     acts = pool.starmap(get_act, list(range(self.player_num)))
        return acts
    
    def __move_players__(self, acts):
        # if act is None, use last act
        for i, act in enumerate(acts):
            if (act is None):
                act = self.players[i].Act
        for i in range(self.player_num):
            # Ignore previously dead snakes
            if (self.players[i].IsDead):
                continue
            self.players[i].move_len = 0
            self.players[i].total_len = len(self.map.SnakePosition[i])
            # Can move up to 'speed' times
            max_step = self.players[i].Speed
            act = acts[i]
            # if (act is None):
            #     print(self.get_game_info(to_list=True))
            act = act[:max_step]
            for key in act:
                dir = key2dir(key)
                assert dir is not None
                self.map.SnakePosition[i].insert(0, add_c(self.map.SnakePosition[i][0], dir))
                self.players[i].move_len += 1
            # Growth of snake
            use_save_len = min(self.players[i].SaveLength, self.players[i].move_len)
            self.players[i].SaveLength -= use_save_len
            for _ in range(self.players[i].move_len - use_save_len):
                self.map.SnakePosition[i].pop()
        # Set last_Act
        for i in range(self.player_num):
            self.players[i].Act = acts[i]
    
    def __collide__(self):
        # # Initialize now_dead
        # for i in range(self.player_num):
        #     self.players[i].now_dead = self.players[i].is_dead
        head_poss = []
        body_poss = []
        is_strong = []
        for i in range(self.player_num):
            self.players[i].KillList = []
            positions = self.map.SnakePosition[i]
            move_len = self.players[i].move_len
            total_len = self.players[i].total_len
            # still ok if move_len > total_len
            head_poss.append(set(positions[:move_len]))
            body_poss.append(set(positions[move_len:total_len]))
            is_strong.append(self.players[i].Prop['strong'] > 0)

        for i in range(self.player_num):
            # Ignore previously dead snakes
            if (self.players[i].IsDead):
                continue
            # Collide with walls
            if (not self.map.is_valid_poss(head_poss[i]) or not head_poss[i].isdisjoint(self.map.WallPosition)):
                self.players[i].NowDead = True
            # Collide with self
            if (not head_poss[i].isdisjoint(body_poss[i])):
                if (is_strong[i]):
                    self.players[i].remove_head = True
                else:
                    self.players[i].NowDead = True
            # Collide with others
            for j in range(i+1, self.player_num):
                collide_h2h = not head_poss[i].isdisjoint(head_poss[j])
                collide_h2b = not head_poss[i].isdisjoint(body_poss[j])
                collide_b2h = not body_poss[i].isdisjoint(head_poss[j])
                if (collide_h2h):
                    # [20220520] Rearranged collision logic
                    if (is_strong[i] and not is_strong[j]):
                        self.__on_kill__(i, j, True)
                    if (not is_strong[i] and is_strong[j]):
                        self.__on_kill__(j, i, True)
                    if (is_strong[i] and is_strong[j]):
                        self.players[i].remove_head = True
                        self.players[j].remove_head = True
                    # If both weak
                    if (not is_strong[i] and not is_strong[j]):
                        if (self.players[i].total_len > self.players[j].total_len):
                            self.__on_kill__(i, j, True)
                        elif (self.players[i].total_len < self.players[j].total_len):
                            self.__on_kill__(j, i, True)
                        else:
                            self.players[i].NowDead = True
                            self.players[j].NowDead = True
                else:
                    if (collide_h2b):
                        if (is_strong[i]):
                            self.players[i].remove_head = True
                        else:
                            self.__on_kill__(j, i, False)
                    if (collide_b2h):
                        if (is_strong[j]):
                            self.players[j].remove_head = True
                        else:
                            self.__on_kill__(i, j, False)

        # Realize remove head
        for i in range(self.player_num):
            if (self.players[i].remove_head):
                self.__remove_head__(i)

    def __on_kill__(self, killer: int, killed: int, active_kill: bool):
        self.players[killed].NowDead = True
        self.players[killed].KilledList.append(killer)
        self.players[killer].KillList.append(killed)
        if (active_kill):
            self.players[killer].Kill += 2
        else:
            self.players[killer].Kill += 1

    def __remove_head__(self, player_ind):
        player = self.players[player_ind]
        move_len = player.move_len
        self.map.SnakePosition[player_ind] = self.map.SnakePosition[player_ind][move_len:]
        player.total_len -= move_len
        player.total_len = max(player.total_len, 0)
        if (player.total_len < 1):
            player.NowDead = True
        # player.head_len = 0
        player.remove_head = False
    
    def __update_time__(self):
        self.map.Time += 1
        for player in self.players:
            player.Prop['speed'] = max(0, player.Prop['speed'] - 1)
            if (player.Prop['speed'] == 0):
                player.Speed = 1
            player.Prop['strong'] = max(0, player.Prop['strong'] - 1)
            player.Prop['double'] = max(0, player.Prop['double'] - 1)

    def __get_props__(self):
        for i in range(self.player_num):
            if (self.players[i].NowDead):
                continue
            valid_poss_set = set(self.map.SnakePosition[i][:self.players[i].total_len])
            if (self.players[i].Prop['double'] > 0):
                increment = 2
            else:
                increment = 1
            for pos in valid_poss_set & self.map.SugarPosition:
                self.map.SugarPosition.remove(pos)
                self.players[i].SaveLength += increment
            for pos in valid_poss_set & self.map.PropPosition[0]:
                self.map.PropPosition[0].remove(pos)
                self.players[i].Speed += 1
                self.players[i].Prop['speed'] += 5
            for pos in valid_poss_set & self.map.PropPosition[1]:
                self.map.PropPosition[1].remove(pos)
                self.players[i].Prop['strong'] += 5
            for pos in valid_poss_set & self.map.PropPosition[2]:
                self.map.PropPosition[2].remove(pos)
                self.players[i].Prop['double'] += 5

    def __confirm_new_snakes__(self):
        # Execute death and growth
        for i in range(self.player_num):
            if (self.players[i].IsDead):
                continue
            # Death of snakes
            if (self.players[i].NowDead):
                self.__on_die__(i)
                self.players[i].IsDead = self.players[i].NowDead
                continue

    def __on_die__(self, i):
        if (len(self.map.SnakePosition[i]) == 0):
            return
        valid_poss_set = self.map.SnakePosition[i][:self.players[i].total_len]
        valid_poss_set = set([pos for pos in valid_poss_set if self.map.is_valid_pos(pos)])
        self.map.SnakePosition[i].clear()
        for pos in self.map.vacant_subset(valid_poss_set):
            self.map.SugarPosition.add(pos)

    def __calc_scores__(self):
        for i in range(self.player_num):
            if (not self.players[i].IsDead):
                self.players[i].Score_kill = self.players[i].Kill
                self.players[i].Score_time = self.map.Time + 1
                self.players[i].Score_len = len(self.map.SnakePosition[i])
        
        scores = [0 for _ in range(self.player_num)]
        scores += 1.5 * rankdata([self.players[i].Score_kill for i in range(self.player_num)])
        scores += rankdata([self.players[i].Score_time for i in range(self.player_num)])
        scores += rankdata([self.players[i].Score_len for i in range(self.player_num)])
        scores /= 3.5

        self.map.Score = list(scores)
        for i in range(self.player_num):
            self.players[i].Score = scores[i]

    def __check_all_dead__(self):
        return np.all([player.IsDead for player in self.players])

    def __kill_all__(self):
        for i in range(self.player_num):
            if (not self.players[i].IsDead):
                self.players[i].IsDead = True
                self.__on_die__(i)

# %%
if __name__ ==  '__main__':
    pass
    # # Print map from gameinfo received
    # m = Map(6)
    # m.load_game_info(r'D:\zzx\Desktop\tmp\GameInfo_9096_10.json')
    # m.print()

    # # Print walls and props
    # m = Map(6)
    # filelist = os.listdir('game_info_sample/')
    # for file in filelist:
    #     m.load_game_info(os.path.join('game_info_sample', file))
    #     os.system('cls')
    #     print(f'Round: {m.Time}')
    #     m.print(wall=True, sugar=False, prop=True, snake=False)
    #     sleep(1.0)

    # # Inspect generation of props and sugars
    # # input_dir = 'game_info_sample/'
    # # input_dir = 'game_info_sample_20220402/'
    # # input_dir = r'D:\zzx\Desktop\tmp\game_info_sample_20220404_1'
    # input_dir = 'game_info_test/'
    # m = Map(6)
    # filelist = sorted(os.listdir(input_dir))
    # pre_props = [set(), set(), set()]
    # pre_sugars = set()
    # diffs = []
    # for file in filelist:
    #     m.load_game_info(os.path.join(input_dir, file))
    #     props = m.PropPosition
    #     sugars = m.SugarPosition
    #     # if (pre_props is not None):
    #     diff = [0, 0, 0, 0]
    #     for i in range(3):
    #         diff[i] = len(props[i] - pre_props[i])
    #     diff[3] = len(sugars - pre_sugars)
    #     diffs.append(diff)
    #     print(f'Round {m.Time}, diff = {str(diff)}, diff_sum = {str(np.sum(diffs, axis=0))}')
    #     pre_props = props
    #     pre_sugars = sugars
    # diff_sum = np.sum(diffs[1:], axis=0)
    # diff_sum[3] -= np.sum(np.sort(np.array(diffs)[1:, 3])[-6:])
    # print(f'diff_sum = {str(diff_sum)}')
    
    # # Print whole game info
    # # input_dir = r'D:\zzx\Desktop\tmp\game_info_9328'
    # input_dir = r'D:\zzx\Programming\vsCode\JiukunSnake\game_info_test'
    # game = SnakeGame(player_num=6)
    # filelist = sorted(os.listdir(input_dir))
    # # print(filelist)
    # for i, file in enumerate(filelist):
    #     game.load_game_info(os.path.join(input_dir, file))
    #     game.print()
    #     sleep(0.5)

# %%
# if __name__ ==  '__main__':
#     # Inspect specific round
#     # game_info_path = r'D:\zzx\Desktop\tmp\game_info_9328\GameInfo_9328_040.json'
#     game_info_path = r'D:\zzx\Programming\vsCode\JiukunSnake\game_info_test\game_info_round_ 40.json'
#     game = SnakeGame(player_num=6)
#     game.load_game_info(game_info_path)
#     game.print()
#     # print(AI_greedy_1(0, load_json(game_info_path), debug=True))
#     # print(AI_wyg(0, load_json(game_info_path), debug=True))
#     # print(search_path_keys((20, 10), (32, 34), game.map.WallPosition))

#     # # Test AI time usage
#     # game_info = load_json(r'D:\zzx\Programming\vsCode\JiukunSnake\game_info_test\game_info_round_  0.json')
#     # time_start = time()
#     # AI_greedy_0(0, game_info, debug=False)
#     # print(time() - time_start)

# %%
if __name__ ==  '__main__':
    random.seed(6000)
    scores = []
    scores_kill = []
    scores_len = []
    scores_time = []
    for i in range(400):
        # random.seed(1000 * (i+1))
        print('Game', i)
        time_elapsed = 0
        time_start = time()
        # game = SnakeGame(AIs=[AI_greedy_0 for _ in range(1)] + [AI0_rand for _ in range(5)])
        # game = SnakeGame(AIs=[AI0_rand for _ in range(6)])
        # game = SnakeGame(AIs=[AI_20220520 for _ in range(6)])
        game = SnakeGame(AIs=[AI_20220520 for _ in range(3)] + [AI_20220520_early for _ in range(3)])
        # game.run_till_end(savedir='game_info_test', print=True, time_sleep=0.5)
        game.run_till_end(print=False)
        time_total = time() - time_start
        print('Total time:', time_total)
        print('Part time:', time_elapsed)
        print(time_elapsed / time_total)
        print(game.map.Time)
        print([game.players[i].Score for i in range(6)])
        print([game.players[i].Score_kill for i in range(6)])
        print([game.players[i].Score_len for i in range(6)])
        print([game.players[i].Score_time for i in range(6)])
        print(np.mean([game.players[i].Score for i in range(1)]))
        scores.append([game.players[i].Score for i in range(6)])
        scores_kill.append([game.players[i].Score_kill for i in range(6)])
        scores_len.append([game.players[i].Score_len for i in range(6)])
        scores_time.append([game.players[i].Score_time for i in range(6)])
    print(np.mean(scores, axis=0))
    print('Average Score_kill =', np.mean(scores_kill, axis=0))
    print('Average Score_len =', np.mean(scores_len, axis=0))
    print('Average Score_time =', np.mean(scores_time, axis=0))
    print(np.mean(np.mean(scores, axis=0)[:3]))
# Out:
# Game 0
# Round 21, Num_ = 1, PredictedPathPositions = {(18, 22), (21, 21), (18, 21), (19, 21), (20, 21)}
# Total time: 1.8619372844696045
# Part time: 0
# 0.0
# 80
# [2.0, 3.2142857142857144, 4.5, 1.8571428571428572, 3.4285714285714284, 6.0]
# [0, 2, 2, 0, 0, 6]
# [27, 21, 30, 9, 53, 60]
# [22, 24, 72, 24, 32, 81]
# 2.0
# Game 1
# Round 7, Num_ = 0, PredictedPathPositions = {(34, 15), (34, 16)}
# Round 23, Num_ = 0, PredictedPathPositions = {(31, 16), (30, 17), (29, 18), (30, 18), (30, 16)}
# Round 23, Num_ = 2, PredictedPathPositions = {(30, 14), (30, 17), (30, 13), (30, 15), (30, 16)}
# Round 41, Num_ = 2, PredictedPathPositions = {(37, 15), (38, 15), (35, 15), (35, 16), (36, 15)}
# Round 47, Num_ = 2, PredictedPathPositions = {(33, 23), (34, 22), (33, 25), (34, 23), (33, 24)}
# Round 61, Num_ = 0, PredictedPathPositions = {(36, 24), (36, 25), (36, 22), (36, 23), (36, 21)}
# Round 63, Num_ = 0, PredictedPathPositions = {(41, 24), (40, 23), (41, 23), (39, 24), (40, 24)}
# Round 63, Num_ = 2, PredictedPathPositions = {(39, 23), (40, 22), (40, 23), (39, 22), (39, 24)}
# Round 64, Num_ = 0, PredictedPathPositions = {(39, 28), (39, 27), (39, 24), (37, 25), (38, 25), (39, 26), (38, 24), (39, 25)}
# Round 68, Num_ = 0, PredictedPathPositions = {(38, 24), (39, 24), (40, 24)}
# Round 70, Num_ = 0, PredictedPathPositions = {(36, 24), (35, 22), (37, 24), (36, 22), (36, 23)}
# Round 70, Num_ = 2, PredictedPathPositions = {(34, 22), (35, 22), (36, 22), (36, 23), (33, 22)}
# Round 77, Num_ = 0, PredictedPathPositions = {(33, 20), (33, 21), (34, 20), (34, 21), (33, 22)}
# Total time: 2.9944865703582764
# Part time: 0
# 0.0
# 92
# [3.7142857142857144, 4.285714285714286, 4.285714285714286, 5.714285714285714, 1.5, 1.5]
# [2, 2, 2, 4, 0, 0]
# [18, 73, 19, 58, 0, 3]
# [80, 76, 88, 93, 71, 13]
# 3.7142857142857144
# Game 2
# Round 18, Num_ = 2, PredictedPathPositions = {(17, 17), (17, 18), (17, 19)}
# Round 32, Num_ = 1, PredictedPathPositions = {(33, 12), (32, 12), (34, 12), (31, 12), (34, 13)}
# Round 52, Num_ = 0, PredictedPathPositions = {(33, 23), (32, 21), (29, 23), (30, 23), (31, 23), (32, 23), (33, 22), (29, 25), (28, 25), (33, 21), (31, 22), (27, 25), (32, 22), (29, 24)}
# Round 62, Num_ = 0, PredictedPathPositions = {(40, 26), (39, 26)}
# Round 66, Num_ = 2, PredictedPathPositions = {(20, 16), (20, 14), (20, 17), (20, 13), (20, 15)}
# Round 67, Num_ = 1, PredictedPathPositions = {(23, 23), (20, 23), (23, 24), (21, 23), (22, 23)}
# Round 69, Num_ = 2, PredictedPathPositions = {(11, 23), (9, 23), (12, 23), (13, 23), (10, 23)}
# Round 70, Num_ = 0, PredictedPathPositions = {(24, 14), (25, 14), (26, 14), (27, 14), (23, 14)}
# Round 70, Num_ = 1, PredictedPathPositions = {(23, 15), (23, 16), (23, 13), (23, 14), (24, 13)}
# Round 71, Num_ = 1, PredictedPathPositions = {(25, 16), (26, 16), (24, 15), (25, 15), (26, 15)}
# Round 75, Num_ = 1, PredictedPathPositions = {(19, 17), (20, 17), (19, 15), (21, 17), (19, 16)}
# Total time: 3.931339740753174
# Part time: 0
# 0.0
# 132
# [5.428571428571429, 3.142857142857143, 2.2142857142857144, 3.2142857142857144, 4.642857142857143, 2.357142857142857]
# [8, 4, 0, 2, 2, 0]
# [28, 0, 20, 5, 41, 32]
# [133, 91, 91, 92, 98, 53]
# 5.428571428571429
# Game 3
# Round 24, Num_ = 1, PredictedPathPositions = {(21, 15), (22, 15), (23, 15), (19, 15), (20, 15)}
# Round 49, Num_ = 0, PredictedPathPositions = {(28, 20), (31, 20), (29, 20), (21, 19), (30, 20), (22, 20), (22, 14), (23, 19), (22, 17), (22, 18), (21, 20), (22, 15), (22, 21), (23, 20), (26, 20), (24, 20), (27, 20), (21, 21), (31, 19), (22, 16), (22, 19), (25, 20)}
# Total time: 2.6404917240142822
# Part time: 0
# 0.0
# 99
# [4.0, 4.142857142857143, 2.2857142857142856, 1.4285714285714286, 5.714285714285714, 3.4285714285714284]
# [2, 4, 0, 0, 6, 0]
# [31, 17, 23, 6, 36, 42]
# [73, 90, 22, 17, 100, 50]
# 4.0
# Game 4
# Total time: 2.49210262298584
# Part time: 0
# 0.0
# 85
# [1.2142857142857142, 1.7857142857142858, 3.0, 4.785714285714286, 4.214285714285714, 6.0]
# [0, 0, 2, 4, 4, 6]
# [7, 13, 14, 54, 27, 64]
# [20, 27, 48, 75, 69, 86]
# 1.2142857142857142
# Game 5
# Round 43, Num_ = 2, PredictedPathPositions = {(32, 15), (32, 16), (32, 14), (32, 17), (32, 13)}
# Round 52, Num_ = 1, PredictedPathPositions = {(29, 25), (26, 24), (28, 25), (27, 24), (28, 24)}
# Round 83, Num_ = 1, PredictedPathPositions = {(26, 21), (25, 23), (27, 21), (25, 22), (25, 21)}
# Total time: 3.8489580154418945
# Part time: 0
# 0.0
# 141
# [3.0714285714285716, 3.2142857142857144, 4.428571428571429, 1.9285714285714286, 4.857142857142857, 3.5]
# [0, 0, 2, 0, 6, 0]
# [63, 42, 26, 0, 35, 47]
# [37, 93, 142, 79, 124, 93]
# 3.0714285714285716
# Game 6
# Total time: 1.8039100170135498
# Part time: 0
# 0.0
# 92
# [3.5714285714285716, 2.5, 4.214285714285714, 3.357142857142857, 1.6428571428571428, 5.714285714285714]
# [2, 0, 0, 0, 0, 8]
# [16, 8, 74, 42, 3, 71]
# [13, 18, 65, 48, 9, 93]
# 3.5714285714285716
# Game 7
# Round 5, Num_ = 2, PredictedPathPositions = {(41, 24)}
# Total time: 1.6148226261138916
# Part time: 0
# 0.0
# 103
# [1.7142857142857142, 1.8571428571428572, 4.214285714285714, 2.4285714285714284, 4.785714285714286, 6.0]
# [0, 0, 2, 0, 2, 4]
# [1, 5, 13, 5, 41, 42]
# [9, 7, 17, 10, 94, 104]
# 1.7142857142857142
# Game 8
# Round 69, Num_ = 2, PredictedPathPositions = {(28, 20), (28, 21)}
# Round 79, Num_ = 1, PredictedPathPositions = {(18, 17), (21, 19), (22, 20), (25, 21), (24, 22), (18, 18), (19, 18), (18, 15), (20, 18), (22, 21), (25, 22), (24, 20), (18, 16), (21, 18), (23, 21), (22, 19), (24, 21), (25, 20), (18, 14)}
# Total time: 2.765079975128174
# Part time: 0
# 0.0
# 113
# [2.0, 5.071428571428571, 3.857142857142857, 2.857142857142857, 5.785714285714286, 1.4285714285714286]
# [0, 4, 2, 0, 4, 0]
# [16, 39, 39, 23, 65, 13]
# [20, 113, 80, 103, 114, 17]
# 2.0
# Game 9
# Round 13, Num_ = 2, PredictedPathPositions = {(24, 30), (24, 32), (24, 28), (24, 31), (24, 29)}
# Round 16, Num_ = 0, PredictedPathPositions = {(28, 17), (29, 17), (26, 17), (29, 16), (27, 17)}
# Round 17, Num_ = 0, PredictedPathPositions = {(26, 21), (27, 21), (28, 21), (29, 21), (30, 21)}
# Round 17, Num_ = 2, PredictedPathPositions = {(30, 19), (29, 22), (30, 20), (30, 21), (29, 21)}
# Round 19, Num_ = 2, PredictedPathPositions = {(27, 21), (28, 21), (29, 21), (30, 21), (31, 21)}
# Total time: 1.046877384185791
# Part time: 0
# 0.0
# 39
# [2.7857142857142856, 2.7857142857142856, 5.428571428571429, 2.5, 1.9285714285714286, 5.571428571428571]
# [0, 0, 6, 0, 0, 2]
# [14, 18, 79, 20, 8, 108]
# [22, 19, 38, 15, 17, 40]
# 2.7857142857142856
# Game 10
# Round 21, Num_ = 1, PredictedPathPositions = {(36, 19), (36, 20), (36, 17), (36, 18), (36, 21)}
# Total time: 2.4275479316711426
# Part time: 0
# 0.0
# 86
# [1.7142857142857142, 3.357142857142857, 5.357142857142857, 2.0, 5.428571428571429, 3.142857142857143]
# [0, 2, 2, 0, 6, 0]
# [13, 17, 67, 19, 59, 39]
# [27, 49, 87, 14, 83, 57]
# 1.7142857142857142
# Game 11
# Round 13, Num_ = 2, PredictedPathPositions = {(23, 17), (24, 17), (25, 17), (23, 16), (26, 17)}
# Round 27, Num_ = 1, PredictedPathPositions = {(18, 22), (19, 22), (18, 20), (18, 21), (18, 19)}
# Total time: 2.4769227504730225
# Part time: 0
# 0.0
# 123
# [4.428571428571429, 3.357142857142857, 3.2142857142857144, 6.0, 2.357142857142857, 1.6428571428571428]
# [2, 0, 0, 4, 0, 0]
# [32, 36, 37, 42, 28, 22]
# [118, 86, 19, 124, 19, 14]
# 4.428571428571429
# Game 12
# Round 24, Num_ = 1, PredictedPathPositions = {(30, 30), (27, 29), (27, 30), (28, 30), (29, 30)}
# Round 29, Num_ = 1, PredictedPathPositions = {(41, 20), (40, 20), (43, 20), (39, 20), (42, 20)}
# Round 36, Num_ = 1, PredictedPathPositions = {(43, 21), (43, 24), (43, 25), (43, 22), (43, 23)}
# Round 53, Num_ = 2, PredictedPathPositions = {(32, 21), (33, 20), (31, 20), (32, 20), (31, 19), (33, 21), (32, 19), (34, 21), (31, 21)}
# Round 73, Num_ = 0, PredictedPathPositions = {(36, 11), (36, 14), (36, 12), (36, 13), (36, 15)}
# Total time: 2.404895782470703
# Part time: 0
# 0.0
# 84
# [3.642857142857143, 3.0714285714285716, 6.0, 1.9285714285714286, 1.9285714285714286, 4.428571428571429]
# [0, 0, 8, 0, 0, 4]
# [31, 29, 50, 4, 0, 22]
# [82, 54, 85, 11, 12, 84]
# 3.642857142857143
# Game 13
# Total time: 1.7977397441864014
# Part time: 0
# 0.0
# 63
# [3.642857142857143, 3.0714285714285716, 4.642857142857143, 5.785714285714286, 2.2142857142857144, 1.6428571428571428]
# [0, 0, 6, 6, 0, 0]
# [46, 33, 31, 60, 13, 7]
# [44, 25, 53, 64, 22, 19]
# 3.642857142857143
# Game 14
# Round 24, Num_ = 1, PredictedPathPositions = {(22, 20), (23, 20)}
# Total time: 2.6620066165924072
# Part time: 0
# 0.0
# 150
# [3.142857142857143, 3.857142857142857, 2.142857142857143, 3.5714285714285716, 2.7142857142857144, 5.571428571428571]
# [0, 0, 0, 0, 0, 4]
# [2, 113, 10, 26, 13, 35]
# [151, 51, 18, 114, 26, 151]
# 3.142857142857143
# Game 15
# Total time: 1.721034288406372
# Part time: 0
# 0.0
# 55
# [5.785714285714286, 2.5, 2.5, 3.9285714285714284, 2.357142857142857, 3.9285714285714284]
# [2, 0, 0, 2, 0, 0]
# [132, 25, 16, 0, 0, 76]
# [56, 19, 25, 37, 28, 53]
# 5.785714285714286
# Game 16
# Round 9, Num_ = 0, PredictedPathPositions = {(42, 25)}
# Round 16, Num_ = 0, PredictedPathPositions = {(35, 25)}
# Round 46, Num_ = 0, PredictedPathPositions = {(40, 25), (40, 22), (41, 25), (40, 23), (40, 24)}
# Total time: 2.6792824268341064
# Part time: 0
# 0.0
# 115
# [4.714285714285714, 2.0, 1.4285714285714286, 3.4285714285714284, 5.0, 4.428571428571429]
# [4, 0, 0, 0, 4, 4]
# [37, 7, 5, 52, 25, 17]
# [84, 19, 9, 60, 116, 94]
# 4.714285714285714
# Game 17
# Round 24, Num_ = 0, PredictedPathPositions = {(33, 18), (33, 20), (31, 20), (32, 20), (33, 19)}
# Round 24, Num_ = 2, PredictedPathPositions = {(32, 21), (31, 20), (31, 22), (32, 20), (32, 22)}
# Round 26, Num_ = 0, PredictedPathPositions = {(28, 20), (28, 21), (29, 21), (28, 19), (29, 19)}
# Round 26, Num_ = 2, PredictedPathPositions = {(28, 20), (31, 20), (29, 20), (32, 20), (30, 20)}
# Round 28, Num_ = 0, PredictedPathPositions = {(34, 17), (34, 18), (34, 15), (34, 16), (34, 19)}
# Round 29, Num_ = 1, PredictedPathPositions = {(18, 24), (16, 24), (17, 24), (16, 22), (16, 23)}
# Round 32, Num_ = 1, PredictedPathPositions = {(23, 12), (23, 10), (23, 11), (24, 10), (25, 10)}
# Round 33, Num_ = 1, PredictedPathPositions = {(22, 8), (20, 6), (20, 8), (21, 8), (20, 7)}
# Round 38, Num_ = 2, PredictedPathPositions = {(17, 23), (18, 23), (19, 23), (20, 23), (21, 23)}
# Round 49, Num_ = 0, PredictedPathPositions = {(28, 28), (28, 25), (28, 26), (27, 25), (28, 27)}
# Round 50, Num_ = 0, PredictedPathPositions = {(25, 24), (26, 24), (22, 24), (23, 24), (24, 24)}
# Round 64, Num_ = 1, PredictedPathPositions = {(21, 10), (21, 13), (22, 14), (16, 9), (17, 9), (24, 13), (18, 9), (19, 9), (20, 9), (21, 14), (21, 11), (23, 14), (24, 14), (25, 13), (26, 14), (21, 9), (21, 12), (25, 14)}
# Round 64, Num_ = 2, PredictedPathPositions = {(21, 10), (21, 11), (20, 10)}
# Round 66, Num_ = 2, PredictedPathPositions = {(34, 13), (34, 14)}
# Round 67, Num_ = 0, PredictedPathPositions = {(20, 16), (21, 16), (17, 16), (18, 16), (19, 16)}
# Round 74, Num_ = 2, PredictedPathPositions = {(30, 19), (31, 20), (30, 18), (32, 20), (30, 20)}
# Round 76, Num_ = 0, PredictedPathPositions = {(18, 23), (19, 23), (20, 23), (18, 22), (19, 22), (20, 22), (18, 21), (19, 21)}
# Total time: 4.037657022476196
# Part time: 0
# 0.0
# 126
# [5.5, 2.642857142857143, 3.7857142857142856, 2.0714285714285716, 3.357142857142857, 3.642857142857143]
# [4, 0, 2, 0, 4, 2]
# [44, 7, 6, 18, 0, 28]
# [98, 91, 127, 77, 83, 83]
# 5.5
# Game 18
# Round 88, Num_ = 0, PredictedPathPositions = {(37, 23)}
# Total time: 1.8035519123077393
# Part time: 0
# 0.0
# 109
# [4.785714285714286, 5.357142857142857, 2.4285714285714284, 4.0, 2.2857142857142856, 2.142857142857143]
# [2, 2, 0, 4, 0, 0]
# [48, 54, 3, 0, 0, 3]
# [94, 110, 17, 19, 19, 11]
# 4.785714285714286
# Game 19
# Round 39, Num_ = 2, PredictedPathPositions = {(27, 31), (27, 32), (27, 34), (27, 30), (27, 33)}
# Round 43, Num_ = 1, PredictedPathPositions = {(16, 20), (16, 21), (17, 20), (18, 20), (16, 22)}
# Round 43, Num_ = 2, PredictedPathPositions = {(18, 18), (19, 17), (18, 20), (19, 18), (18, 19)}
# Round 45, Num_ = 1, PredictedPathPositions = {(28, 22), (29, 22), (26, 22), (29, 21), (27, 22)}
# Round 46, Num_ = 1, PredictedPathPositions = {(17, 22), (18, 22), (19, 22), (15, 22), (16, 22)}
# Round 65, Num_ = 1, PredictedPathPositions = {(16, 25), (19, 25), (17, 25), (20, 25), (18, 25)}
# Round 81, Num_ = 1, PredictedPathPositions = {(34, 17), (33, 20), (24, 20), (33, 19), (34, 19), (25, 21), (24, 19), (34, 18), (24, 18), (24, 21)}
# Round 83, Num_ = 1, PredictedPathPositions = {(25, 24), (26, 24), (27, 24), (25, 25), (27, 23)}
# Round 94, Num_ = 1, PredictedPathPositions = {(35, 19), (36, 20), (34, 20), (35, 20), (34, 19)}
# Total time: 3.153359889984131
# Part time: 0
# 0.0
# 108
# [1.7142857142857142, 3.4285714285714284, 5.785714285714286, 5.214285714285714, 2.0, 2.857142857142857]
# [0, 2, 4, 4, 0, 0]
# [6, 11, 36, 28, 16, 22]
# [17, 99, 109, 102, 15, 82]
# 1.7142857142857142
# Game 20
# Total time: 2.343067169189453
# Part time: 0
# 0.0
# 89
# [1.5, 3.4285714285714284, 4.571428571428571, 4.285714285714286, 5.714285714285714, 1.5]
# [0, 2, 2, 2, 4, 0]
# [16, 22, 48, 49, 75, 2]
# [19, 34, 90, 69, 85, 20]
# 1.5
# Game 21
# Round 72, Num_ = 2, PredictedPathPositions = {(28, 17), (29, 17), (28, 15), (28, 16), (29, 16)}
# Total time: 2.8925998210906982
# Part time: 0
# 0.0
# 116
# [3.357142857142857, 3.357142857142857, 6.0, 1.9285714285714286, 4.428571428571429, 1.9285714285714286]
# [0, 0, 4, 0, 2, 0]
# [44, 59, 67, 0, 30, 3]
# [82, 56, 117, 48, 110, 10]
# 3.357142857142857
# Game 22
# Round 67, Num_ = 0, PredictedPathPositions = {(25, 25), (26, 25)}
# Total time: 2.5918221473693848
# Part time: 0
# 0.0
# 91
# [3.357142857142857, 1.6428571428571428, 5.0, 2.5, 2.5, 6.0]
# [0, 0, 4, 0, 0, 6]
# [26, 1, 30, 9, 13, 37]
# [80, 14, 86, 47, 19, 92]
# 3.357142857142857
# Game 23
# Round 38, Num_ = 0, PredictedPathPositions = {(13, 14), (15, 16), (14, 14), (15, 14), (15, 15)}
# Total time: 1.9957242012023926
# Part time: 0
# 0.0
# 62
# [3.4285714285714284, 2.2857142857142856, 2.2857142857142856, 3.5714285714285716, 3.857142857142857, 5.571428571428571]
# [0, 0, 0, 2, 2, 2]
# [72, 22, 9, 14, 0, 91]
# [45, 22, 38, 25, 62, 63]
# 3.4285714285714284
# Game 24
# Round 13, Num_ = 1, PredictedPathPositions = {(34, 16), (34, 17), (33, 16)}
# Round 13, Num_ = 2, PredictedPathPositions = {(31, 16), (32, 16), (33, 16), (34, 16), (30, 16)}
# Round 66, Num_ = 1, PredictedPathPositions = {(14, 19), (14, 22), (14, 23), (14, 20), (14, 21)}
# Round 68, Num_ = 1, PredictedPathPositions = {(15, 21), (16, 20), (17, 20), (15, 22), (15, 20)}
# Total time: 2.1818349361419678
# Part time: 0
# 0.0
# 104
# [2.5, 5.142857142857143, 3.9285714285714284, 1.6428571428571428, 5.285714285714286, 2.5]
# [0, 6, 0, 0, 4, 0]
# [7, 67, 108, 4, 68, 27]
# [21, 80, 73, 11, 105, 19]
# 2.5
# Game 25
# Round 20, Num_ = 0, PredictedPathPositions = {(15, 21), (16, 21), (15, 20)}
# Round 20, Num_ = 1, PredictedPathPositions = {(15, 21), (16, 21), (14, 22), (17, 21), (14, 21)}
# Round 21, Num_ = 0, PredictedPathPositions = {(19, 20), (20, 20), (18, 20)}
# Round 21, Num_ = 1, PredictedPathPositions = {(20, 19), (18, 21), (19, 21), (20, 20), (20, 21)}
# Total time: 1.6737701892852783
# Part time: 0
# 0.0
# 51
# [5.142857142857143, 5.357142857142857, 1.8571428571428572, 4.5, 2.0, 2.142857142857143]
# [4, 2, 0, 2, 0, 0]
# [38, 108, 10, 91, 19, 16]
# [50, 52, 30, 47, 27, 30]
# 5.142857142857143
# Game 26
# Total time: 1.9595003128051758
# Part time: 0
# 0.0
# 87
# [2.0, 1.4285714285714286, 5.714285714285714, 4.785714285714286, 2.7142857142857144, 4.357142857142857]
# [0, 0, 4, 2, 0, 2]
# [7, 5, 32, 64, 25, 25]
# [20, 9, 88, 42, 41, 76]
# 2.0
# Game 27
# Round 15, Num_ = 0, PredictedPathPositions = {(32, 15), (33, 15), (34, 15), (33, 14), (34, 14)}
# Round 57, Num_ = 2, PredictedPathPositions = {(39, 18), (38, 20), (40, 23), (39, 21), (40, 20), (45, 19), (36, 16), (41, 18), (42, 17), (41, 21), (42, 20), (44, 17), (38, 16), (38, 19), (40, 16), (39, 20), (40, 22), (36, 15), (42, 16), (44, 16), (41, 23), (43, 20), (44, 19), (43, 17), (38, 18), (38, 21), (40, 18), (39, 16), (40, 21), (37, 16), (41, 16), (42, 21), (43, 16), (42, 18), (41, 22), (43, 19)}
# Round 73, Num_ = 2, PredictedPathPositions = {(26, 21), (26, 20), (26, 22), (24, 20), (25, 20)}
# Round 86, Num_ = 0, PredictedPathPositions = {(31, 19), (32, 19)}
# Total time: 2.833723545074463
# Part time: 0
# 0.0
# 101
# [4.642857142857143, 1.4285714285714286, 2.857142857142857, 2.0, 5.785714285714286, 4.285714285714286]
# [6, 0, 0, 0, 6, 2]
# [24, 5, 29, 9, 44, 37]
# [101, 12, 86, 14, 102, 98]
# 4.642857142857143
# Game 28
# Round 13, Num_ = 1, PredictedPathPositions = {(46, 20), (47, 20), (48, 20), (45, 21), (46, 21)}
# Round 17, Num_ = 2, PredictedPathPositions = {(23, 27), (23, 28), (23, 25), (23, 26), (23, 24)}
# Round 29, Num_ = 2, PredictedPathPositions = {(36, 24), (37, 24), (33, 24), (34, 24), (35, 24)}
# Total time: 2.71669340133667
# Part time: 0
# 0.0
# 118
# [1.4285714285714286, 2.2857142857142856, 4.0, 5.571428571428571, 2.2857142857142856, 5.428571428571429]
# [0, 0, 2, 4, 0, 6]
# [3, 16, 30, 45, 14, 43]
# [10, 28, 80, 119, 43, 92]
# 1.4285714285714286
# Game 29
# Round 39, Num_ = 1, PredictedPathPositions = {(31, 16), (32, 16), (29, 15), (29, 16), (30, 16)}
# Round 72, Num_ = 1, PredictedPathPositions = {(29, 14), (27, 14), (28, 14), (29, 13)}
# Round 109, Num_ = 1, PredictedPathPositions = {(23, 18)}
# Total time: 2.332566738128662
# Part time: 0
# 0.0
# 122
# [2.2142857142857144, 6.0, 5.0, 2.5, 1.9285714285714286, 3.357142857142857]
# [0, 4, 2, 0, 0, 0]
# [0, 45, 37, 14, 6, 27]
# [23, 123, 114, 22, 14, 79]
# 2.2142857142857144
# Game 30
# Total time: 2.243354558944702
# Part time: 0
# 0.0
# 100
# [1.6428571428571428, 2.5, 2.5, 3.357142857142857, 5.785714285714286, 5.214285714285714]
# [0, 0, 0, 0, 6, 6]
# [2, 8, 7, 31, 39, 33]
# [9, 12, 29, 75, 101, 93]
# 1.6428571428571428
# Game 31
# Round 21, Num_ = 2, PredictedPathPositions = {(31, 11), (32, 10), (33, 10), (33, 9), (31, 10)}
# Round 58, Num_ = 2, PredictedPathPositions = {(28, 17), (28, 23), (29, 17), (28, 20), (28, 19), (28, 22), (28, 18), (28, 25), (28, 21), (28, 24)}
# Round 60, Num_ = 0, PredictedPathPositions = {(30, 19), (31, 20), (29, 18), (30, 18), (30, 20)}
# Round 79, Num_ = 0, PredictedPathPositions = {(33, 23), (34, 23), (35, 23), (31, 23), (32, 23)}
# Round 81, Num_ = 2, PredictedPathPositions = {(35, 19), (35, 22), (35, 18), (35, 20), (35, 21)}
# Round 84, Num_ = 2, PredictedPathPositions = {(24, 19), (25, 19), (21, 19), (22, 19), (23, 19)}
# Total time: 3.2905068397521973
# Part time: 0
# 0.0
# 97
# [5.785714285714286, 1.7142857142857142, 5.214285714285714, 3.7142857142857144, 1.7142857142857142, 2.857142857142857]
# [4, 0, 4, 2, 0, 0]
# [34, 3, 31, 25, 0, 26]
# [98, 12, 97, 94, 57, 58]
# 5.785714285714286
# Game 32
# Round 14, Num_ = 2, PredictedPathPositions = {(21, 15), (17, 15), (18, 15), (19, 15), (20, 15)}
# Round 46, Num_ = 0, PredictedPathPositions = {(29, 22), (29, 23), (29, 21), (30, 21), (31, 21)}
# Round 50, Num_ = 0, PredictedPathPositions = {(27, 26), (27, 27), (28, 26), (26, 28), (27, 28)}
# Round 56, Num_ = 0, PredictedPathPositions = {(37, 20), (33, 20), (36, 20), (34, 20), (35, 20)}
# Total time: 2.9956116676330566
# Part time: 0
# 0.0
# 86
# [2.7857142857142856, 4.642857142857143, 1.9285714285714286, 1.9285714285714286, 4.5, 5.214285714285714]
# [0, 4, 0, 0, 0, 4]
# [22, 35, 17, 19, 43, 37]
# [59, 78, 37, 29, 87, 84]
# 2.7857142857142856
# Game 33
# Round 13, Num_ = 0, PredictedPathPositions = {(29, 17), (29, 18)}
# Round 13, Num_ = 2, PredictedPathPositions = {(28, 17), (29, 17), (27, 17), (27, 18)}
# Round 15, Num_ = 0, PredictedPathPositions = {(33, 17), (32, 15), (34, 17), (32, 16), (33, 16)}
# Round 15, Num_ = 2, PredictedPathPositions = {(31, 16), (32, 16), (29, 16), (30, 16)}
# Round 45, Num_ = 1, PredictedPathPositions = {(19, 14), (19, 17), (19, 20), (22, 23), (18, 15), (19, 18), (19, 15), (19, 21), (20, 15), (20, 21), (22, 21), (22, 24), (19, 16), (20, 16), (19, 19), (21, 21), (22, 22), (18, 14)}
# Total time: 2.6585984230041504
# Part time: 0
# 0.0
# 122
# [4.571428571428571, 5.428571428571429, 1.4285714285714286, 5.0, 2.2857142857142856, 2.2857142857142856]
# [2, 6, 0, 4, 0, 0]
# [39, 48, 4, 45, 21, 19]
# [123, 59, 31, 105, 33, 46]
# 4.571428571428571
# Game 34
# Round 42, Num_ = 0, PredictedPathPositions = {(39, 23), (40, 23), (42, 24), (41, 23), (42, 23)}
# Round 43, Num_ = 0, PredictedPathPositions = {(37, 21), (38, 21), (39, 21), (39, 22), (36, 21)}
# Total time: 2.621642827987671
# Part time: 0
# 0.0
# 129
# [3.357142857142857, 4.214285714285714, 1.9285714285714286, 3.5714285714285716, 2.5, 5.428571428571429]
# [0, 0, 0, 2, 0, 4]
# [19, 68, 5, 0, 9, 14]
# [57, 95, 12, 63, 23, 130]
# 3.357142857142857
# Game 35
# Round 8, Num_ = 1, PredictedPathPositions = {(28, 27)}
# Round 27, Num_ = 1, PredictedPathPositions = {(34, 23), (35, 23), (36, 23), (34, 24), (34, 25)}
# Total time: 2.6101207733154297
# Part time: 0
# 0.0
# 108
# [1.7142857142857142, 4.785714285714286, 2.2857142857142856, 3.7142857142857144, 3.142857142857143, 5.357142857142857]
# [0, 2, 0, 4, 0, 2]
# [15, 165, 16, 0, 24, 171]
# [22, 70, 24, 43, 45, 109]
# 1.7142857142857142
# Game 36
# Total time: 2.071307897567749
# Part time: 0
# 0.0
# 109
# [4.428571428571429, 2.0, 5.0, 5.571428571428571, 1.7142857142857142, 2.2857142857142856]
# [2, 0, 2, 2, 0, 0]
# [16, 8, 24, 46, 0, 1]
# [31, 18, 109, 110, 19, 28]
# 4.428571428571429
# Game 37
# Round 25, Num_ = 1, PredictedPathPositions = {(31, 16), (29, 17), (30, 17), (30, 16), (31, 15)}
# Round 45, Num_ = 2, PredictedPathPositions = {(21, 20), (22, 21), (21, 19), (19, 20), (22, 20), (20, 20), (21, 21), (22, 19)}
# Total time: 2.034864902496338
# Part time: 0
# 0.0
# 66
# [3.5, 5.428571428571429, 5.571428571428571, 3.5, 1.2142857142857142, 1.7857142857142858]
# [2, 6, 4, 2, 0, 0]
# [26, 75, 89, 34, 4, 9]
# [46, 66, 67, 42, 12, 36]
# 3.5
# Game 38
# Total time: 1.9915592670440674
# Part time: 0
# 0.0
# 72
# [3.642857142857143, 2.7857142857142856, 4.571428571428571, 2.642857142857143, 1.6428571428571428, 5.714285714285714]
# [0, 0, 2, 0, 0, 8]
# [57, 19, 29, 29, 8, 38]
# [46, 51, 55, 39, 22, 73]
# 3.642857142857143
# Game 39
# Round 37, Num_ = 1, PredictedPathPositions = {(23, 33), (22, 31), (23, 31), (23, 34), (23, 32)}
# Round 55, Num_ = 0, PredictedPathPositions = {(15, 21), (16, 21), (17, 20), (17, 21), (15, 22)}
# Total time: 2.9268112182617188
# Part time: 0
# 0.0
# 112
# [6.0, 4.214285714285714, 1.4285714285714286, 2.857142857142857, 3.9285714285714284, 2.5714285714285716]
# [4, 2, 0, 0, 2, 0]
# [83, 51, 5, 71, 32, 39]
# [113, 68, 28, 44, 99, 56]
# 6.0
# Game 40
# Round 28, Num_ = 0, PredictedPathPositions = {(33, 23), (34, 23), (35, 22), (35, 23), (35, 21)}
# Round 60, Num_ = 0, PredictedPathPositions = {(28, 23), (28, 20), (27, 24), (29, 20), (28, 19), (27, 23), (29, 19), (28, 22), (28, 18), (28, 21), (27, 19), (27, 25), (27, 18)}
# Round 67, Num_ = 0, PredictedPathPositions = {(29, 14), (30, 14), (27, 14), (30, 15), (28, 14)}
# Round 80, Num_ = 0, PredictedPathPositions = {(28, 17), (28, 18), (28, 20), (28, 19), (27, 17)}
# Round 81, Num_ = 0, PredictedPathPositions = {(31, 20), (29, 20), (31, 22), (30, 20), (31, 21)}
# Total time: 2.9951415061950684
# Part time: 0
# 0.0
# 128
# [3.5, 1.6428571428571428, 3.7857142857142856, 5.285714285714286, 1.3571428571428572, 5.428571428571429]
# [2, 0, 2, 4, 0, 6]
# [20, 8, 27, 45, 5, 26]
# [89, 15, 61, 105, 15, 129]
# 3.5
# Game 41
# Round 85, Num_ = 2, PredictedPathPositions = {(28, 20), (31, 20), (29, 20), (32, 20), (30, 20)}
# Total time: 2.881716012954712
# Part time: 0
# 0.0
# 135
# [2.2857142857142856, 3.642857142857143, 2.857142857142857, 5.571428571428571, 1.4285714285714286, 5.214285714285714]
# [0, 2, 0, 4, 0, 2]
# [13, 22, 21, 47, 9, 47]
# [34, 25, 92, 129, 16, 136]
# 2.2857142857142856
# Game 42
# Round 37, Num_ = 1, PredictedPathPositions = {(42, 26), (41, 26)}
# Total time: 2.8867084980010986
# Part time: 0
# 0.0
# 133
# [1.2142857142857142, 2.9285714285714284, 2.0714285714285716, 4.071428571428571, 5.285714285714286, 5.428571428571429]
# [0, 2, 0, 2, 4, 8]
# [6, 20, 26, 35, 48, 29]
# [23, 56, 54, 74, 88, 134]
# 1.2142857142857142
# Game 43
# Round 33, Num_ = 0, PredictedPathPositions = {(26, 32), (27, 32), (25, 32), (24, 31), (25, 31)}
# Round 33, Num_ = 2, PredictedPathPositions = {(26, 32), (24, 32), (22, 32), (25, 32), (23, 32)}
# Total time: 2.7232742309570312
# Part time: 0
# 0.0
# 96
# [2.2142857142857144, 1.9285714285714286, 3.357142857142857, 2.5, 5.428571428571429, 5.571428571428571]
# [0, 0, 0, 0, 6, 4]
# [9, 15, 24, 17, 26, 44]
# [55, 20, 80, 23, 96, 97]
# 2.2142857142857144
# Game 44
# Round 11, Num_ = 0, PredictedPathPositions = {(26, 17)}
# Round 17, Num_ = 2, PredictedPathPositions = {(16, 20), (17, 20), (18, 20), (18, 21), (19, 21)}
# Round 26, Num_ = 0, PredictedPathPositions = {(26, 21), (23, 21), (26, 22), (24, 21), (25, 21)}
# Round 32, Num_ = 0, PredictedPathPositions = {(32, 21), (34, 22), (33, 21), (32, 20), (33, 22)}
# Total time: 1.9362421035766602
# Part time: 0
# 0.0
# 72
# [3.2142857142857144, 3.7857142857142856, 6.0, 5.0, 1.6428571428571428, 1.3571428571428572]
# [2, 2, 6, 4, 0, 0]
# [55, 77, 93, 83, 5, 5]
# [35, 58, 73, 62, 17, 16]
# 3.2142857142857144
# Game 45
# Round 17, Num_ = 0, PredictedPathPositions = {(33, 23), (31, 24), (32, 24), (32, 23), (33, 22)}
# Total time: 1.461611270904541
# Part time: 0
# 0.0
# 56
# [3.4285714285714284, 1.7857142857142858, 5.142857142857143, 4.0, 5.428571428571429, 1.2142857142857142]
# [2, 0, 2, 2, 4, 0]
# [18, 17, 130, 44, 78, 4]
# [23, 16, 57, 29, 55, 14]
# 3.4285714285714284
# Game 46
# Round 61, Num_ = 0, PredictedPathPositions = {(24, 18)}
# Round 61, Num_ = 1, PredictedPathPositions = {(24, 18)}
# Round 73, Num_ = 0, PredictedPathPositions = {(24, 19), (25, 19), (26, 19), (22, 19), (23, 19)}
# Total time: 2.9682881832122803
# Part time: 0
# 0.0
# 140
# [5.214285714285714, 4.0, 1.2857142857142858, 3.0, 3.642857142857143, 3.857142857142857]
# [4, 2, 0, 2, 4, 2]
# [38, 48, 7, 36, 0, 10]
# [87, 76, 17, 67, 76, 141]
# 5.214285714285714
# Game 47
# Total time: 2.0898685455322266
# Part time: 0
# 0.0
# 150
# [2.0, 2.5714285714285716, 5.285714285714286, 5.285714285714286, 2.2857142857142856, 3.5714285714285716]
# [0, 0, 2, 2, 0, 2]
# [4, 18, 41, 20, 0, 3]
# [17, 18, 85, 151, 32, 24]
# 2.0
# Game 48
# Round 12, Num_ = 1, PredictedPathPositions = {(20, 18), (20, 19), (20, 20), (21, 18)}
# Round 15, Num_ = 2, PredictedPathPositions = {(23, 12), (23, 10), (23, 11), (23, 8), (23, 9)}
# Round 58, Num_ = 2, PredictedPathPositions = {(17, 20), (18, 20)}
# Total time: 2.619974136352539
# Part time: 0
# 0.0
# 150
# [2.7142857142857144, 1.7142857142857142, 5.5, 4.785714285714286, 3.7142857142857144, 2.5714285714285716]
# [0, 0, 4, 4, 2, 0]
# [30, 11, 34, 30, 2, 19]
# [25, 17, 88, 83, 151, 58]
# 2.7142857142857144
# Game 49
# Round 11, Num_ = 0, PredictedPathPositions = {(18, 18)}
# Total time: 2.6939125061035156
# Part time: 0
# 0.0
# 106
# [4.857142857142857, 5.571428571428571, 3.357142857142857, 2.2142857142857144, 1.6428571428571428, 3.357142857142857]
# [8, 4, 0, 0, 0, 0]
# [18, 47, 42, 17, 15, 20]
# [80, 107, 70, 25, 24, 73]
# 4.857142857142857
# Game 50
# Round 16, Num_ = 2, PredictedPathPositions = {(30, 35), (31, 34), (31, 35), (28, 35), (29, 35)}
# Round 18, Num_ = 2, PredictedPathPositions = {(36, 34), (32, 34), (33, 34), (34, 34), (35, 34)}
# Round 56, Num_ = 2, PredictedPathPositions = {(31, 17), (33, 19), (32, 17), (34, 19), (35, 19), (30, 19), (31, 19), (32, 19), (30, 18), (31, 18), (32, 18)}
# Total time: 2.729290246963501
# Part time: 0
# 0.0
# 73
# [6.0, 1.2142857142857142, 4.071428571428571, 2.0714285714285716, 4.714285714285714, 2.9285714285714284]
# [8, 0, 2, 0, 4, 2]
# [55, 3, 47, 25, 42, 22]
# [74, 17, 65, 56, 69, 57]
# 6.0
# Game 51
# Round 19, Num_ = 1, PredictedPathPositions = {(35, 19), (36, 19), (37, 19), (38, 19), (39, 19)}
# Round 29, Num_ = 0, PredictedPathPositions = {(25, 18), (25, 19), (25, 17), (25, 20), (25, 21)}
# Round 30, Num_ = 0, PredictedPathPositions = {(22, 21), (22, 19), (22, 20), (22, 22), (22, 23)}
# Round 31, Num_ = 0, PredictedPathPositions = {(26, 18), (28, 18), (26, 17), (28, 19), (27, 18)}
# Total time: 3.203760862350464
# Part time: 0
# 0.0
# 113
# [2.142857142857143, 6.0, 2.4285714285714284, 4.142857142857143, 2.7142857142857144, 3.5714285714285716]
# [0, 6, 0, 0, 0, 0]
# [0, 27, 10, 23, 4, 14]
# [35, 114, 28, 112, 36, 101]
# 2.142857142857143
# Game 52
# Round 26, Num_ = 0, PredictedPathPositions = {(27, 27), (26, 27), (31, 23), (32, 23), (31, 26), (32, 26), (26, 28), (28, 27), (33, 23), (29, 27), (30, 27), (32, 24), (31, 27), (32, 25), (26, 29), (31, 22), (33, 24), (32, 22)}
# Round 26, Num_ = 2, PredictedPathPositions = {(30, 14), (30, 17), (30, 23), (30, 20), (31, 23), (32, 23), (33, 22), (30, 18), (30, 15), (30, 21), (33, 23), (32, 24), (30, 16), (30, 19), (30, 22), (33, 24), (32, 22)}
# Total time: 2.6571121215820312
# Part time: 0
# 0.0
# 107
# [5.714285714285714, 4.285714285714286, 5.0, 1.7142857142857142, 2.0, 2.2857142857142856]
# [6, 2, 4, 0, 0, 0]
# [63, 33, 101, 13, 30, 16]
# [108, 91, 57, 33, 27, 35]
# 5.714285714285714
# Game 53
# Total time: 1.8505983352661133
# Part time: 0
# 0.0
# 95
# [2.7857142857142856, 1.6428571428571428, 3.357142857142857, 2.2142857142857144, 5.428571428571429, 5.571428571428571]
# [0, 0, 0, 0, 6, 4]
# [22, 2, 30, 9, 39, 42]
# [18, 9, 24, 17, 90, 96]
# 2.7857142857142856
# Game 54
# Round 79, Num_ = 1, PredictedPathPositions = {(25, 18), (28, 18), (26, 18), (27, 18)}
# Total time: 2.4154672622680664
# Part time: 0
# 0.0
# 102
# [5.571428571428571, 5.142857142857143, 2.0, 2.0, 2.0, 4.285714285714286]
# [4, 6, 0, 0, 0, 2]
# [33, 22, 9, 7, 12, 27]
# [103, 102, 18, 47, 11, 79]
# 5.571428571428571
# Game 55
# Round 16, Num_ = 0, PredictedPathPositions = {(21, 25), (21, 26), (20, 24), (21, 24), (21, 27)}
# Round 22, Num_ = 0, PredictedPathPositions = {(9, 19)}
# Round 22, Num_ = 2, PredictedPathPositions = {(9, 21), (9, 18), (9, 19), (9, 17), (9, 20)}
# Round 33, Num_ = 0, PredictedPathPositions = {(31, 29), (32, 29), (32, 30), (33, 30), (34, 30)}
# Round 50, Num_ = 0, PredictedPathPositions = {(34, 17), (35, 17), (37, 18), (36, 17), (37, 17)}
# Round 56, Num_ = 0, PredictedPathPositions = {(31, 22), (31, 23), (30, 21), (29, 21), (31, 21)}
# Round 57, Num_ = 0, PredictedPathPositions = {(30, 24), (30, 22), (30, 23), (30, 20), (30, 21)}
# Round 60, Num_ = 0, PredictedPathPositions = {(30, 23), (31, 23), (32, 23), (33, 22), (23, 22), (34, 22), (24, 22), (35, 22), (36, 22), (26, 22), (27, 22), (30, 21), (31, 21), (32, 21), (25, 22), (37, 22), (38, 22), (28, 22), (29, 22), (30, 22), (31, 22), (32, 22), (22, 22)}
# Round 61, Num_ = 0, PredictedPathPositions = {(24, 19), (25, 19), (23, 20), (23, 21), (23, 19)}
# Round 63, Num_ = 0, PredictedPathPositions = {(25, 24), (26, 24), (27, 24), (28, 24), (29, 24)}
# Total time: 3.3988728523254395
# Part time: 0
# 0.0
# 126
# [3.5, 2.357142857142857, 1.5, 5.285714285714286, 4.285714285714286, 4.071428571428571]
# [2, 0, 0, 4, 6, 2]
# [18, 27, 14, 42, 5, 56]
# [73, 49, 39, 127, 90, 61]
# 3.5
# Game 56
# Round 44, Num_ = 0, PredictedPathPositions = {(23, 27), (23, 19), (22, 17), (24, 19), (23, 22), (23, 28), (23, 25), (22, 18), (23, 17), (23, 23), (23, 20), (23, 26), (23, 29), (23, 18), (24, 18), (23, 21), (23, 24)}
# Round 84, Num_ = 1, PredictedPathPositions = {(24, 19)}
# Total time: 2.8731088638305664
# Part time: 0
# 0.0
# 139
# [4.5, 5.142857142857143, 1.7142857142857142, 4.5, 1.7142857142857142, 3.4285714285714284]
# [2, 8, 0, 2, 0, 0]
# [41, 24, 9, 39, 7, 47]
# [91, 140, 29, 108, 35, 45]
# 4.5
# Game 57
# Round 20, Num_ = 1, PredictedPathPositions = {(23, 27), (23, 28), (23, 26), (24, 26), (23, 29)}
# Round 20, Num_ = 2, PredictedPathPositions = {(23, 28), (24, 28), (23, 31), (23, 29), (23, 30)}
# Round 23, Num_ = 1, PredictedPathPositions = {(21, 31), (22, 31), (23, 31), (23, 29), (23, 30)}
# Round 23, Num_ = 2, PredictedPathPositions = {(21, 31), (22, 31), (23, 31), (20, 31), (20, 32)}
# Round 30, Num_ = 2, PredictedPathPositions = {(24, 19), (25, 18), (25, 19), (26, 18), (27, 18)}
# Round 32, Num_ = 2, PredictedPathPositions = {(31, 18), (31, 19), (32, 19), (31, 17), (33, 19)}
# Round 53, Num_ = 1, PredictedPathPositions = {(28, 20), (28, 21), (29, 21), (30, 21), (31, 21)}
# Round 53, Num_ = 2, PredictedPathPositions = {(32, 21), (31, 24), (31, 22), (31, 23), (31, 21)}
# Round 63, Num_ = 1, PredictedPathPositions = {(26, 21), (31, 20), (21, 19), (23, 19), (34, 19), (37, 18), (17, 15), (28, 21), (17, 18), (30, 21), (32, 21), (15, 14), (24, 20), (18, 19), (20, 19), (31, 22), (22, 19), (34, 21), (36, 18), (37, 17), (17, 14), (17, 17), (27, 21), (32, 20), (30, 20), (25, 21), (35, 19), (29, 21), (31, 21), (23, 20), (34, 20), (17, 16), (17, 19), (19, 19), (32, 22), (30, 22), (33, 21), (35, 18), (16, 14), (24, 21), (38, 17)}
# Total time: 2.9932334423065186
# Part time: 0
# 0.0
# 106
# [5.428571428571429, 2.9285714285714284, 3.7857142857142856, 3.2142857142857144, 4.428571428571429, 1.2142857142857142]
# [8, 2, 2, 0, 4, 0]
# [73, 16, 106, 90, 32, 2]
# [107, 66, 64, 84, 85, 10]
# 5.428571428571429
# Game 58
# Round 34, Num_ = 1, PredictedPathPositions = {(18, 17), (19, 17), (20, 17), (18, 16), (19, 16)}
# Round 45, Num_ = 2, PredictedPathPositions = {(35, 25), (35, 22), (35, 23), (35, 21), (35, 24)}
# Round 46, Num_ = 2, PredictedPathPositions = {(34, 26)}
# Round 48, Num_ = 0, PredictedPathPositions = {(38, 23), (39, 23), (40, 22), (41, 22), (39, 22)}
# Round 60, Num_ = 2, PredictedPathPositions = {(30, 19), (31, 19), (27, 19), (28, 19), (29, 19)}
# Round 69, Num_ = 0, PredictedPathPositions = {(22, 13), (21, 15), (21, 13), (21, 14), (23, 13)}
# Round 71, Num_ = 0, PredictedPathPositions = {(28, 20), (31, 20), (29, 20), (30, 20), (27, 20)}
# Round 72, Num_ = 0, PredictedPathPositions = {(29, 25), (29, 27), (29, 23), (29, 26), (29, 24)}
# Total time: 3.3080849647521973
# Part time: 0
# 0.0
# 138
# [3.4285714285714284, 3.9285714285714284, 3.2142857142857144, 5.714285714285714, 1.7142857142857142, 3.0]
# [0, 2, 2, 4, 0, 0]
# [25, 51, 0, 55, 3, 33]
# [139, 59, 75, 99, 11, 75]
# 3.4285714285714284
# Game 59
# Round 30, Num_ = 2, PredictedPathPositions = {(31, 24), (31, 25), (31, 22), (31, 23), (31, 21)}
# Total time: 2.277517080307007
# Part time: 0
# 0.0
# 96
# [2.7857142857142856, 1.6428571428571428, 3.642857142857143, 6.0, 2.2142857142857144, 4.714285714285714]
# [0, 0, 0, 8, 0, 2]
# [25, 1, 49, 56, 5, 27]
# [29, 11, 74, 97, 14, 94]
# 2.7857142857142856
# Game 60
# Round 12, Num_ = 0, PredictedPathPositions = {(16, 15), (16, 16), (17, 15), (18, 15), (16, 17)}
# Round 20, Num_ = 1, PredictedPathPositions = {(30, 8), (28, 6), (30, 7), (29, 6), (30, 6)}
# Round 27, Num_ = 0, PredictedPathPositions = {(31, 11), (32, 11), (33, 11), (34, 11), (30, 11)}
# Round 27, Num_ = 1, PredictedPathPositions = {(31, 11), (31, 14), (32, 14), (31, 12), (31, 13)}
# Total time: 1.890214204788208
# Part time: 0
# 0.0
# 99
# [5.428571428571429, 5.071428571428571, 2.4285714285714284, 1.4285714285714286, 3.9285714285714284, 2.7142857142857144]
# [4, 2, 0, 0, 2, 0]
# [63, 56, 11, 4, 10, 11]
# [32, 100, 14, 9, 83, 17]
# 5.428571428571429
# Game 61
# Total time: 2.031080722808838
# Part time: 0
# 0.0
# 97
# [4.642857142857143, 2.0, 4.285714285714286, 1.4285714285714286, 5.785714285714286, 2.857142857142857]
# [4, 0, 2, 0, 4, 0]
# [37, 10, 55, 5, 60, 40]
# [91, 23, 37, 9, 98, 33]
# 4.642857142857143
# Game 62
# Total time: 1.9557909965515137
# Part time: 0
# 0.0
# 81
# [2.357142857142857, 1.2142857142857142, 3.7857142857142856, 2.642857142857143, 5.785714285714286, 5.214285714285714]
# [0, 0, 2, 2, 4, 4]
# [11, 7, 33, 10, 51, 38]
# [19, 15, 57, 16, 82, 78]
# 2.357142857142857
# Game 63
# Round 39, Num_ = 0, PredictedPathPositions = {(38, 10), (37, 8), (37, 9), (38, 9), (37, 7)}
# Round 63, Num_ = 1, PredictedPathPositions = {(23, 17), (23, 18), (23, 20), (23, 16), (23, 19)}
# Total time: 3.0645751953125
# Part time: 0
# 0.0
# 80
# [5.785714285714286, 4.071428571428571, 2.7857142857142856, 1.7857142857142858, 3.5, 3.0714285714285716]
# [4, 2, 0, 0, 4, 2]
# [73, 24, 64, 12, 0, 0]
# [81, 76, 57, 20, 57, 58]
# 5.785714285714286
# Game 64
# Round 10, Num_ = 0, PredictedPathPositions = {(44, 31)}
# Total time: 3.0267131328582764
# Part time: 0
# 0.0
# 127
# [4.285714285714286, 1.7857142857142858, 5.714285714285714, 3.7142857142857144, 1.2142857142857142, 4.285714285714286]
# [2, 0, 8, 2, 0, 2]
# [83, 14, 46, 17, 10, 33]
# [75, 25, 128, 87, 24, 91]
# 4.285714285714286
# Game 65
# Round 25, Num_ = 2, PredictedPathPositions = {(22, 13), (22, 15), (21, 16), (22, 16), (22, 14)}
# Round 68, Num_ = 2, PredictedPathPositions = {(29, 17), (29, 18), (27, 19), (28, 19), (29, 19)}
# Round 70, Num_ = 1, PredictedPathPositions = {(35, 19), (36, 19), (37, 19), (38, 19), (39, 19)}
# Round 78, Num_ = 2, PredictedPathPositions = {(16, 20), (17, 20), (17, 21), (14, 20), (15, 20)}
# Round 80, Num_ = 2, PredictedPathPositions = {(23, 17), (24, 17), (25, 17), (26, 17), (26, 18)}
# Round 83, Num_ = 1, PredictedPathPositions = {(39, 17), (40, 17), (36, 17), (37, 17), (38, 17)}
# Round 83, Num_ = 2, PredictedPathPositions = {(18, 17), (19, 17), (20, 17), (21, 17), (22, 17)}
# Round 84, Num_ = 1, PredictedPathPositions = {(37, 20), (37, 18), (37, 19), (36, 17), (37, 17)}
# Round 87, Num_ = 2, PredictedPathPositions = {(14, 19), (15, 19), (16, 19), (17, 19), (18, 19)}
# Round 93, Num_ = 2, PredictedPathPositions = {(18, 17), (19, 17), (21, 18), (20, 17), (21, 17)}
# Round 101, Num_ = 2, PredictedPathPositions = {(25, 23), (24, 23), (22, 24), (23, 24), (24, 24)}
# Round 109, Num_ = 2, PredictedPathPositions = {(24, 21), (22, 21), (23, 21), (24, 20), (22, 20)}
# Round 116, Num_ = 2, PredictedPathPositions = {(33, 17), (32, 15), (32, 16), (33, 16), (32, 14)}
# Total time: 4.417151212692261
# Part time: 0
# 0.0
# 135
# [2.0714285714285716, 3.2142857142857144, 4.571428571428571, 2.5714285714285716, 4.285714285714286, 4.285714285714286]
# [0, 0, 4, 2, 2, 2]
# [25, 24, 19, 8, 32, 30]
# [21, 136, 126, 96, 100, 117]
# 2.0714285714285716
# Game 66
# Total time: 1.8222298622131348
# Part time: 0
# 0.0
# 86
# [1.4285714285714286, 4.285714285714286, 2.2857142857142856, 5.785714285714286, 4.928571428571429, 2.2857142857142856]
# [0, 2, 0, 4, 4, 0]
# [3, 76, 8, 83, 75, 11]
# [8, 34, 21, 87, 77, 15]
# 1.4285714285714286
# Game 67
# Round 58, Num_ = 1, PredictedPathPositions = {(27, 15), (28, 20), (25, 9), (29, 20), (26, 7), (27, 13), (26, 10), (27, 16), (27, 19), (25, 7), (26, 11), (27, 14), (27, 20), (27, 17), (25, 8), (26, 9), (26, 12), (27, 12), (27, 18)}
# Total time: 1.7869949340820312
# Part time: 0
# 0.0
# 89
# [5.785714285714286, 5.214285714285714, 2.357142857142857, 2.5, 2.7857142857142856, 2.357142857142857]
# [4, 4, 0, 0, 0, 0]
# [49, 39, 4, 2, 4, 4]
# [90, 79, 9, 59, 12, 9]
# 5.785714285714286
# Game 68
# Total time: 2.0077972412109375
# Part time: 0
# 0.0
# 84
# [1.9285714285714286, 1.9285714285714286, 5.142857142857143, 2.7857142857142856, 5.285714285714286, 3.9285714285714284]
# [0, 0, 6, 0, 4, 0]
# [7, 5, 41, 26, 55, 63]
# [15, 17, 75, 29, 85, 42]
# 1.9285714285714286
# Game 69
# Round 17, Num_ = 0, PredictedPathPositions = {(43, 20), (43, 21), (43, 22), (43, 19)}
# Round 19, Num_ = 0, PredictedPathPositions = {(39, 17), (37, 16), (38, 16), (39, 16), (36, 16)}
# Total time: 2.0440590381622314
# Part time: 0
# 0.0
# 97
# [3.5714285714285716, 6.0, 3.357142857142857, 3.9285714285714284, 2.5, 1.6428571428571428]
# [2, 4, 0, 0, 0, 0]
# [29, 72, 54, 64, 20, 7]
# [23, 98, 55, 68, 26, 12]
# 3.5714285714285716
# Game 70
# Round 40, Num_ = 0, PredictedPathPositions = {(23, 18), (25, 20), (23, 20), (24, 20), (23, 19)}
# Total time: 1.961991548538208
# Part time: 0
# 0.0
# 86
# [3.642857142857143, 1.6428571428571428, 2.642857142857143, 2.357142857142857, 6.0, 4.714285714285714]
# [0, 0, 0, 0, 6, 4]
# [39, 6, 8, 8, 56, 50]
# [75, 10, 16, 13, 87, 63]
# 3.642857142857143
# Game 71
# Round 23, Num_ = 0, PredictedPathPositions = {(27, 21), (25, 19), (26, 19), (27, 19), (27, 20)}
# Round 25, Num_ = 0, PredictedPathPositions = {(34, 27), (34, 23), (34, 26), (34, 24), (34, 25)}
# Round 26, Num_ = 0, PredictedPathPositions = {(35, 19), (35, 17), (35, 18), (35, 20), (35, 21)}
# Round 49, Num_ = 0, PredictedPathPositions = {(23, 12), (24, 12), (24, 10), (24, 11), (22, 12)}
# Round 49, Num_ = 2, PredictedPathPositions = {(25, 13), (25, 11), (25, 12), (24, 10), (25, 10)}
# Round 51, Num_ = 0, PredictedPathPositions = {(22, 18), (22, 16), (23, 16), (22, 17), (22, 19)}
# Round 51, Num_ = 2, PredictedPathPositions = {(22, 18), (21, 20), (23, 18), (22, 19), (22, 20)}
# Round 57, Num_ = 2, PredictedPathPositions = {(17, 26), (18, 26), (21, 25), (19, 25), (17, 25), (20, 25), (18, 25), (22, 25), (17, 24), (18, 24)}
# Round 59, Num_ = 2, PredictedPathPositions = {(27, 13), (27, 10), (27, 11), (28, 13), (27, 12)}
# Total time: 2.429112434387207
# Part time: 0
# 0.0
# 75
# [3.357142857142857, 2.2142857142857144, 4.714285714285714, 1.6428571428571428, 6.0, 3.0714285714285716]
# [0, 0, 4, 0, 6, 0]
# [39, 5, 35, 0, 49, 34]
# [58, 49, 66, 12, 76, 63]
# 3.357142857142857
# Game 72
# Round 16, Num_ = 2, PredictedPathPositions = {(28, 17), (28, 18), (28, 15), (28, 16), (28, 19)}
# Round 42, Num_ = 0, PredictedPathPositions = {(19, 14), (18, 16), (19, 15), (19, 16), (18, 14)}
# Total time: 1.768867015838623
# Part time: 0
# 0.0
# 69
# [3.4285714285714284, 2.0, 3.857142857142857, 4.714285714285714, 5.571428571428571, 1.4285714285714286]
# [0, 0, 4, 4, 4, 0]
# [19, 11, 12, 42, 124, 7]
# [69, 17, 19, 59, 70, 15]
# 3.4285714285714284
# Game 73
# Round 15, Num_ = 2, PredictedPathPositions = {(21, 31), (22, 31), (23, 31), (24, 31), (20, 31)}
# Total time: 1.8083488941192627
# Part time: 0
# 0.0
# 74
# [5.214285714285714, 1.4285714285714286, 3.142857142857143, 5.785714285714286, 3.142857142857143, 2.2857142857142856]
# [4, 0, 2, 4, 0, 0]
# [49, 18, 30, 56, 46, 35]
# [53, 15, 27, 75, 39, 24]
# 5.214285714285714
# Game 74
# Round 24, Num_ = 2, PredictedPathPositions = {(27, 13), (29, 12), (28, 13), (26, 13), (29, 13)}
# Round 26, Num_ = 0, PredictedPathPositions = {(27, 16), (24, 17), (25, 17), (26, 17), (27, 17)}
# Round 26, Num_ = 2, PredictedPathPositions = {(25, 16), (23, 17), (24, 17), (25, 17), (25, 15)}
# Round 50, Num_ = 0, PredictedPathPositions = {(26, 16), (27, 16), (28, 16), (29, 15), (29, 16)}
# Round 50, Num_ = 2, PredictedPathPositions = {(25, 16), (26, 16), (22, 16), (23, 16), (24, 16)}
# Round 51, Num_ = 0, PredictedPathPositions = {(28, 17), (29, 17), (29, 15), (29, 16), (27, 17)}
# Round 51, Num_ = 2, PredictedPathPositions = {(23, 17), (24, 17), (25, 17), (26, 17), (27, 17)}
# Round 52, Num_ = 2, PredictedPathPositions = {(26, 16), (23, 17), (24, 17), (25, 17), (26, 17)}
# Round 65, Num_ = 2, PredictedPathPositions = {(19, 13), (19, 14), (21, 13), (19, 15), (20, 13)}
# Total time: 2.6043481826782227
# Part time: 0
# 0.0
# 80
# [3.0, 2.0, 5.571428571428571, 5.428571428571429, 2.0, 3.0]
# [2, 0, 4, 6, 0, 0]
# [0, 6, 62, 56, 3, 32]
# [56, 12, 81, 71, 21, 56]
# 3.0
# Game 75
# Round 28, Num_ = 0, PredictedPathPositions = {(17, 22), (14, 22), (14, 21), (15, 22), (16, 22)}
# Round 28, Num_ = 2, PredictedPathPositions = {(15, 21), (16, 21), (17, 21), (14, 20), (14, 21)}
# Round 31, Num_ = 1, PredictedPathPositions = {(26, 21), (27, 21), (28, 21)}
# Round 38, Num_ = 2, PredictedPathPositions = {(33, 28), (33, 31), (33, 29), (33, 30), (33, 27)}
# Round 45, Num_ = 0, PredictedPathPositions = {(9, 23), (9, 24), (9, 22), (9, 25), (9, 26)}
# Round 45, Num_ = 1, PredictedPathPositions = {(33, 25), (33, 26), (33, 24), (34, 24), (35, 24)}
# Round 55, Num_ = 0, PredictedPathPositions = {(11, 20), (11, 21), (12, 20), (12, 19), (11, 22)}
# Round 68, Num_ = 1, PredictedPathPositions = {(43, 21), (43, 19), (43, 20), (43, 17), (43, 18)}
# Round 70, Num_ = 1, PredictedPathPositions = {(42, 20)}
# Round 73, Num_ = 0, PredictedPathPositions = {(41, 19), (39, 21), (42, 19), (39, 22), (39, 19), (39, 20), (40, 19)}
# Round 76, Num_ = 0, PredictedPathPositions = {(22, 18), (20, 19), (21, 18), (20, 18), (22, 17)}
# Total time: 2.8737740516662598
# Part time: 0
# 0.0
# 86
# [3.357142857142857, 4.142857142857143, 5.714285714285714, 3.357142857142857, 2.7857142857142856, 1.6428571428571428]
# [0, 2, 6, 0, 0, 0]
# [21, 48, 93, 104, 19, 7]
# [81, 74, 87, 61, 80, 8]
# 3.357142857142857
# Game 76
# Round 24, Num_ = 1, PredictedPathPositions = {(29, 27), (29, 26), (30, 26), (31, 26), (28, 27)}
# Round 47, Num_ = 0, PredictedPathPositions = {(36, 11), (33, 10), (34, 10), (35, 10), (31, 10), (32, 10), (37, 11), (31, 9), (35, 11)}
# Round 50, Num_ = 0, PredictedPathPositions = {(38, 23), (39, 23), (39, 24), (39, 25), (37, 23)}
# Total time: 2.3340370655059814
# Part time: 0
# 0.0
# 68
# [4.5, 2.857142857142857, 2.0, 6.0, 4.214285714285714, 1.4285714285714286]
# [2, 0, 0, 4, 2, 0]
# [103, 80, 36, 109, 55, 7]
# [55, 48, 32, 69, 59, 13]
# 4.5
# Game 77
# Round 12, Num_ = 1, PredictedPathPositions = {(21, 15), (22, 15)}
# Round 16, Num_ = 0, PredictedPathPositions = {(39, 17), (40, 17), (41, 17), (42, 17), (43, 17)}
# Round 17, Num_ = 0, PredictedPathPositions = {(41, 14), (44, 15), (42, 14), (43, 14), (44, 14)}
# Round 23, Num_ = 1, PredictedPathPositions = {(24, 19), (24, 17), (24, 18), (24, 20), (24, 21)}
# Round 29, Num_ = 1, PredictedPathPositions = {(26, 14), (26, 12), (26, 13), (27, 12), (26, 15)}
# Round 30, Num_ = 1, PredictedPathPositions = {(27, 16), (28, 15), (28, 16), (28, 13), (28, 14)}
# Round 49, Num_ = 0, PredictedPathPositions = {(43, 21), (41, 22), (43, 20), (42, 22), (43, 22)}
# Total time: 3.0343549251556396
# Part time: 0
# 0.0
# 90
# [4.571428571428571, 2.857142857142857, 1.2142857142857142, 3.7142857142857144, 5.714285714285714, 2.9285714285714284]
# [2, 2, 0, 2, 4, 0]
# [34, 21, 6, 33, 70, 46]
# [91, 35, 14, 83, 89, 76]
# 4.571428571428571
# Game 78
# Round 25, Num_ = 1, PredictedPathPositions = {(27, 26), (27, 27), (28, 26), (26, 27), (29, 26)}
# Round 37, Num_ = 1, PredictedPathPositions = {(39, 21), (41, 21), (40, 21), (39, 19), (39, 20)}
# Round 39, Num_ = 2, PredictedPathPositions = {(45, 22), (45, 20), (45, 21), (43, 22), (44, 22)}
# Round 42, Num_ = 1, PredictedPathPositions = {(45, 19)}
# Total time: 2.5950777530670166
# Part time: 0
# 0.0
# 79
# [2.0, 2.857142857142857, 4.571428571428571, 6.0, 2.0, 3.5714285714285716]
# [0, 0, 2, 6, 0, 4]
# [10, 18, 55, 63, 11, 0]
# [47, 50, 69, 80, 19, 62]
# 2.0
# Game 79
# Round 15, Num_ = 0, PredictedPathPositions = {(20, 19), (17, 20), (18, 20), (19, 20), (20, 20)}
# Round 15, Num_ = 2, PredictedPathPositions = {(16, 20), (16, 18), (17, 20), (18, 20), (16, 19)}
# Round 17, Num_ = 2, PredictedPathPositions = {(30, 14), (30, 12), (30, 13), (30, 15), (30, 16)}
# Round 20, Num_ = 0, PredictedPathPositions = {(26, 11), (25, 13), (26, 12), (26, 13), (24, 13)}
# Round 20, Num_ = 2, PredictedPathPositions = {(24, 14), (24, 12), (24, 15), (24, 16), (24, 13)}
# Round 22, Num_ = 0, PredictedPathPositions = {(24, 12), (25, 11), (25, 12), (24, 10), (25, 10)}
# Round 22, Num_ = 2, PredictedPathPositions = {(24, 12), (25, 11), (25, 12), (24, 11), (24, 13)}
# Round 27, Num_ = 0, PredictedPathPositions = {(31, 16), (31, 17), (30, 15), (30, 16), (31, 15)}
# Round 27, Num_ = 2, PredictedPathPositions = {(31, 16), (31, 17), (30, 15), (32, 17), (30, 16)}
# Total time: 2.011850118637085
# Part time: 0
# 0.0
# 87
# [5.428571428571429, 3.142857142857143, 5.357142857142857, 2.5714285714285716, 2.642857142857143, 1.8571428571428572]
# [4, 0, 2, 0, 2, 0]
# [28, 19, 34, 16, 0, 3]
# [87, 80, 88, 21, 9, 9]
# 5.428571428571429
# Game 80
# Round 28, Num_ = 0, PredictedPathPositions = {(36, 19), (36, 20), (36, 17), (36, 18), (37, 17)}
# Round 29, Num_ = 0, PredictedPathPositions = {(39, 17), (40, 17), (41, 17), (39, 16), (39, 15)}
# Round 29, Num_ = 1, PredictedPathPositions = {(39, 15), (38, 15), (38, 16), (38, 17)}
# Round 31, Num_ = 0, PredictedPathPositions = {(35, 14), (36, 14), (37, 13), (37, 14), (34, 14)}
# Round 50, Num_ = 1, PredictedPathPositions = {(35, 19), (36, 19), (36, 20), (33, 19), (34, 19)}
# Round 51, Num_ = 1, PredictedPathPositions = {(34, 22), (32, 22), (34, 21), (35, 21), (33, 22)}
# Total time: 2.723588228225708
# Part time: 0
# 0.0
# 111
# [2.7142857142857144, 4.5, 1.4285714285714286, 5.0, 2.0, 5.357142857142857]
# [0, 2, 0, 4, 0, 2]
# [17, 18, 2, 17, 11, 52]
# [50, 86, 12, 111, 17, 112]
# 2.7142857142857144
# Game 81
# Round 13, Num_ = 1, PredictedPathPositions = {(35, 19), (33, 18), (34, 18), (35, 18)}
# Round 59, Num_ = 1, PredictedPathPositions = {(20, 14), (21, 13), (20, 17), (23, 13), (24, 13), (14, 19), (18, 18), (15, 19), (19, 18), (21, 14), (17, 18), (20, 18), (20, 15), (25, 13), (16, 19), (14, 20), (17, 19), (15, 20), (20, 16), (22, 13), (14, 18), (15, 18)}
# Total time: 2.7491507530212402
# Part time: 0
# 0.0
# 128
# [1.2142857142857142, 4.285714285714286, 1.7857142857142858, 3.4285714285714284, 5.428571428571429, 4.857142857142857]
# [0, 2, 0, 2, 6, 2]
# [5, 34, 8, 25, 27, 40]
# [10, 65, 19, 60, 129, 123]
# 1.2142857142857142
# Game 82
# Round 26, Num_ = 0, PredictedPathPositions = {(24, 25), (26, 24), (26, 25), (24, 26), (25, 25)}
# Round 32, Num_ = 0, PredictedPathPositions = {(23, 12), (20, 12), (23, 11), (21, 12), (22, 12)}
# Round 33, Num_ = 0, PredictedPathPositions = {(24, 12), (25, 12), (26, 12), (24, 11), (27, 12)}
# Round 61, Num_ = 0, PredictedPathPositions = {(20, 19), (20, 22), (20, 23), (20, 20), (20, 21)}
# Total time: 2.459317922592163
# Part time: 0
# 0.0
# 90
# [5.357142857142857, 4.571428571428571, 1.5714285714285714, 1.8571428571428572, 2.857142857142857, 4.785714285714286]
# [2, 4, 0, 0, 0, 2]
# [27, 21, 6, 6, 11, 24]
# [91, 18, 10, 11, 84, 90]
# 5.357142857142857
# Game 83
# ...
# Round 17, Num_ = 0, PredictedPathPositions = {(39, 8), (39, 10), (39, 11), (38, 8), (39, 9)}
# Round 17, Num_ = 1, PredictedPathPositions = {(36, 11), (39, 11), (37, 11), (38, 11)}
# Round 31, Num_ = 0, PredictedPathPositions = {(19, 18)}
# Round 60, Num_ = 0, PredictedPathPositions = {(31, 14), (32, 14), (33, 14), (31, 15), (34, 14)}
# Round 60, Num_ = 1, PredictedPathPositions = {(32, 15), (33, 15), (34, 15), (30, 15), (31, 15)}
# Round 66, Num_ = 2, PredictedPathPositions = {(37, 20), (37, 16), (38, 16), (37, 19), (39, 17), (38, 15), (37, 18), (39, 16), (37, 17), (39, 15), (38, 17)}
# Total time: 2.6142637729644775
# Part time: 0
# 0.0
# 111
# [4.214285714285714, 3.142857142857143, 4.5, 1.7142857142857142, 5.714285714285714, 1.7142857142857142]
# [2, 0, 2, 0, 6, 0]
# [44, 55, 31, 7, 77, 12]
# [70, 67, 112, 18, 84, 14]
# 4.214285714285714
# Game 375
# Round 24, Num_ = 0, PredictedPathPositions = {(21, 20)}
# Round 33, Num_ = 1, PredictedPathPositions = {(38, 20), (38, 19), (33, 19), (34, 19), (38, 18), (37, 18), (34, 18), (35, 18), (36, 18)}
# Round 59, Num_ = 1, PredictedPathPositions = {(39, 28), (34, 27), (42, 26), (35, 27), (42, 29), (36, 27), (34, 26), (42, 28), (40, 29), (38, 28), (41, 29), (42, 27), (39, 29), (37, 27), (38, 27)}
# Total time: 2.6556615829467773
# Part time: 0
# 0.0
# 103
# [3.7142857142857144, 3.7142857142857144, 1.2142857142857142, 2.642857142857143, 3.7142857142857144, 6.0]
# [2, 2, 0, 0, 2, 4]
# [27, 17, 16, 35, 25, 44]
# [62, 81, 26, 48, 68, 104]
# 3.7142857142857144
# Game 376
# Round 10, Num_ = 0, PredictedPathPositions = {(31, 17), (32, 17), (29, 17), (30, 17)}
# Round 17, Num_ = 0, PredictedPathPositions = {(29, 14), (30, 14), (28, 15), (30, 15), (28, 14)}
# Round 19, Num_ = 0, PredictedPathPositions = {(33, 12), (29, 12), (30, 12), (31, 12), (32, 12)}
# Round 36, Num_ = 0, PredictedPathPositions = {(22, 13), (23, 12), (24, 12), (22, 12), (24, 13)}
# Round 39, Num_ = 0, PredictedPathPositions = {(12, 17), (12, 15), (12, 16), (11, 14), (12, 14)}
# Round 39, Num_ = 1, PredictedPathPositions = {(14, 13), (14, 14), (12, 13), (12, 14), (13, 13)}
# Round 48, Num_ = 0, PredictedPathPositions = {(30, 13), (33, 13), (31, 13), (34, 13), (32, 13)}
# Round 58, Num_ = 1, PredictedPathPositions = {(22, 18), (23, 18), (24, 17), (24, 18), (24, 16)}
# Round 64, Num_ = 2, PredictedPathPositions = {(39, 23), (38, 25), (38, 24), (39, 24), (39, 25)}
# Total time: 2.803413152694702
# Part time: 0
# 0.0
# 78
# [4.571428571428571, 5.571428571428571, 3.7142857142857144, 1.5, 3.0, 2.642857142857143]
# [4, 4, 4, 0, 2, 0]
# [34, 47, 0, 6, 31, 39]
# [70, 79, 70, 18, 68, 61]
# 4.571428571428571
# Game 377
# Round 21, Num_ = 2, PredictedPathPositions = {(16, 20), (14, 19), (17, 20), (14, 20), (15, 20)}
# Round 24, Num_ = 1, PredictedPathPositions = {(26, 21), (25, 23), (25, 24), (25, 22), (25, 21)}
# Round 57, Num_ = 1, PredictedPathPositions = {(23, 20), (25, 22), (24, 20), (22, 20), (22, 23), (24, 19), (23, 22), (24, 22), (24, 18), (22, 22)}
# Round 57, Num_ = 2, PredictedPathPositions = {(22, 21), (23, 20), (24, 20), (22, 20), (22, 22)}
# Round 58, Num_ = 1, PredictedPathPositions = {(21, 20), (18, 21), (19, 21), (20, 20), (20, 21)}
# Round 58, Num_ = 2, PredictedPathPositions = {(15, 21), (16, 21), (17, 21), (18, 21), (14, 21)}
# Round 59, Num_ = 1, PredictedPathPositions = {(19, 19), (20, 19), (16, 19), (17, 19), (18, 19)}
# Round 59, Num_ = 2, PredictedPathPositions = {(16, 20), (17, 20), (18, 20), (16, 19), (19, 20)}
# Total time: 3.057476758956909
# Part time: 0
# 0.0
# 89
# [3.4285714285714284, 5.714285714285714, 2.2857142857142856, 3.4285714285714284, 1.7142857142857142, 4.428571428571429]
# [0, 6, 0, 4, 0, 2]
# [30, 43, 28, 0, 8, 48]
# [74, 90, 63, 73, 14, 73]
# 3.4285714285714284
# Game 378
# Round 30, Num_ = 0, PredictedPathPositions = {(26, 16), (24, 17), (24, 18), (25, 17), (26, 17)}
# Round 32, Num_ = 0, PredictedPathPositions = {(28, 17), (29, 17), (29, 18), (26, 17), (27, 17)}
# Round 33, Num_ = 0, PredictedPathPositions = {(30, 18), (32, 18), (31, 18), (29, 18)}
# Round 77, Num_ = 1, PredictedPathPositions = {(19, 23), (18, 20), (20, 23), (19, 20), (20, 20), (18, 19), (22, 23), (19, 19), (19, 22), (19, 21), (21, 23), (20, 21)}
# Total time: 2.5372865200042725
# Part time: 0
# 0.0
# 93
# [6.0, 4.428571428571429, 3.357142857142857, 3.357142857142857, 1.9285714285714286, 1.9285714285714286]
# [6, 4, 0, 0, 0, 0]
# [33, 18, 23, 22, 6, 0]
# [94, 93, 28, 78, 12, 18]
# 6.0
# Game 379
# Round 11, Num_ = 0, PredictedPathPositions = {(23, 22), (23, 20), (23, 21), (24, 20), (22, 22)}
# Round 44, Num_ = 0, PredictedPathPositions = {(32, 21), (32, 20), (29, 21), (30, 21), (31, 21)}
# Round 44, Num_ = 1, PredictedPathPositions = {(28, 23), (29, 23), (30, 22), (30, 23), (30, 21)}
# Round 54, Num_ = 1, PredictedPathPositions = {(32, 15), (33, 12), (33, 15), (33, 13), (33, 14)}
# Total time: 2.2078773975372314
# Part time: 0
# 0.0
# 80
# [6.0, 3.7142857142857144, 3.642857142857143, 2.2857142857142856, 3.9285714285714284, 1.4285714285714286]
# [6, 0, 2, 0, 2, 0]
# [64, 49, 32, 18, 28, 8]
# [81, 80, 18, 33, 77, 10]
# 6.0
# Game 380
# Total time: 1.4636120796203613
# Part time: 0
# 0.0
# 58
# [1.9285714285714286, 5.571428571428571, 3.642857142857143, 5.142857142857143, 2.5, 2.2142857142857144]
# [0, 2, 0, 4, 0, 0]
# [6, 94, 85, 45, 9, 0]
# [8, 59, 46, 51, 18, 28]
# 1.9285714285714286
# Game 381
# Round 26, Num_ = 0, PredictedPathPositions = {(21, 15), (21, 16), (22, 16), (23, 16), (24, 16)}
# Total time: 3.300544023513794
# Part time: 0
# 0.0
# 109
# [6.0, 1.0, 2.642857142857143, 3.5, 3.5, 4.357142857142857]
# [6, 0, 2, 2, 2, 2]
# [37, 9, 12, 28, 33, 34]
# [110, 11, 58, 84, 81, 94]
# 6.0
# Game 382
# Round 15, Num_ = 1, PredictedPathPositions = {(23, 17), (24, 17), (22, 17), (24, 18)}
# Round 19, Num_ = 1, PredictedPathPositions = {(28, 18), (28, 20), (29, 18), (30, 18), (28, 19)}
# Round 49, Num_ = 2, PredictedPathPositions = {(42, 21), (42, 18), (42, 19), (42, 22), (42, 20)}
# Round 68, Num_ = 1, PredictedPathPositions = {(37, 10), (34, 11), (35, 10), (35, 11), (36, 10)}
# Round 72, Num_ = 0, PredictedPathPositions = {(30, 25), (33, 25), (31, 25), (32, 25), (34, 25)}
# Round 83, Num_ = 2, PredictedPathPositions = {(30, 15), (30, 16)}
# Round 103, Num_ = 1, PredictedPathPositions = {(32, 13)}
# Total time: 2.7296695709228516
# Part time: 0
# 0.0
# 109
# [2.4285714285714284, 6.0, 3.857142857142857, 2.4285714285714284, 3.2857142857142856, 3.0]
# [0, 4, 0, 0, 0, 0]
# [0, 31, 5, 4, 15, 1]
# [76, 110, 109, 14, 29, 97]
# 2.4285714285714284
# Game 383
# Round 17, Num_ = 0, PredictedPathPositions = {(28, 28), (26, 28), (28, 29), (28, 30), (27, 28)}
# Round 17, Num_ = 1, PredictedPathPositions = {(25, 29), (26, 29), (27, 29), (25, 28), (28, 29)}
# Round 42, Num_ = 2, PredictedPathPositions = {(28, 12), (28, 10), (28, 11), (29, 10), (28, 13)}
# Round 66, Num_ = 1, PredictedPathPositions = {(33, 23), (34, 22), (34, 23), (34, 21), (33, 22)}
# Round 66, Num_ = 2, PredictedPathPositions = {(35, 19), (34, 22), (35, 22), (35, 20), (35, 21)}
# Round 67, Num_ = 2, PredictedPathPositions = {(36, 24), (36, 25), (36, 27), (36, 23), (36, 26)}
# Total time: 3.2553484439849854
# Part time: 0
# 0.0
# 102
# [3.9285714285714284, 3.2142857142857144, 5.5, 3.642857142857143, 1.5, 3.2142857142857144]
# [4, 2, 4, 0, 0, 2]
# [0, 35, 36, 43, 2, 29]
# [96, 70, 103, 96, 8, 78]
# 3.9285714285714284
# Game 384
# Round 32, Num_ = 0, PredictedPathPositions = {(19, 24)}
# Total time: 2.2917423248291016
# Part time: 0
# 0.0
# 82
# [5.714285714285714, 2.9285714285714284, 1.6428571428571428, 2.357142857142857, 3.0714285714285716, 5.285714285714286]
# [6, 0, 0, 0, 0, 4]
# [68, 10, 6, 10, 17, 108]
# [83, 60, 13, 19, 55, 74]
# 5.714285714285714
# Game 385
# Round 13, Num_ = 0, PredictedPathPositions = {(20, 16), (19, 14), (19, 15), (19, 16), (18, 14)}
# Total time: 2.379202365875244
# Part time: 0
# 0.0
# 102
# [5.571428571428571, 3.142857142857143, 3.2857142857142856, 2.857142857142857, 1.4285714285714286, 4.714285714285714]
# [2, 0, 2, 0, 0, 2]
# [42, 32, 16, 25, 3, 30]
# [103, 42, 20, 84, 7, 96]
# 5.571428571428571
# Game 386
# Round 10, Num_ = 2, PredictedPathPositions = {(36, 15)}
# Round 14, Num_ = 0, PredictedPathPositions = {(21, 19), (22, 19)}
# Round 49, Num_ = 2, PredictedPathPositions = {(21, 25), (21, 21), (21, 24), (21, 22), (21, 23)}
# Round 50, Num_ = 2, PredictedPathPositions = {(21, 25), (21, 24), (22, 24), (22, 22), (22, 23)}
# Round 52, Num_ = 0, PredictedPathPositions = {(16, 14), (16, 15), (16, 16), (17, 16), (18, 16)}
# Total time: 3.1468141078948975
# Part time: 0
# 0.0
# 111
# [3.357142857142857, 1.6428571428571428, 4.285714285714286, 2.642857142857143, 3.642857142857143, 5.428571428571429]
# [0, 0, 2, 0, 0, 4]
# [71, 8, 30, 18, 22, 31]
# [58, 16, 98, 98, 112, 107]
# 3.357142857142857
# Game 387
# Round 23, Num_ = 0, PredictedPathPositions = {(8, 15), (8, 14), (9, 14), (10, 14), (11, 14)}
# Round 25, Num_ = 0, PredictedPathPositions = {(9, 16), (10, 16), (11, 16), (8, 16), (11, 17)}
# Round 48, Num_ = 1, PredictedPathPositions = {(21, 25), (20, 24), (20, 25), (21, 24), (20, 26)}
# Round 48, Num_ = 2, PredictedPathPositions = {(21, 25), (23, 23), (21, 24), (21, 23), (22, 23)}
# Round 49, Num_ = 2, PredictedPathPositions = {(18, 22), (18, 23), (19, 22), (19, 20), (19, 21)}
# Round 50, Num_ = 2, PredictedPathPositions = {(19, 24), (19, 25), (19, 27), (19, 28), (19, 26)}
# Round 62, Num_ = 0, PredictedPathPositions = {(19, 13), (17, 14), (17, 15), (17, 13), (18, 13)}
# Round 68, Num_ = 2, PredictedPathPositions = {(23, 27), (22, 26), (22, 27), (23, 26), (22, 28)}
# Round 69, Num_ = 2, PredictedPathPositions = {(23, 23), (23, 20), (22, 24), (23, 19), (24, 19), (23, 22), (21, 25), (23, 25), (21, 24), (23, 21), (22, 25), (23, 24)}
# Total time: 3.4197487831115723
# Part time: 0
# 0.0
# 87
# [3.2142857142857144, 3.5, 3.5, 6.0, 3.2142857142857144, 1.5714285714285714]
# [2, 2, 2, 8, 2, 0]
# [1, 43, 37, 89, 10, 28]
# [87, 70, 75, 88, 80, 37]
# 3.2142857142857144
# Game 388
# Total time: 1.4033598899841309
# Part time: 0
# 0.0
# 60
# [3.857142857142857, 1.8571428571428572, 2.4285714285714284, 3.0, 5.142857142857143, 4.714285714285714]
# [0, 0, 0, 0, 6, 0]
# [52, 7, 21, 49, 73, 84]
# [42, 14, 19, 28, 33, 61]
# 3.857142857142857
# Game 389
# Round 24, Num_ = 2, PredictedPathPositions = {(33, 23), (32, 21), (34, 23), (32, 22), (32, 23)}
# Round 50, Num_ = 0, PredictedPathPositions = {(30, 19), (29, 22), (30, 22), (30, 20), (30, 21)}
# Round 50, Num_ = 2, PredictedPathPositions = {(30, 17), (31, 20), (31, 17), (30, 20), (33, 19), (32, 17), (32, 23), (30, 18), (32, 18), (31, 21), (33, 23), (34, 23), (35, 23), (30, 19), (32, 19), (31, 22), (32, 22)}
# Total time: 2.8075294494628906
# Part time: 0
# 0.0
# 118
# [3.0714285714285716, 2.2142857142857144, 3.0714285714285716, 5.285714285714286, 1.6428571428571428, 5.714285714285714]
# [0, 0, 0, 6, 0, 8]
# [30, 17, 20, 62, 8, 53]
# [55, 32, 61, 98, 13, 119]
# 3.0714285714285716
# Game 390
# Round 75, Num_ = 2, PredictedPathPositions = {(36, 24), (37, 24), (33, 24), (34, 24), (35, 24)}
# Round 94, Num_ = 1, PredictedPathPositions = {(28, 22), (28, 23), (28, 21), (29, 21), (30, 21)}
# Total time: 3.355313539505005
# Part time: 0
# 0.0
# 118
# [2.5714285714285716, 3.857142857142857, 4.0, 2.5714285714285716, 2.0, 6.0]
# [0, 4, 2, 0, 0, 6]
# [25, 5, 37, 4, 12, 54]
# [52, 113, 94, 118, 17, 119]
# 2.5714285714285716
# Game 391
# Round 13, Num_ = 0, PredictedPathPositions = {(26, 10), (26, 11), (26, 12), (26, 13), (25, 10)}
# Round 13, Num_ = 2, PredictedPathPositions = {(27, 13), (30, 13), (28, 13), (26, 13), (29, 13)}
# Round 44, Num_ = 0, PredictedPathPositions = {(21, 20), (21, 21), (21, 18), (21, 19), (21, 22)}
# Round 53, Num_ = 0, PredictedPathPositions = {(22, 15), (21, 16), (24, 17), (23, 15), (24, 16), (24, 19), (21, 15), (24, 18), (24, 15)}
# Round 55, Num_ = 0, PredictedPathPositions = {(25, 18), (25, 19), (24, 21), (25, 20), (25, 21)}
# Round 55, Num_ = 2, PredictedPathPositions = {(24, 22), (26, 20), (25, 22), (25, 20), (25, 21)}
# Round 57, Num_ = 2, PredictedPathPositions = {(21, 21), (17, 21), (18, 21), (19, 21), (20, 21)}
# Round 75, Num_ = 0, PredictedPathPositions = {(22, 18), (22, 19), (21, 17), (23, 19), (22, 17)}
# Total time: 2.1352269649505615
# Part time: 0
# 0.0
# 84
# [4.571428571428571, 2.0, 4.428571428571429, 1.4285714285714286, 2.5714285714285716, 6.0]
# [2, 0, 4, 0, 0, 6]
# [41, 13, 27, 9, 16, 50]
# [81, 26, 67, 16, 27, 85]
# 4.571428571428571
# Game 392
# Round 45, Num_ = 0, PredictedPathPositions = {(35, 27), (36, 27), (35, 26), (37, 28), (37, 27)}
# Round 59, Num_ = 0, PredictedPathPositions = {(27, 21), (26, 20), (27, 20), (27, 22), (25, 20)}
# Total time: 2.6920394897460938
# Part time: 0
# 0.0
# 105
# [2.9285714285714284, 3.7857142857142856, 1.2142857142857142, 2.642857142857143, 4.428571428571429, 6.0]
# [0, 2, 0, 2, 4, 8]
# [55, 47, 8, 20, 46, 62]
# [63, 64, 16, 19, 92, 106]
# 2.9285714285714284
# Game 393
# Round 30, Num_ = 0, PredictedPathPositions = {(30, 30), (31, 30), (32, 30), (29, 31), (30, 31)}
# Round 34, Num_ = 0, PredictedPathPositions = {(25, 23), (28, 23), (28, 24), (26, 23), (27, 23)}
# Round 72, Num_ = 2, PredictedPathPositions = {(24, 19), (23, 22), (23, 20), (23, 21), (23, 19)}
# Round 77, Num_ = 0, PredictedPathPositions = {(23, 16), (23, 15)}
# Round 81, Num_ = 0, PredictedPathPositions = {(23, 18), (23, 19)}
# Total time: 2.910181999206543
# Part time: 0
# 0.0
# 107
# [5.285714285714286, 2.0, 5.0, 1.8571428571428572, 4.714285714285714, 2.142857142857143]
# [2, 0, 2, 0, 2, 0]
# [54, 8, 32, 0, 34, 0]
# [106, 14, 108, 44, 80, 56]
# 5.285714285714286
# Game 394
# Total time: 2.1932101249694824
# Part time: 0
# 0.0
# 74
# [1.4285714285714286, 5.571428571428571, 2.2857142857142856, 5.0, 3.142857142857143, 3.5714285714285716]
# [0, 2, 0, 2, 0, 2]
# [0, 54, 7, 31, 18, 4]
# [11, 75, 15, 73, 56, 55]
# 1.4285714285714286
# Game 395
# Round 9, Num_ = 0, PredictedPathPositions = {(19, 19), (17, 19), (18, 19)}
# Round 11, Num_ = 0, PredictedPathPositions = {(14, 16)}
# Total time: 1.9649238586425781
# Part time: 0
# 0.0
# 109
# [3.357142857142857, 2.857142857142857, 1.4285714285714286, 5.714285714285714, 5.071428571428571, 2.5714285714285716]
# [2, 0, 0, 6, 2, 0]
# [12, 19, 5, 51, 37, 11]
# [16, 23, 13, 106, 110, 36]
# 3.357142857142857
# Game 396
# Round 35, Num_ = 0, PredictedPathPositions = {(29, 25), (28, 25)}
# Round 40, Num_ = 1, PredictedPathPositions = {(30, 30), (31, 30), (32, 30), (33, 30), (29, 30)}
# Round 40, Num_ = 2, PredictedPathPositions = {(32, 31), (33, 28), (32, 29), (32, 30), (32, 28)}
# Round 42, Num_ = 2, PredictedPathPositions = {(28, 25), (26, 25), (26, 27), (27, 25), (26, 26)}
# Round 45, Num_ = 0, PredictedPathPositions = {(28, 23), (27, 27), (28, 20), (31, 20), (28, 26), (29, 20), (29, 26), (30, 20), (28, 22), (29, 25), (27, 26), (28, 25), (28, 21), (28, 24), (28, 27)}
# Round 66, Num_ = 0, PredictedPathPositions = {(38, 23), (38, 24)}
# Total time: 2.7943520545959473
# Part time: 0
# 0.0
# 93
# [4.285714285714286, 4.357142857142857, 2.7142857142857144, 1.4285714285714286, 5.785714285714286, 2.4285714285714284]
# [2, 6, 0, 0, 6, 0]
# [27, 12, 23, 3, 39, 23]
# [91, 93, 54, 10, 94, 46]
# 4.285714285714286
# Game 397
# Total time: 1.868717908859253
# Part time: 0
# 0.0
# 73
# [5.142857142857143, 5.142857142857143, 2.642857142857143, 1.6428571428571428, 4.0, 2.4285714285714284]
# [4, 2, 0, 0, 2, 2]
# [75, 99, 26, 3, 7, 0]
# [55, 74, 30, 11, 73, 11]
# 5.142857142857143
# Game 398
# Round 56, Num_ = 2, PredictedPathPositions = {(25, 13), (25, 14), (23, 13), (25, 15), (24, 13)}
# Total time: 2.188753128051758
# Part time: 0
# 0.0
# 68
# [1.3571428571428572, 3.5, 6.0, 3.7857142857142856, 1.6428571428571428, 4.714285714285714]
# [0, 2, 6, 2, 0, 4]
# [3, 37, 54, 32, 5, 45]
# [10, 52, 69, 61, 10, 60]
# 1.3571428571428572
# Game 399
# Round 12, Num_ = 2, PredictedPathPositions = {(24, 19), (22, 19), (23, 19), (21, 19)}
# Round 71, Num_ = 2, PredictedPathPositions = {(37, 21), (34, 20), (34, 21), (35, 21), (36, 21)}
# Round 72, Num_ = 2, PredictedPathPositions = {(30, 19), (33, 20), (31, 20), (32, 20), (30, 20)}
# Total time: 2.6230392456054688
# Part time: 0
# 0.0
# 111
# [2.5, 3.5, 4.857142857142857, 4.857142857142857, 3.642857142857143, 1.6428571428571428]
# [0, 0, 6, 4, 0, 0]
# [18, 25, 17, 25, 47, 10]
# [26, 91, 112, 111, 64, 13]
# 2.5
# [3.62285714 3.51767857 3.55482143 3.44732143 3.47392857 3.38339286]
# Average Score_kill = [1.73  1.76  1.755 1.605 1.675 1.56 ]
# Average Score_len = [34.0775 31.68   32.9375 29.9125 29.45   28.29  ]
# Average Score_time = [58.2225 57.85   57.2425 56.9325 57.365  56.26  ]
# 3.5651190476190475
