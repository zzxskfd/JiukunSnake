# %%
import numpy as np
import gc
import os
import random
from scipy.stats import rankdata
from copy import copy, deepcopy
from time import sleep, time
from colorama import Fore, Style

# from AI import AI0, AI_greedy_1, AI0_rand, AI_greedy_0, AI_new_tree_search
from AI import AI_20220520, AI_20220520_early, AI_reversing
from utils import create_folder, save_json, DIRECTIONS, load_json, key2dir, add_c, search_path_keys

# %%
class Player:
    def __init__(self, num, name=None) -> None:
        if (name is None):
            name = f'Player_{num}'
        self.Name = name
        self.Num = num
        self.Act = 'w'
        # self.LastAct = 'w'
        self.IsDead = False
        self.NowDead = False
        self.Speed = 1
        self.Kill = 0
        self.KillList = []
        self.KilledList = []
        self.SaveLength = 0
        self.Prop = {
            'speed': 0,
            'strong': 0,
            'double': 0,
        }
        # self.del_act = None
        self.Score_len = None
        self.Score_kill = None
        self.Score_time = None
        self.Score = None
        # Addtional params
        self.move_len = 0
        self.total_len = 0
        self.remove_head = False

    def load_game_info(self, loadpath):
        game_info = load_json(loadpath)
        self.__dict__.update(game_info['gameinfo']['Player'][self.Num])

# %%
class Map:
    def __init__(self, num_players, max_time=150) -> None:
        self.Length = 55    # X
        self.Width = 40     # Y
        # TODO Snake initial positions for 4/5 players? Use random when training?
        self.SnakePosition = [[] for _ in range(num_players)]
        if (num_players == 6):
            x0 = int(self.Length / 4)
            y0 = int(self.Width / 3)
            init_pos = [
                [x0, y0], [2 * x0, y0], [3 * x0, y0],
                [x0, y0 * 2], [2 * x0, y0 * 2], [3 * x0, y0 * 2],
            ]
            init_pos = [tuple(p) for p in init_pos]
            random.shuffle(init_pos)
            for i, pos in enumerate(init_pos):
                self.SnakePosition[i] = [pos, add_c(pos, random.choice(DIRECTIONS))]

        self.SugarPosition = set()
        self.WallPosition = set()
        self.PropPosition = [set(), set(), set()]   # speed, strong, double
        self.Time = 0
        self.Score = [None for _ in range(num_players)]
        # Additional parameters
        self.max_time = max_time
        self.wall_gen_ind = 0
        self.all_grids = set([(x, y) for x in range(self.Length) for y in range(self.Width)])
    
    def gen_walls_and_props(self):
        # Generate walls
        if (self.Time % 5 == 0 and (self.Time >= 100 or self.Length * self.Width - len(self.WallPosition) - len(self.SugarPosition) > 400)):
            i = self.wall_gen_ind
            for j in range(self.Width):
                self.WallPosition.add((i, j))
                self.WallPosition.add((self.Length - 1 - i, j))
            for j in range(self.Length):
                self.WallPosition.add((j, i))
                self.WallPosition.add((j, self.Width - 1 - i))
            self.WallPosition = self.vacant_subset(self.WallPosition, wall=False)
            self.wall_gen_ind += 1
        # Generate sugars and props
        if (self.Time == 0):
            # Initial num: 200 sugar, 50/50/50 props
            sugar_num = 200
            prop_num = 50
            poss = self.__gen_uniform_poss__(sugar_num + 3 * prop_num, range_=self.vacant_subset())
            for i in range(3):
                self.PropPosition[i] = set(poss[i*prop_num:(i+1)*prop_num])
            self.SugarPosition = set(poss[3*prop_num:])
        else:
            n_sugar = 200 + self.Time
            r_sugar = 100 + min(self.Time * 10, 200)
            num = max(0, n_sugar - len(self.SugarPosition))
            poss = self.__gen_gauss_poss__(num=num, max_toss_num=r_sugar)
            self.SugarPosition = self.SugarPosition.union(poss)

            # speed, strong, double
            n_props = [60 + int(self.Time * 0.2), 40, 50]
            r_props = [10 + min(self.Time * 10, 100)] * 3
            for i in range(3):
                # speed > strong > double
                num = max(0, n_props[i] - len(self.PropPosition[i]))
                poss = self.__gen_gauss_poss__(num=num, max_toss_num=r_props[i])
                self.PropPosition[i] = self.PropPosition[i].union(poss)

        # Old version
        # if (self.Time == 1):
        #     # When time == 1, generate extra 10 speed props
        #     poss = self.__gen_gauss_poss__(10, range=self.vacant_subset())
        #     self.PropPosition[0] = self.PropPosition[0].union(poss)
        # # Sugar
        # sugar_num = random.choice([1, 1, 1, 1, 2, 2, 3, 3, 4])
        # poss = self.__gen_gauss_poss__(sugar_num)
        # poss = self.vacant_subset(poss)
        # self.SugarPosition = self.SugarPosition.union(poss)
        # # Props
        # for i in range(3):
        #     # speed > strong > double
        #     poss = self.__gen_gauss_poss__(1)
        #     poss = self.vacant_subset(poss)
        #     self.PropPosition[i] = self.PropPosition[i].union(poss)

    def __gen_gauss_poss__(self, num:int, range_:set=None, max_toss_num=2000)->list:
        mu_x = (self.Length - 1) / 2
        mu_y = (self.Width - 1) / 2
        sigma_x = 10
        sigma_y = 10
        # if not enough spaces, return all remaining spaces
        if (range_ is not None and num >= len(range_)):
            poss = list(range_)
            random.shuffle(poss)
            return poss
        poss = set()    # note: use set to avoid equal samples
        for _ in range(max_toss_num):
            if (len(poss) >= num):
                break
            pos = (int(np.round(random.gauss(mu_x, sigma_x))),
                    int(np.round(random.gauss(mu_y, sigma_y))))
            while (not self.is_valid_pos(pos) or (range_ is not None and not pos in range_)):
                pos = (int(np.round(random.gauss(mu_x, sigma_x))),
                    int(np.round(random.gauss(mu_y, sigma_y))))
            poss.add(pos)
        poss = list(poss)
        random.shuffle(poss)
        return poss

    def __gen_uniform_poss__(self, num, range_:set=None, max_toss_num=2000):
        # if not enough spaces, return all remaining spaces
        if (range_ is not None and num >= len(range_)):
            poss = list(range_)
            random.shuffle(poss)
            return poss
        poss = set()    # note: use set to avoid equal samples
        for _ in range(max_toss_num):
            if (len(poss) >= num):
                break
            # note: assuming the outside is wall, do not use in an empty map
            pos = (random.randrange(1, self.Length-1), random.randrange(1, self.Width-1))
            while (range_ is not None and not pos in range_):
                pos = (random.randrange(1, self.Length-1), random.randrange(1, self.Width-1))
            poss.add(pos)
        poss = list(poss)
        random.shuffle(poss)
        return poss

    def time_over(self):
        return self.Time >= self.max_time
    
    def is_valid_pos(self, pos):
        return (0 <= pos[0] <= self.Length - 1) and (0 <= pos[1] <= self.Width - 1)

    def is_valid_poss(self, poss):
        return np.all([self.is_valid_pos(pos) for pos in poss])
    
    def vacant_subset(self, poss=None, wall=True, sugar=True, prop=True, snake=True) -> set:
        if (poss is None):
            poss = self.all_grids
        res = poss.copy()
        if (type(res) != set):
            res = set(res)
        if (snake):
            for snake_poss in self.SnakePosition:
                res -= set(snake_poss)
        if (sugar):
            res -= self.SugarPosition
        if (wall):
            res -= self.WallPosition
        if (prop):
            for i in range(3):
                res -= self.PropPosition[i]
        return res
    
    def load_game_info(self, loadpath, as_set=True):
        game_info = load_json(loadpath)
        self.__dict__.update(game_info['gameinfo']['Map'])
        if (as_set):
            # convert data to set of tuples
            self.SugarPosition = set([tuple(pos) for pos in self.SugarPosition])
            self.WallPosition = set([tuple(pos) for pos in self.WallPosition])
            for i in range(3):
                self.PropPosition[i] = set([tuple(pos) for pos in self.PropPosition[i]])

    def print(self, wall=True, sugar=True, prop=True, snake=True, legend=True, player_names=None):
        wall_char = 'ww'
        sugar_char = '* '
        prop_chars = ['sp', 'st', 'do']   # speed, strong, double
        # prop_chars = [Fore.LIGHTBLUE_EX + c + Style.RESET_ALL for c in prop_chars]
        player_colors = [
            Fore.RED,
            Fore.GREEN,
            Fore.BLUE,
            Fore.YELLOW,
            Fore.CYAN,
            Fore.MAGENTA,
        ]
        snake_head_chars = [player_colors[i]+'@@'+Style.RESET_ALL for i in range(len(self.SnakePosition))]
        snake_body_chars = [player_colors[i]+'OO'+Style.RESET_ALL for i in range(len(self.SnakePosition))]

        board = [['  ' for i in range(self.Width)] for j in range(self.Length)]
        if (wall):
            for pos in self.WallPosition:
                # # Ignore the outer walls
                # if (not self.is_valid_pos(pos)):
                #     continue
                # if (board[pos[0]][pos[1]] != '  '):
                #     print(f'Warning: conflict on {pos[0]}{pos[1]}')
                board[pos[0]][pos[1]] = wall_char
        if (sugar):
            for pos in self.SugarPosition:
                board[pos[0]][pos[1]] = sugar_char
        if (prop):
            for i in range(3):
                for pos in self.PropPosition[i]:
                    board[pos[0]][pos[1]] = prop_chars[i]
        if (snake):
            for i, positions in enumerate(self.SnakePosition):
                if (len(positions) == 0):
                    continue
                pos = positions[0]
                board[pos[0]][pos[1]] = snake_head_chars[i]
                for pos in positions[1:]:
                    board[pos[0]][pos[1]] = snake_body_chars[i]
        board = np.transpose(board)

        if (legend):
            if (player_names is None):
                player_names = [f'Player_{i}' for i in range(len(self.SnakePosition))]
            print('  '.join([player_names[i] + ':' + player_colors[i]+'O'+Style.RESET_ALL for i in range(len(self.SnakePosition))]))
        print('\n'.join(reversed([''.join(row) for row in board])))

# %%
class SnakeGame:
    def __init__(self, player_num:int=None, AIs:list=None) -> None:
        self.reset(player_num=player_num, AIs=AIs)

    def reset(self, player_num:int=None, AIs:list=None):
        assert AIs is not None or player_num is not None
        if (AIs is not None and player_num is not None):
            assert player_num == len(AIs)
        if (player_num is None):
            self.player_num = len(AIs)
        else:
            self.player_num = player_num
        self.AIs = AIs
        self.players = [Player(i) for i in range(self.player_num)]
        self.map = Map(self.player_num)
        self.map.gen_walls_and_props()
        self.__calc_scores__()
        # [20220521]
        self.game_info_history = []

    def get_game_info(self, to_list=True):
        game_info = dict()
        game_info['Player'] = []
        for p in self.players:
            tmp = copy(p.__dict__)
            # tmp = deepcopy(p.__dict__)
            tmp.pop('move_len')
            tmp.pop('total_len')
            tmp.pop('remove_head')
            game_info['Player'].append(tmp)
        game_info['Map'] = copy(self.map.__dict__)
        game_info['Map'].pop('all_grids')
        if (to_list):
            game_info['Map']['WallPosition'] = list(self.map.WallPosition)
            game_info['Map']['SugarPosition'] = list(self.map.SugarPosition)
            game_info['Map']['PropPosition'] = []
            for i in range(3):
                game_info['Map']['PropPosition'].append(list(self.map.PropPosition[i]))

        res = dict()
        res['gameinfo'] = game_info
        res['tableinfo'] = None
        if (to_list):
            save_json(res, 'game_info_tmp.json')
            res = load_json('game_info_tmp.json')
        return res

    def load_game_info(self, game_info_path):
        game_info = load_json(game_info_path)
        self.reset(player_num=len(game_info['gameinfo']['Player']))
        self.map.load_game_info(game_info_path)
        for i in range(self.player_num):
            self.players[i].load_game_info(game_info_path)

    def print(self, cls=True):
        if (cls):
            os.system('cls')
        print(f'Round {self.map.Time}')
        print('Speed:', [player.Speed for player in self.players])
        print('Prop speed:', [player.Prop['speed'] for player in self.players])
        print('Prop strong:', [player.Prop['strong'] for player in self.players])
        print('Prop double:', [player.Prop['double'] for player in self.players])
        self.map.print(player_names=[self.players[i].Name for i in range(self.player_num)])

    def run_till_end(self, time_sleep=0.0, savedir=None, print=True):
        # Run a whole game
        if (savedir is not None):
            create_folder(savedir)
        def print_and_save():
            if (print):
                self.print()
            if (savedir is not None):
                save_json(
                    self.get_game_info(to_list=True),
                    os.path.join(savedir, 'game_info_round_%3d.json' % (self.map.Time))
                )
    
        print_and_save()
        sleep(time_sleep)
        while (self.move_one_round()):
            print_and_save()
            sleep(time_sleep)
        print_and_save()

    def move_one_round(self, AIs=None, acts=None) -> bool:
        # Return true if game is not ended
        if (acts is None):
            if (AIs is None):
                AIs = self.AIs
            game_info = self.get_game_info(to_list=False)
            self.game_info_history.append(game_info)
            # start_time = time()
            acts = self.__ask_for_acts__()
            # global time_elapsed
            # time_elapsed += (time() - start_time)
        self.__move_players__(acts)
        self.__collide__()
        self.__get_props__()
        self.__update_time__()
        self.__calc_scores__()
        self.__confirm_new_snakes__()
        self.map.gen_walls_and_props()

        # for i, AI in enumerate(AIs):
        #     if (AI.__name__ == 'AI_reversing'):
        #         self.players[i].Prop['strong'] = 1000

        if (self.__check_all_dead__()):
            return False
        if (self.map.time_over()):
            self.__kill_all__()
            return False
        return True
    
    def __ask_for_acts__(self):
        acts = []
        for i, AI in enumerate(self.AIs):
            acts.append(AI(i, self.game_info_history))
            # acts.append(AI(i, game_info))
        # with Pool(processes=8) as pool:
        #     acts = pool.starmap(get_act, list(range(self.player_num)))
        return acts
    
    def __move_players__(self, acts):
        # if act is None, use last act
        for i, act in enumerate(acts):
            if (act is None):
                act = self.players[i].Act
        for i in range(self.player_num):
            # Ignore previously dead snakes
            if (self.players[i].IsDead):
                continue
            self.players[i].move_len = 0
            self.players[i].total_len = len(self.map.SnakePosition[i])
            # Can move up to 'speed' times
            max_step = self.players[i].Speed
            act = acts[i]
            # if (act is None):
            #     print(self.get_game_info(to_list=True))
            act = act[:max_step]
            for key in act:
                dir = key2dir(key)
                assert dir is not None
                self.map.SnakePosition[i].insert(0, add_c(self.map.SnakePosition[i][0], dir))
                self.players[i].move_len += 1
            # Growth of snake
            use_save_len = min(self.players[i].SaveLength, self.players[i].move_len)
            self.players[i].SaveLength -= use_save_len
            for _ in range(self.players[i].move_len - use_save_len):
                self.map.SnakePosition[i].pop()
        # Set last_Act
        for i in range(self.player_num):
            self.players[i].Act = acts[i]
    
    def __collide__(self):
        # # Initialize now_dead
        # for i in range(self.player_num):
        #     self.players[i].now_dead = self.players[i].is_dead
        head_poss = []
        body_poss = []
        is_strong = []
        for i in range(self.player_num):
            self.players[i].KillList = []
            positions = self.map.SnakePosition[i]
            move_len = self.players[i].move_len
            total_len = self.players[i].total_len
            # still ok if move_len > total_len
            head_poss.append(set(positions[:move_len]))
            body_poss.append(set(positions[move_len:total_len]))
            is_strong.append(self.players[i].Prop['strong'] > 0)

        for i in range(self.player_num):
            # Ignore previously dead snakes
            if (self.players[i].IsDead):
                continue
            # Collide with walls
            if (not self.map.is_valid_poss(head_poss[i]) or not head_poss[i].isdisjoint(self.map.WallPosition)):
                self.players[i].NowDead = True
            # Collide with self
            if (not head_poss[i].isdisjoint(body_poss[i])):
                if (is_strong[i]):
                    self.players[i].remove_head = True
                else:
                    self.players[i].NowDead = True
            # Collide with others
            for j in range(i+1, self.player_num):
                collide_h2h = not head_poss[i].isdisjoint(head_poss[j])
                collide_h2b = not head_poss[i].isdisjoint(body_poss[j])
                collide_b2h = not body_poss[i].isdisjoint(head_poss[j])
                if (collide_h2h):
                    # [20220520] Rearranged collision logic
                    if (is_strong[i] and not is_strong[j]):
                        self.__on_kill__(i, j, True)
                    if (not is_strong[i] and is_strong[j]):
                        self.__on_kill__(j, i, True)
                    if (is_strong[i] and is_strong[j]):
                        self.players[i].remove_head = True
                        self.players[j].remove_head = True
                    # If both weak
                    if (not is_strong[i] and not is_strong[j]):
                        if (self.players[i].total_len > self.players[j].total_len):
                            self.__on_kill__(i, j, True)
                        elif (self.players[i].total_len < self.players[j].total_len):
                            self.__on_kill__(j, i, True)
                        else:
                            self.players[i].NowDead = True
                            self.players[j].NowDead = True
                else:
                    if (collide_h2b):
                        if (is_strong[i]):
                            self.players[i].remove_head = True
                        else:
                            self.__on_kill__(j, i, False)
                    if (collide_b2h):
                        if (is_strong[j]):
                            self.players[j].remove_head = True
                        else:
                            self.__on_kill__(i, j, False)

        # Realize remove head
        for i in range(self.player_num):
            if (self.players[i].remove_head):
                self.__remove_head__(i)

    def __on_kill__(self, killer: int, killed: int, active_kill: bool):
        self.players[killed].NowDead = True
        self.players[killed].KilledList.append(killer)
        self.players[killer].KillList.append(killed)
        if (active_kill):
            self.players[killer].Kill += 2
        else:
            self.players[killer].Kill += 1

    def __remove_head__(self, player_ind):
        player = self.players[player_ind]
        move_len = player.move_len
        self.map.SnakePosition[player_ind] = self.map.SnakePosition[player_ind][move_len:]
        player.total_len -= move_len
        player.total_len = max(player.total_len, 0)
        if (player.total_len < 1):
            player.NowDead = True
        # player.head_len = 0
        player.remove_head = False
    
    def __update_time__(self):
        self.map.Time += 1
        for player in self.players:
            player.Prop['speed'] = max(0, player.Prop['speed'] - 1)
            if (player.Prop['speed'] == 0):
                player.Speed = 1
            player.Prop['strong'] = max(0, player.Prop['strong'] - 1)
            player.Prop['double'] = max(0, player.Prop['double'] - 1)

    def __get_props__(self):
        for i in range(self.player_num):
            if (self.players[i].NowDead):
                continue
            valid_poss_set = set(self.map.SnakePosition[i][:self.players[i].total_len])
            if (self.players[i].Prop['double'] > 0):
                increment = 2
            else:
                increment = 1
            for pos in valid_poss_set & self.map.SugarPosition:
                self.map.SugarPosition.remove(pos)
                self.players[i].SaveLength += increment
            for pos in valid_poss_set & self.map.PropPosition[0]:
                self.map.PropPosition[0].remove(pos)
                self.players[i].Speed += 1
                self.players[i].Prop['speed'] += 5
            for pos in valid_poss_set & self.map.PropPosition[1]:
                self.map.PropPosition[1].remove(pos)
                self.players[i].Prop['strong'] += 5
            for pos in valid_poss_set & self.map.PropPosition[2]:
                self.map.PropPosition[2].remove(pos)
                self.players[i].Prop['double'] += 5

    def __confirm_new_snakes__(self):
        # Execute death and growth
        for i in range(self.player_num):
            if (self.players[i].IsDead):
                continue
            # Death of snakes
            if (self.players[i].NowDead):
                self.__on_die__(i)
                self.players[i].IsDead = self.players[i].NowDead
                continue

    def __on_die__(self, i):
        if (len(self.map.SnakePosition[i]) == 0):
            return
        valid_poss_set = self.map.SnakePosition[i][:self.players[i].total_len]
        valid_poss_set = set([pos for pos in valid_poss_set if self.map.is_valid_pos(pos)])
        self.map.SnakePosition[i].clear()
        for pos in self.map.vacant_subset(valid_poss_set):
            self.map.SugarPosition.add(pos)

    def __calc_scores__(self):
        for i in range(self.player_num):
            if (not self.players[i].IsDead):
                self.players[i].Score_kill = self.players[i].Kill
                self.players[i].Score_time = self.map.Time + 1
                self.players[i].Score_len = len(self.map.SnakePosition[i])
        
        scores = [0 for _ in range(self.player_num)]
        scores += 1.5 * rankdata([self.players[i].Score_kill for i in range(self.player_num)])
        scores += rankdata([self.players[i].Score_time for i in range(self.player_num)])
        scores += rankdata([self.players[i].Score_len for i in range(self.player_num)])
        scores /= 3.5

        self.map.Score = list(scores)
        for i in range(self.player_num):
            self.players[i].Score = scores[i]

    def __check_all_dead__(self):
        return np.all([player.IsDead for player in self.players])

    def __kill_all__(self):
        for i in range(self.player_num):
            if (not self.players[i].IsDead):
                self.players[i].IsDead = True
                self.__on_die__(i)

# %%
if __name__ ==  '__main__':
    pass
    # # Print map from gameinfo received
    # m = Map(6)
    # m.load_game_info(r'D:\zzx\Desktop\tmp\GameInfo_9096_10.json')
    # m.print()

    # # Print walls and props
    # m = Map(6)
    # filelist = os.listdir('game_info_sample/')
    # for file in filelist:
    #     m.load_game_info(os.path.join('game_info_sample', file))
    #     os.system('cls')
    #     print(f'Round: {m.Time}')
    #     m.print(wall=True, sugar=False, prop=True, snake=False)
    #     sleep(1.0)

    # # Inspect generation of props and sugars
    # # input_dir = 'game_info_sample/'
    # # input_dir = 'game_info_sample_20220402/'
    # # input_dir = r'D:\zzx\Desktop\tmp\game_info_sample_20220404_1'
    # input_dir = 'game_info_test/'
    # m = Map(6)
    # filelist = sorted(os.listdir(input_dir))
    # pre_props = [set(), set(), set()]
    # pre_sugars = set()
    # diffs = []
    # for file in filelist:
    #     m.load_game_info(os.path.join(input_dir, file))
    #     props = m.PropPosition
    #     sugars = m.SugarPosition
    #     # if (pre_props is not None):
    #     diff = [0, 0, 0, 0]
    #     for i in range(3):
    #         diff[i] = len(props[i] - pre_props[i])
    #     diff[3] = len(sugars - pre_sugars)
    #     diffs.append(diff)
    #     print(f'Round {m.Time}, diff = {str(diff)}, diff_sum = {str(np.sum(diffs, axis=0))}')
    #     pre_props = props
    #     pre_sugars = sugars
    # diff_sum = np.sum(diffs[1:], axis=0)
    # diff_sum[3] -= np.sum(np.sort(np.array(diffs)[1:, 3])[-6:])
    # print(f'diff_sum = {str(diff_sum)}')
    
    # # Print whole game info
    # # input_dir = r'D:\zzx\Desktop\tmp\game_info_9328'
    # input_dir = r'D:\zzx\Programming\vsCode\JiukunSnake\game_info_test'
    # game = SnakeGame(player_num=6)
    # filelist = sorted(os.listdir(input_dir))
    # # print(filelist)
    # for i, file in enumerate(filelist):
    #     game.load_game_info(os.path.join(input_dir, file))
    #     game.print()
    #     sleep(0.5)

# %%
# if __name__ ==  '__main__':
#     # Inspect specific round
#     # game_info_path = r'D:\zzx\Desktop\tmp\game_info_9328\GameInfo_9328_040.json'
#     game_info_path = r'D:\zzx\Programming\vsCode\JiukunSnake\game_info_test\game_info_round_ 40.json'
#     game = SnakeGame(player_num=6)
#     game.load_game_info(game_info_path)
#     game.print()
#     # print(AI_greedy_1(0, load_json(game_info_path), debug=True))
#     # print(AI_wyg(0, load_json(game_info_path), debug=True))
#     # print(search_path_keys((20, 10), (32, 34), game.map.WallPosition))

#     # # Test AI time usage
#     # game_info = load_json(r'D:\zzx\Programming\vsCode\JiukunSnake\game_info_test\game_info_round_  0.json')
#     # time_start = time()
#     # AI_greedy_0(0, game_info, debug=False)
#     # print(time() - time_start)

# %%
if __name__ ==  '__main__':
    # random.seed(6000)
    scores = []
    scores_kill = []
    scores_len = []
    scores_time = []
    for i in range(400):
        random.seed(1000 * (i+1))
        print('Game', i)
        time_elapsed = 0
        time_start = time()
        # game = SnakeGame(AIs=[AI_greedy_0 for _ in range(1)] + [AI0_rand for _ in range(5)])
        # game = SnakeGame(AIs=[AI0_rand for _ in range(6)])
        # game = SnakeGame(AIs=[AI_20220520 for _ in range(6)])
        game = SnakeGame(AIs=[AI_20220520 for _ in range(3)] + [AI_20220520_early for _ in range(3)])
        # game.run_till_end(savedir='game_info_test', print=True, time_sleep=0.5)
        # game.run_till_end(print=True, time_sleep=0.5)
        game.run_till_end(print=False)
        time_total = time() - time_start
        print('Total time:', time_total)
        print('Part time:', time_elapsed)
        print(time_elapsed / time_total)
        print(game.map.Time)
        print([game.players[i].Score for i in range(6)])
        print([game.players[i].Score_kill for i in range(6)])
        print([game.players[i].Score_len for i in range(6)])
        print([game.players[i].Score_time for i in range(6)])
        print(np.mean([game.players[i].Score for i in range(3)]))
        scores.append([game.players[i].Score for i in range(6)])
        scores_kill.append([game.players[i].Score_kill for i in range(6)])
        scores_len.append([game.players[i].Score_len for i in range(6)])
        scores_time.append([game.players[i].Score_time for i in range(6)])
    print(np.mean(scores, axis=0))
    print('Average Score_kill =', np.mean(scores_kill, axis=0))
    print('Average Score_len =', np.mean(scores_len, axis=0))
    print('Average Score_time =', np.mean(scores_time, axis=0))
    print(np.mean(np.mean(scores, axis=0)[:3]))
# Out:
# Game 0
# Round 77, Num_ = 1, kill_keys = aaaaaaaaaaaaaawassd, kill_plans_score[res] = -0.4222222222222222
# Total time: 2.682891368865967
# Part time: 0
# 0.0
# 98
# [3.357142857142857, 4.214285714285714, 4.785714285714286, 1.2142857142857142, 2.0714285714285716, 5.357142857142857]
# [2, 2, 2, 0, 0, 2]
# [25, 29, 33, 5, 12, 40]
# [22, 84, 98, 13, 79, 99]
# 4.1190476190476195
# Game 1
# Round 18, Num_ = 1, kill_keys = dwdwdwwdwdssa, kill_plans_score[res] = -0.43333333333333335
# Round 27, Num_ = 2, kill_keys = wddwwwdddddwdssa, kill_plans_score[res] = 0.0
# Round 48, Num_ = 1, kill_keys = ddddddddwdssa, kill_plans_score[res] = -0.11607142857142858
# Round 76, Num_ = 2, kill_keys = aaaawwaaaaaaaaawassd, kill_plans_score[res] = 0.0
# Total time: 2.5297446250915527
# Part time: 0
# 0.0
# 96
# [1.9285714285714286, 4.928571428571429, 4.928571428571429, 3.0714285714285716, 3.9285714285714284, 2.2142857142857144]
# [0, 4, 4, 0, 0, 0]
# [14, 41, 39, 57, 72, 2]
# [20, 78, 97, 29, 50, 40]
# 3.928571428571429
# Game 2
# Round 64, Num_ = 0, kill_keys = wwwwwwwaaaawassd, kill_plans_score[res] = 0.0
# Round 67, Num_ = 0, kill_keys = dddwwddddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.289083480834961
# Part time: 0
# 0.0
# 79
# [5.785714285714286, 1.9285714285714286, 1.9285714285714286, 3.642857142857143, 4.071428571428571, 3.642857142857143]
# [4, 0, 0, 0, 4, 0]
# [61, 14, 10, 30, 29, 51]
# [80, 12, 16, 69, 64, 66]
# 3.214285714285714
# Game 3
# Total time: 3.5089964866638184
# Part time: 0
# 0.0
# 150
# [2.5, 2.7857142857142856, 2.5, 4.214285714285714, 3.5, 5.5]
# [0, 0, 0, 0, 2, 2]
# [5, 1, 6, 36, 0, 48]
# [90, 107, 19, 151, 99, 116]
# 2.5952380952380953
# Game 4
# Round 50, Num_ = 0, kill_keys = dwddddwwwdddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 1.3582806587219238
# Part time: 0
# 0.0
# 52
# [5.785714285714286, 2.0, 5.214285714285714, 2.857142857142857, 2.0, 3.142857142857143]
# [4, 0, 4, 0, 0, 2]
# [100, 7, 65, 30, 5, 0]
# [53, 13, 52, 27, 15, 28]
# 4.333333333333333
# Game 5
# Round 20, Num_ = 1, kill_keys = waaaawddwa, kill_plans_score[res] = -0.5882352941176471
# Round 22, Num_ = 2, kill_keys = sdwdssa, kill_plans_score[res] = -0.18421052631578946
# Total time: 1.8773889541625977
# Part time: 0
# 0.0
# 80
# [2.0, 3.2142857142857144, 4.5, 1.8571428571428572, 3.4285714285714284, 6.0]
# [0, 2, 2, 0, 0, 6]
# [27, 21, 30, 9, 53, 60]
# [22, 24, 72, 24, 32, 81]
# 3.2380952380952386
# Game 6
# Round 11, Num_ = 1, kill_keys = wwwawassd, kill_plans_score[res] = 0.0
# Round 20, Num_ = 1, kill_keys = aaaawassd, kill_plans_score[res] = -0.2647058823529412
# Total time: 2.166165828704834
# Part time: 0
# 0.0
# 100
# [3.642857142857143, 4.714285714285714, 2.5, 1.7857142857142858, 2.357142857142857, 6.0]
# [0, 4, 0, 0, 0, 6]
# [34, 48, 6, 5, 5, 57]
# [79, 69, 13, 12, 22, 101]
# 3.619047619047619
# Game 7
# Round 44, Num_ = 1, kill_keys = sssssssssssaaawassd, kill_plans_score[res] = -0.5757575757575758
# Round 52, Num_ = 1, kill_keys = sdddsssdsddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.536910057067871
# Part time: 0
# 0.0
# 107
# [3.642857142857143, 4.428571428571429, 2.2142857142857144, 1.6428571428571428, 3.642857142857143, 5.428571428571429]
# [0, 6, 0, 0, 0, 8]
# [74, 33, 11, 8, 56, 53]
# [46, 86, 20, 16, 54, 108]
# 3.4285714285714284
# Game 8
# Round 62, Num_ = 0, kill_keys = ddddddddddsdddddwdssa, kill_plans_score[res] = 0.0
# Round 66, Num_ = 0, kill_keys = sssaaaaaaawassd, kill_plans_score[res] = 0.0
# Total time: 1.9234671592712402
# Part time: 0
# 0.0
# 74
# [5.571428571428571, 2.5714285714285716, 1.8571428571428572, 4.285714285714286, 1.5714285714285714, 5.142857142857143]
# [4, 0, 0, 2, 0, 6]
# [67, 23, 6, 61, 4, 30]
# [75, 20, 14, 64, 14, 68]
# 3.3333333333333335
# Game 9
# Total time: 2.661010503768921
# Part time: 0
# 0.0
# 147
# [3.2142857142857144, 3.357142857142857, 2.9285714285714284, 1.9285714285714286, 4.571428571428571, 5.0]
# [0, 0, 0, 0, 6, 4]
# [19, 53, 16, 10, 6, 48]
# [65, 36, 65, 17, 148, 111]
# 3.1666666666666665
# Game 10
# Round 11, Num_ = 1, kill_keys = ssdsaasd, kill_plans_score[res] = 0.0
# Round 23, Num_ = 1, kill_keys = dsssdwdssa, kill_plans_score[res] = -0.43478260869565216
# Round 23, Num_ = 2, kill_keys = wwwwwaaawassd, kill_plans_score[res] = -0.23636363636363636
# Round 73, Num_ = 0, kill_keys = wddddwdssa, kill_plans_score[res] = -0.25
# Round 73, Num_ = 1, kill_keys = wwwaaaaaaaaawassd, kill_plans_score[res] = -0.5862068965517241
# Round 73, Num_ = 2, kill_keys = wdwaawd, kill_plans_score[res] = 0.0
# Round 81, Num_ = 2, kill_keys = dddddwddddddwwwwddwa, kill_plans_score[res] = -0.39215686274509803
# Total time: 2.6651670932769775
# Part time: 0
# 0.0
# 94
# [4.0, 4.428571428571429, 5.714285714285714, 2.0, 3.4285714285714284, 1.4285714285714286]
# [2, 6, 8, 0, 0, 0]
# [36, 26, 51, 6, 57, 4]
# [79, 83, 95, 25, 75, 13]
# 4.714285714285714
# Game 11
# Round 53, Num_ = 0, kill_keys = aawwwwwaawwwawawwwwaawassd, kill_plans_score[res] = -0.5306122448979592
# Round 53, Num_ = 2, kill_keys = ssddddddddwdssa, kill_plans_score[res] = -0.18518518518518517
# Round 79, Num_ = 2, kill_keys = wwaaaaaaaaawaawwwawwaa, kill_plans_score[res] = -0.5641025641025641
# Total time: 3.1102707386016846
# Part time: 0
# 0.0
# 127
# [4.0, 1.4285714285714286, 5.214285714285714, 2.7142857142857144, 5.214285714285714, 2.4285714285714284]
# [2, 0, 4, 0, 4, 0]
# [23, 7, 59, 40, 82, 38]
# [128, 12, 98, 55, 81, 55]
# 3.5476190476190474
# Game 12
# Round 11, Num_ = 2, kill_keys = sssaawassd, kill_plans_score[res] = 0.0
# Round 21, Num_ = 0, kill_keys = wwwdddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.1152703762054443
# Part time: 0
# 0.0
# 106
# [4.428571428571429, 1.2142857142857142, 3.2142857142857144, 5.714285714285714, 1.7857142857142858, 4.642857142857143]
# [4, 0, 2, 6, 0, 2]
# [63, 10, 30, 156, 13, 206]
# [38, 13, 23, 107, 16, 71]
# 2.9523809523809526
# Game 13
# Total time: 0.8872451782226562
# Part time: 0
# 0.0
# 40
# [2.0, 2.2857142857142856, 4.785714285714286, 2.857142857142857, 3.0714285714285716, 6.0]
# [0, 0, 2, 0, 2, 4]
# [6, 8, 27, 7, 0, 84]
# [15, 12, 25, 22, 21, 41]
# 3.0238095238095237
# Game 14
# Round 37, Num_ = 1, kill_keys = wwdddddwdssa, kill_plans_score[res] = 0.0
# Total time: 1.8941020965576172
# Part time: 0
# 0.0
# 112
# [2.2857142857142856, 5.714285714285714, 1.7142857142857142, 4.5, 4.785714285714286, 2.0]
# [0, 6, 0, 2, 2, 0]
# [28, 102, 14, 68, 58, 7]
# [21, 49, 14, 39, 113, 28]
# 3.2380952380952377
# Game 15
# Round 41, Num_ = 0, kill_keys = wdwwwdwwwwdwdssa, kill_plans_score[res] = -0.32
# Round 41, Num_ = 1, kill_keys = dddwwwwwdddddwwddwwddwdssa, kill_plans_score[res] = -0.3611111111111111
# Round 41, Num_ = 2, kill_keys = wwwwwwwwwwwwwdwaawd, kill_plans_score[res] = -0.7307692307692307
# Round 63, Num_ = 0, kill_keys = wdwdddddddddddddwdssa, kill_plans_score[res] = -0.328125
# Round 63, Num_ = 1, kill_keys = wwwddwdssa, kill_plans_score[res] = -0.2222222222222222
# Round 63, Num_ = 2, kill_keys = dddddddddwwwddwwdddwdssa, kill_plans_score[res] = -0.3870967741935484
# Round 84, Num_ = 1, kill_keys = awwwwaaawaaaawassd, kill_plans_score[res] = -0.4864864864864865
# Round 84, Num_ = 2, kill_keys = dwwwwwwdddddddddddwdssa, kill_plans_score[res] = 0.0
# Round 93, Num_ = 2, kill_keys = sssssaaawassd, kill_plans_score[res] = 0.0
# Total time: 2.88191294670105
# Part time: 0
# 0.0
# 99
# [4.0, 5.0, 6.0, 1.7857142857142858, 3.0, 1.2142857142857142]
# [4, 6, 8, 0, 2, 0]
# [42, 44, 48, 4, 23, 0]
# [86, 95, 100, 43, 65, 13]
# 5.0
# Game 16
# Round 19, Num_ = 0, kill_keys = ddwdssa, kill_plans_score[res] = -0.25
# Round 38, Num_ = 1, kill_keys = aaaaawassd, kill_plans_score[res] = -0.16393442622950818
# Round 69, Num_ = 1, kill_keys = dddddddddddssdddwdssa, kill_plans_score[res] = -0.5675675675675675
# Total time: 2.600876808166504
# Part time: 0
# 0.0
# 91
# [4.214285714285714, 6.0, 2.0, 3.142857142857143, 4.214285714285714, 1.4285714285714286]
# [2, 6, 0, 0, 2, 0]
# [58, 78, 26, 72, 39, 12]
# [71, 92, 24, 40, 83, 21]
# 4.071428571428572
# Game 17
# Round 57, Num_ = 1, kill_keys = sdddssdddwdssa, kill_plans_score[res] = -0.208955223880597
# Round 100, Num_ = 1, kill_keys = wwwddddwwwwddwwawwdwdss, kill_plans_score[res] = -0.8214285714285714
# Total time: 3.4462313652038574
# Part time: 0
# 0.0
# 125
# [3.357142857142857, 4.571428571428571, 1.6428571428571428, 5.571428571428571, 3.2142857142857144, 2.642857142857143]
# [0, 4, 0, 2, 0, 0]
# [30, 14, 4, 41, 40, 16]
# [102, 125, 40, 126, 59, 59]
# 3.1904761904761902
# Game 18
# Round 50, Num_ = 0, kill_keys = ssssssassssdsaasd, kill_plans_score[res] = -0.09392265193370165
# Round 50, Num_ = 1, kill_keys = sssssaawassd, kill_plans_score[res] = -0.3157894736842105
# Round 82, Num_ = 0, kill_keys = aaaaaaaawassd, kill_plans_score[res] = -0.24074074074074073
# Round 84, Num_ = 0, kill_keys = ssssssaasd, kill_plans_score[res] = -0.24390243902439024
# Total time: 2.3216025829315186
# Part time: 0
# 0.0
# 87
# [6.0, 4.5, 1.4285714285714286, 2.0, 4.5, 2.5714285714285716]
# [6, 2, 0, 0, 2, 0]
# [31, 25, 0, 7, 27, 8]
# [88, 86, 14, 23, 84, 52]
# 3.9761904761904763
# Game 19
# Round 23, Num_ = 0, kill_keys = dddwdssa, kill_plans_score[res] = -0.16
# Total time: 1.4052977561950684
# Part time: 0
# 0.0
# 65
# [5.357142857142857, 4.5, 1.7142857142857142, 2.857142857142857, 4.285714285714286, 2.2857142857142856]
# [2, 2, 0, 0, 4, 0]
# [106, 53, 5, 8, 0, 6]
# [66, 25, 9, 14, 64, 10]
# 3.857142857142857
# Game 20
# Total time: 2.496145725250244
# Part time: 0
# 0.0
# 149
# [2.7142857142857144, 3.0, 4.428571428571429, 5.714285714285714, 2.7142857142857144, 2.4285714285714284]
# [0, 0, 0, 6, 0, 0]
# [16, 9, 37, 26, 11, 3]
# [14, 100, 105, 150, 19, 28]
# 3.380952380952381
# Game 21
# Round 43, Num_ = 1, kill_keys = dsdddddddddddwdssa, kill_plans_score[res] = 0.0
# Round 49, Num_ = 1, kill_keys = ddddwdddddddddddddwdwaawd, kill_plans_score[res] = -0.2
# Round 60, Num_ = 1, kill_keys = ssssasaassaaaasaaaaawassd, kill_plans_score[res] = 0.0
# Round 77, Num_ = 1, kill_keys = waaaaaawaaaawassd, kill_plans_score[res] = -0.18681318681318682
# Total time: 2.586444854736328
# Part time: 0
# 0.0
# 83
# [1.4285714285714286, 6.0, 3.642857142857143, 2.5714285714285716, 3.4285714285714284, 3.9285714285714284]
# [0, 8, 2, 0, 0, 2]
# [3, 71, 32, 40, 47, 30]
# [14, 84, 51, 45, 62, 79]
# 3.6904761904761902
# Game 22
# Round 43, Num_ = 2, kill_keys = wwwwwwwwwdwdssa, kill_plans_score[res] = 0.0
# Round 61, Num_ = 2, kill_keys = sasssaaaaaaaawassd, kill_plans_score[res] = -0.9
# Total time: 2.8683152198791504
# Part time: 0
# 0.0
# 100
# [1.2142857142857142, 1.7857142857142858, 5.214285714285714, 3.2142857142857144, 5.785714285714286, 3.7857142857142856]
# [0, 0, 4, 2, 4, 2]
# [7, 11, 47, 26, 57, 30]
# [9, 36, 90, 45, 101, 63]
# 2.7380952380952386
# Game 23
# Round 20, Num_ = 0, kill_keys = ssssssdsaasd, kill_plans_score[res] = -0.2608695652173913
# Round 60, Num_ = 2, kill_keys = wdwaawd, kill_plans_score[res] = -0.12962962962962962
# Total time: 3.0700907707214355
# Part time: 0
# 0.0
# 129
# [4.214285714285714, 2.857142857142857, 4.785714285714286, 1.7142857142857142, 5.428571428571429, 2.0]
# [2, 0, 2, 0, 4, 0]
# [129, 28, 104, 11, 56, 0]
# [62, 76, 83, 22, 130, 64]
# 3.9523809523809526
# Game 24
# Round 23, Num_ = 0, kill_keys = waaaawassd, kill_plans_score[res] = 0.0
# Round 24, Num_ = 0, kill_keys = wwwawassd, kill_plans_score[res] = -0.23076923076923078
# Round 74, Num_ = 0, kill_keys = dssssssdsaa, kill_plans_score[res] = 0.0
# Round 74, Num_ = 1, kill_keys = dddddsssssssssdsaa, kill_plans_score[res] = -0.1956521739130435
# Round 79, Num_ = 1, kill_keys = sssssssssdsdddddddwddsas, kill_plans_score[res] = -0.8275862068965517
# Total time: 2.3637819290161133
# Part time: 0
# 0.0
# 150
# [5.571428571428571, 4.428571428571429, 3.7857142857142856, 2.5, 2.5, 2.2142857142857144]
# [8, 4, 0, 0, 0, 0]
# [28, 8, 28, 11, 18, 7]
# [81, 151, 76, 25, 18, 26]
# 4.595238095238095
# Game 25
# Total time: 2.5386195182800293
# Part time: 0
# 0.0
# 88
# [3.357142857142857, 4.428571428571429, 1.6428571428571428, 2.5, 5.714285714285714, 3.357142857142857]
# [0, 2, 0, 0, 6, 0]
# [50, 57, 4, 41, 59, 67]
# [74, 67, 11, 59, 89, 37]
# 3.142857142857143
# Game 26
# Round 85, Num_ = 0, kill_keys = dssssddddwdddddddddddddddddddwdssa, kill_plans_score[res] = -0.9444444444444444
# Total time: 2.9839115142822266
# Part time: 0
# 0.0
# 150
# [5.214285714285714, 1.7857142857142858, 3.642857142857143, 2.357142857142857, 5.214285714285714, 2.7857142857142856]
# [2, 0, 0, 0, 2, 0]
# [48, 0, 2, 0, 76, 12]
# [119, 8, 151, 63, 87, 13]
# 3.5476190476190474
# Game 27
# Round 15, Num_ = 1, kill_keys = wdwdssa, kill_plans_score[res] = -0.4666666666666667
# Round 27, Num_ = 1, kill_keys = ssdwdssa, kill_plans_score[res] = 0.0
# Round 30, Num_ = 1, kill_keys = ssdwdssa, kill_plans_score[res] = 0.0
# Total time: 0.8738486766815186
# Part time: 0
# 0.0
# 34
# [3.9285714285714284, 6.0, 1.5714285714285714, 3.142857142857143, 1.8571428571428572, 4.5]
# [2, 6, 0, 0, 0, 2]
# [14, 80, 5, 13, 5, 21]
# [17, 35, 11, 32, 13, 29]
# 3.8333333333333335
# Game 28
# Round 42, Num_ = 1, kill_keys = dwwwdww, kill_plans_score[res] = -0.20588235294117646
# Total time: 3.1942965984344482
# Part time: 0
# 0.0
# 138
# [3.7857142857142856, 4.071428571428571, 1.5, 1.5, 4.428571428571429, 5.714285714285714]
# [2, 2, 0, 0, 4, 6]
# [17, 55, 8, 6, 39, 48]
# [121, 73, 12, 44, 94, 139]
# 3.119047619047619
# Game 29
# Round 39, Num_ = 2, kill_keys = sssdsaasd, kill_plans_score[res] = -0.36
# Round 44, Num_ = 2, kill_keys = ssssdddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.2599310874938965
# Part time: 0
# 0.0
# 69
# [2.7857142857142856, 2.7857142857142856, 3.857142857142857, 3.9285714285714284, 6.0, 1.6428571428571428]
# [0, 0, 4, 0, 6, 0]
# [72, 56, 54, 110, 116, 9]
# [41, 46, 50, 62, 70, 15]
# 3.142857142857143
# Game 30
# Round 65, Num_ = 1, kill_keys = wddwdddwwwddwaw, kill_plans_score[res] = -0.16666666666666666
# Round 65, Num_ = 2, kill_keys = wwdddddwddddwddddwwwddwaw, kill_plans_score[res] = -0.4716981132075472
# Round 87, Num_ = 2, kill_keys = sdddsdssddddddwdssa, kill_plans_score[res] = -0.59375
# Total time: 2.879422903060913
# Part time: 0
# 0.0
# 130
# [1.7142857142857142, 4.714285714285714, 5.5, 3.9285714285714284, 2.5714285714285716, 2.5714285714285716]
# [0, 2, 6, 6, 0, 0]
# [7, 93, 49, 2, 15, 26]
# [17, 89, 131, 89, 67, 27]
# 3.9761904761904763
# Game 31
# Round 43, Num_ = 0, kill_keys = dddddsddssd, kill_plans_score[res] = -0.10891089108910891
# Total time: 2.876054048538208
# Part time: 0
# 0.0
# 87
# [4.142857142857143, 1.4285714285714286, 2.2857142857142856, 4.428571428571429, 2.7142857142857144, 6.0]
# [2, 0, 0, 4, 0, 6]
# [50, 0, 13, 26, 50, 53]
# [77, 17, 55, 78, 45, 88]
# 2.619047619047619
# Game 32
# Total time: 1.712510108947754
# Part time: 0
# 0.0
# 97
# [3.5714285714285716, 2.142857142857143, 3.0, 4.142857142857143, 2.142857142857143, 6.0]
# [0, 0, 0, 0, 0, 4]
# [15, 1, 10, 21, 1, 71]
# [40, 13, 18, 97, 13, 98]
# 2.904761904761905
# Game 33
# Round 26, Num_ = 0, kill_keys = wwwwwwwwwaw, kill_plans_score[res] = 0.0
# Total time: 1.9651236534118652
# Part time: 0
# 0.0
# 99
# [5.571428571428571, 1.9285714285714286, 2.5, 5.142857142857143, 2.5, 3.357142857142857]
# [2, 0, 0, 4, 0, 0]
# [43, 8, 10, 17, 5, 21]
# [100, 18, 21, 99, 33, 28]
# 3.3333333333333335
# Game 34
# Round 26, Num_ = 2, kill_keys = dssssdddddwdssa, kill_plans_score[res] = -0.39473684210526316
# Round 76, Num_ = 1, kill_keys = ddddssdsdddsdsdddddsaasd, kill_plans_score[res] = -0.6153846153846154
# Round 76, Num_ = 2, kill_keys = dwddsddsssssssdsdddddsaasd, kill_plans_score[res] = -0.48148148148148145
# Total time: 2.8734195232391357
# Part time: 0
# 0.0
# 150
# [2.857142857142857, 4.642857142857143, 5.214285714285714, 4.857142857142857, 1.7142857142857142, 1.7142857142857142]
# [0, 4, 4, 2, 0, 0]
# [31, 29, 39, 33, 13, 15]
# [78, 104, 89, 151, 28, 16]
# 4.238095238095238
# Game 35
# Round 32, Num_ = 0, kill_keys = ddwwwwwwdwaawd, kill_plans_score[res] = -0.4117647058823529
# Round 58, Num_ = 0, kill_keys = ddwaawd, kill_plans_score[res] = -0.17073170731707318
# Round 58, Num_ = 2, kill_keys = assasssaaawassd, kill_plans_score[res] = -0.5
# Round 83, Num_ = 2, kill_keys = sssssdddddwa, kill_plans_score[res] = 0.0
# Total time: 2.057321310043335
# Part time: 0
# 0.0
# 86
# [5.571428571428571, 3.2857142857142856, 5.0, 3.7142857142857144, 2.0, 1.4285714285714286]
# [6, 0, 4, 2, 0, 0]
# [33, 33, 30, 29, 16, 9]
# [85, 34, 87, 60, 15, 12]
# 4.6190476190476195
# Game 36
# Total time: 1.0894882678985596
# Part time: 0
# 0.0
# 54
# [3.857142857142857, 1.8571428571428572, 2.857142857142857, 6.0, 2.5714285714285716, 3.857142857142857]
# [0, 0, 0, 6, 0, 0]
# [62, 2, 5, 95, 4, 46]
# [35, 9, 11, 55, 11, 40]
# 2.857142857142857
# Game 37
# Round 12, Num_ = 0, kill_keys = ddwaawd, kill_plans_score[res] = -0.4117647058823529
# Round 43, Num_ = 0, kill_keys = asssssssssssaawd, kill_plans_score[res] = -0.8421052631578947
# Total time: 1.9125428199768066
# Part time: 0
# 0.0
# 102
# [4.642857142857143, 2.2142857142857144, 3.9285714285714284, 1.6428571428571428, 5.5, 3.0714285714285716]
# [4, 0, 0, 0, 4, 0]
# [31, 8, 117, 3, 75, 49]
# [73, 14, 45, 9, 103, 26]
# 3.5952380952380953
# Game 38
# Round 24, Num_ = 2, kill_keys = wwdwdssa, kill_plans_score[res] = 0.0
# Total time: 3.0784919261932373
# Part time: 0
# 0.0
# 117
# [1.8571428571428572, 3.7142857142857144, 4.928571428571429, 1.5714285714285714, 3.7142857142857144, 5.214285714285714]
# [0, 0, 4, 0, 2, 4]
# [9, 26, 29, 9, 19, 20]
# [26, 113, 83, 21, 111, 118]
# 3.5
# Game 39
# Round 35, Num_ = 0, kill_keys = aaawwwwdddddwdwd, kill_plans_score[res] = 0.0
# Round 46, Num_ = 0, kill_keys = ssssssssssssdsaasd, kill_plans_score[res] = -0.9473684210526315
# Total time: 1.643235445022583
# Part time: 0
# 0.0
# 61
# [4.142857142857143, 4.5, 2.2142857142857144, 4.857142857142857, 2.5, 2.7857142857142856]
# [6, 0, 0, 2, 0, 0]
# [1, 88, 3, 81, 2, 9]
# [48, 62, 12, 48, 37, 14]
# 3.619047619047619
# Game 40
# Round 43, Num_ = 2, kill_keys = asssssssas, kill_plans_score[res] = -0.4
# Round 48, Num_ = 0, kill_keys = asssssdsaasd, kill_plans_score[res] = -0.17391304347826086
# Round 58, Num_ = 2, kill_keys = ddddwwdwdssa, kill_plans_score[res] = -0.1643835616438356
# Total time: 2.5335135459899902
# Part time: 0
# 0.0
# 150
# [3.142857142857143, 2.857142857142857, 4.428571428571429, 2.857142857142857, 5.714285714285714, 2.0]
# [2, 0, 4, 0, 6, 0]
# [21, 2, 60, 67, 72, 30]
# [60, 151, 64, 50, 66, 45]
# 3.4761904761904763
# Game 41
# Total time: 2.0630102157592773
# Part time: 0
# 0.0
# 103
# [3.0, 3.857142857142857, 4.428571428571429, 5.428571428571429, 2.142857142857143, 2.142857142857143]
# [0, 0, 0, 4, 0, 0]
# [14, 55, 84, 47, 0, 0]
# [23, 57, 83, 104, 21, 21]
# 3.7619047619047623
# Game 42
# Round 54, Num_ = 0, kill_keys = wwwwwwwwwddddddddwdssa, kill_plans_score[res] = -0.13580246913580246
# Round 74, Num_ = 0, kill_keys = dddwdwwwwwddddwdssa, kill_plans_score[res] = -0.15447154471544716
# Total time: 1.8110337257385254
# Part time: 0
# 0.0
# 79
# [6.0, 3.357142857142857, 1.9285714285714286, 2.642857142857143, 5.0, 2.0714285714285716]
# [8, 0, 0, 0, 2, 0]
# [50, 13, 5, 12, 28, 0]
# [80, 56, 15, 19, 76, 19]
# 3.7619047619047623
# Game 43
# Total time: 3.341127634048462
# Part time: 0
# 0.0
# 129
# [4.0, 2.9285714285714284, 1.7857142857142858, 3.857142857142857, 5.428571428571429, 3.0]
# [2, 0, 0, 2, 4, 2]
# [76, 7, 8, 22, 58, 0]
# [34, 130, 15, 85, 95, 85]
# 2.904761904761905
# Game 44
# Round 69, Num_ = 1, kill_keys = wwwawwdwaawd, kill_plans_score[res] = -0.08163265306122448
# Round 78, Num_ = 1, kill_keys = wawaaasd, kill_plans_score[res] = -0.18604651162790697
# Total time: 2.1158010959625244
# Part time: 0
# 0.0
# 107
# [1.7142857142857142, 6.0, 2.5714285714285716, 1.7142857142857142, 4.5, 4.5]
# [0, 4, 0, 0, 2, 2]
# [0, 54, 20, 0, 30, 47]
# [11, 108, 19, 11, 80, 71]
# 3.428571428571429
# Game 45
# Round 87, Num_ = 2, kill_keys = ssdddddddwdssa, kill_plans_score[res] = -0.4375
# Round 90, Num_ = 0, kill_keys = wwwwwwddddddsa, kill_plans_score[res] = 0.0
# Total time: 3.339946746826172
# Part time: 0
# 0.0
# 150
# [5.071428571428571, 3.7142857142857144, 4.357142857142857, 1.7142857142857142, 3.857142857142857, 2.2857142857142856]
# [2, 0, 2, 0, 6, 0]
# [44, 22, 23, 8, 0, 20]
# [108, 151, 92, 14, 92, 89]
# 4.3809523809523805
# Game 46
# Round 13, Num_ = 0, kill_keys = sdwdssa, kill_plans_score[res] = 0.0
# Round 19, Num_ = 2, kill_keys = ssdsaasd, kill_plans_score[res] = 0.0
# Round 61, Num_ = 0, kill_keys = aaaaawwwwaawawassd, kill_plans_score[res] = -0.4
# Round 61, Num_ = 2, kill_keys = dddsaasd, kill_plans_score[res] = -0.04938271604938271
# Round 99, Num_ = 0, kill_keys = aassaasasaaaaaaawwaaasasd, kill_plans_score[res] = -0.5434782608695652
# Total time: 2.6630256175994873
# Part time: 0
# 0.0
# 110
# [5.571428571428571, 3.4285714285714284, 4.142857142857143, 3.857142857142857, 1.4285714285714286, 2.5714285714285716]
# [6, 0, 4, 2, 0, 0]
# [62, 92, 38, 32, 8, 40]
# [111, 63, 101, 111, 15, 21]
# 4.3809523809523805
# Game 47
# Round 35, Num_ = 2, kill_keys = sdwdssa, kill_plans_score[res] = -0.11290322580645161
# Round 70, Num_ = 2, kill_keys = ddddsddsdssddwdssa, kill_plans_score[res] = -0.12
# Total time: 1.5598132610321045
# Part time: 0
# 0.0
# 76
# [2.4285714285714284, 2.4285714285714284, 6.0, 3.5714285714285716, 4.142857142857143, 2.4285714285714284]
# [0, 0, 4, 0, 0, 0]
# [0, 0, 94, 15, 36, 0]
# [13, 13, 77, 37, 72, 13]
# 3.619047619047619
# Game 48
# Round 42, Num_ = 2, kill_keys = aaaaaaaaaawdwaawd, kill_plans_score[res] = -0.1223021582733813
# Round 59, Num_ = 2, kill_keys = aaaaaaaaaaaawassd, kill_plans_score[res] = -0.12686567164179105
# Total time: 1.5405325889587402
# Part time: 0
# 0.0
# 65
# [2.357142857142857, 2.2142857142857144, 6.0, 2.0714285714285716, 5.0, 3.357142857142857]
# [0, 0, 6, 0, 4, 0]
# [8, 17, 123, 0, 60, 49]
# [14, 12, 66, 14, 61, 44]
# 3.5238095238095237
# Game 49
# Total time: 2.2308690547943115
# Part time: 0
# 0.0
# 71
# [2.4285714285714284, 3.5, 1.6428571428571428, 3.7142857142857144, 3.7142857142857144, 6.0]
# [2, 0, 0, 2, 2, 4]
# [0, 59, 10, 38, 55, 65]
# [26, 58, 26, 57, 50, 72]
# 2.5238095238095237
# Game 50
# Round 18, Num_ = 1, kill_keys = waawassd, kill_plans_score[res] = 0.0
# Round 64, Num_ = 1, kill_keys = dddddssdddddddddddwdssa, kill_plans_score[res] = -0.6052631578947368
# Total time: 2.0660462379455566
# Part time: 0
# 0.0
# 90
# [3.0, 5.428571428571429, 3.5714285714285716, 3.0, 1.8571428571428572, 4.142857142857143]
# [0, 6, 0, 0, 0, 0]
# [19, 75, 9, 31, 7, 86]
# [32, 81, 91, 20, 15, 66]
# 4.0
# Game 51
# Round 54, Num_ = 0, kill_keys = ddwddwdssa, kill_plans_score[res] = -0.37037037037037035
# Round 68, Num_ = 1, kill_keys = aaaaaaaaaasddsa, kill_plans_score[res] = -0.234375
# Round 68, Num_ = 2, kill_keys = dddsssdddwdssa, kill_plans_score[res] = -0.358974358974359
# Total time: 3.0006954669952393
# Part time: 0
# 0.0
# 107
# [4.0, 4.285714285714286, 5.142857142857143, 2.0714285714285716, 1.5, 4.0]
# [2, 2, 2, 0, 0, 4]
# [26, 23, 35, 20, 7, 0]
# [70, 107, 108, 56, 13, 85]
# 4.476190476190475
# Game 52
# Total time: 1.874448537826538
# Part time: 0
# 0.0
# 65
# [3.642857142857143, 3.0714285714285716, 1.6428571428571428, 6.0, 4.428571428571429, 2.2142857142857144]
# [0, 0, 0, 6, 4, 0]
# [94, 56, 6, 119, 28, 8]
# [49, 45, 12, 66, 65, 14]
# 2.785714285714286
# Game 53
# Total time: 2.7928996086120605
# Part time: 0
# 0.0
# 136
# [4.0, 1.7142857142857142, 2.857142857142857, 3.357142857142857, 5.714285714285714, 3.357142857142857]
# [0, 0, 0, 2, 4, 2]
# [30, 2, 12, 0, 27, 9]
# [89, 9, 26, 84, 137, 13]
# 2.857142857142857
# Game 54
# Total time: 2.125305414199829
# Part time: 0
# 0.0
# 96
# [2.0, 1.4285714285714286, 3.4285714285714284, 6.0, 3.4285714285714284, 4.714285714285714]
# [0, 0, 0, 6, 2, 4]
# [16, 6, 39, 46, 27, 33]
# [12, 11, 78, 97, 18, 95]
# 2.285714285714286
# Game 55
# Round 64, Num_ = 0, kill_keys = dssddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.137802839279175
# Part time: 0
# 0.0
# 89
# [5.285714285714286, 4.142857142857143, 2.0, 1.4285714285714286, 3.4285714285714284, 4.714285714285714]
# [2, 2, 0, 0, 0, 2]
# [43, 8, 7, 3, 32, 55]
# [90, 72, 15, 8, 80, 66]
# 3.8095238095238098
# Game 56
# Total time: 2.2723708152770996
# Part time: 0
# 0.0
# 99
# [1.9285714285714286, 3.0714285714285716, 3.357142857142857, 5.214285714285714, 1.9285714285714286, 5.5]
# [0, 0, 0, 6, 0, 6]
# [5, 27, 52, 49, 6, 157]
# [15, 55, 46, 100, 13, 61]
# 2.785714285714286
# Game 57
# Round 67, Num_ = 1, kill_keys = aaasaaassassaawassd, kill_plans_score[res] = -0.6785714285714286
# Round 67, Num_ = 2, kill_keys = awaaaaaaaawaawassd, kill_plans_score[res] = -0.8181818181818182
# Total time: 2.364453077316284
# Part time: 0
# 0.0
# 112
# [4.357142857142857, 4.071428571428571, 5.714285714285714, 2.9285714285714284, 1.0, 2.9285714285714284]
# [2, 2, 4, 2, 0, 2]
# [36, 22, 32, 7, 4, 17]
# [69, 102, 113, 17, 12, 16]
# 4.714285714285714
# Game 58
# Round 44, Num_ = 1, kill_keys = aaaaawwwwwwwwwwdwaawd, kill_plans_score[res] = -0.21212121212121213
# Round 64, Num_ = 2, kill_keys = dddddddsddddddddwdssa, kill_plans_score[res] = -0.28378378378378377
# Round 94, Num_ = 1, kill_keys = wdddwddwwwddddsa, kill_plans_score[res] = 0.0
# Total time: 2.651258707046509
# Part time: 0
# 0.0
# 97
# [2.5714285714285716, 5.785714285714286, 4.928571428571429, 2.0, 4.285714285714286, 1.4285714285714286]
# [0, 4, 4, 0, 2, 0]
# [12, 48, 33, 11, 41, 5]
# [46, 98, 96, 32, 66, 14]
# 4.428571428571429
# Game 59
# Round 46, Num_ = 2, kill_keys = aaaaaaawwaaaaaaaawassd, kill_plans_score[res] = -0.88
# Round 76, Num_ = 1, kill_keys = sssasaaasssssaawassd, kill_plans_score[res] = -0.3076923076923077
# Total time: 1.7843992710113525
# Part time: 0
# 0.0
# 84
# [1.9285714285714286, 5.785714285714286, 5.214285714285714, 2.7857142857142856, 3.357142857142857, 1.9285714285714286]
# [0, 2, 2, 0, 0, 0]
# [6, 61, 54, 11, 15, 6]
# [10, 85, 78, 21, 48, 10]
# 4.309523809523809
# Game 60
# Round 10, Num_ = 2, kill_keys = sawassd, kill_plans_score[res] = 0.0
# Round 35, Num_ = 2, kill_keys = awwwwwwwwwaawassd, kill_plans_score[res] = 0.0
# Round 86, Num_ = 1, kill_keys = dsssddddsdsaa, kill_plans_score[res] = -0.4482758620689655
# Round 109, Num_ = 2, kill_keys = ssddsdsdssasssssddddddddd, kill_plans_score[res] = -1.1363636363636365
# Round 110, Num_ = 2, kill_keys = assdsssddsdsdssasssdsss, kill_plans_score[res] = -0.9583333333333334
# Total time: 2.7275185585021973
# Part time: 0
# 0.0
# 150
# [2.2857142857142856, 5.071428571428571, 5.714285714285714, 4.214285714285714, 1.4285714285714286, 2.2857142857142856]
# [0, 2, 6, 2, 0, 0]
# [15, 28, 26, 23, 5, 13]
# [27, 112, 151, 88, 12, 37]
# 4.357142857142857
# Game 61
# Round 28, Num_ = 0, kill_keys = ddssssdsaasd, kill_plans_score[res] = 0.0
# Total time: 2.659799814224243
# Part time: 0
# 0.0
# 150
# [5.285714285714286, 3.0714285714285716, 2.2142857142857144, 1.6428571428571428, 5.714285714285714, 3.0714285714285716]
# [2, 0, 0, 0, 4, 0]
# [42, 10, 7, 0, 20, 14]
# [130, 128, 18, 13, 151, 30]
# 3.523809523809524
# Game 62
# Round 73, Num_ = 0, kill_keys = dddddddddddddddddddwdss, kill_plans_score[res] = -0.359375
# Total time: 1.6256980895996094
# Part time: 0
# 0.0
# 75
# [5.785714285714286, 2.7857142857142856, 3.642857142857143, 1.7857142857142858, 4.928571428571429, 2.0714285714285716]
# [4, 0, 0, 0, 4, 0]
# [41, 23, 30, 8, 36, 15]
# [76, 22, 75, 14, 33, 14]
# 4.071428571428571
# Game 63
# Round 34, Num_ = 0, kill_keys = dsddddwdssa, kill_plans_score[res] = -0.1864406779661017
# Round 45, Num_ = 1, kill_keys = aaassaaaaawassd, kill_plans_score[res] = -0.25
# Round 84, Num_ = 1, kill_keys = waaaaaaaaaaaaaaaaawassd, kill_plans_score[res] = -0.2987012987012987
# Total time: 2.1515297889709473
# Part time: 0
# 0.0
# 97
# [4.571428571428571, 5.214285714285714, 2.5714285714285716, 2.0, 5.214285714285714, 1.4285714285714286]
# [2, 4, 0, 0, 4, 0]
# [85, 64, 44, 7, 65, 3]
# [47, 98, 36, 20, 86, 9]
# 4.119047619047619
# Game 64
# Total time: 3.372731924057007
# Part time: 0
# 0.0
# 140
# [4.285714285714286, 2.642857142857143, 1.2142857142857142, 4.0, 2.857142857142857, 6.0]
# [2, 0, 0, 2, 2, 4]
# [34, 22, 8, 21, 13, 36]
# [84, 82, 18, 114, 73, 141]
# 2.714285714285714
# Game 65
# Total time: 2.2832651138305664
# Part time: 0
# 0.0
# 71
# [2.0, 3.142857142857143, 3.9285714285714284, 6.0, 1.4285714285714286, 4.5]
# [0, 0, 2, 4, 0, 2]
# [25, 36, 59, 79, 8, 71]
# [32, 67, 54, 72, 10, 62]
# 3.0238095238095237
# Game 66
# Total time: 3.2440037727355957
# Part time: 0
# 0.0
# 111
# [3.4285714285714284, 2.0, 3.142857142857143, 4.785714285714286, 4.142857142857143, 3.5]
# [0, 0, 0, 2, 6, 2]
# [32, 6, 43, 31, 0, 0]
# [94, 12, 83, 112, 94, 94]
# 2.857142857142857
# Game 67
# Total time: 0.6140434741973877
# Part time: 0
# 0.0
# 25
# [1.5714285714285714, 5.214285714285714, 2.0, 5.785714285714286, 3.7142857142857144, 2.7142857142857144]
# [0, 4, 0, 4, 2, 0]
# [3, 21, 8, 43, 10, 8]
# [14, 21, 14, 26, 17, 18]
# 2.9285714285714284
# Game 68
# Round 45, Num_ = 0, kill_keys = ssssawassd, kill_plans_score[res] = -0.17543859649122806
# Round 82, Num_ = 0, kill_keys = dddddsddddwdss, kill_plans_score[res] = -0.6086956521739131
# Round 82, Num_ = 1, kill_keys = ssddsdddssdddddddddddwdss, kill_plans_score[res] = -0.8928571428571429
# Total time: 3.304650068283081
# Part time: 0
# 0.0
# 101
# [3.857142857142857, 3.2142857142857144, 2.0714285714285716, 6.0, 2.0714285714285716, 3.7857142857142856]
# [4, 2, 0, 8, 0, 2]
# [9, 3, 11, 49, 13, 43]
# [89, 101, 47, 102, 25, 84]
# 3.0476190476190474
# Game 69
# Round 45, Num_ = 1, kill_keys = dddddddddddddddwdssa, kill_plans_score[res] = -0.36363636363636365
# Round 77, Num_ = 1, kill_keys = ssaassssaww, kill_plans_score[res] = -0.39285714285714285
# Total time: 2.627173900604248
# Part time: 0
# 0.0
# 95
# [2.857142857142857, 4.642857142857143, 3.142857142857143, 3.142857142857143, 1.4285714285714286, 5.785714285714286]
# [2, 6, 0, 0, 0, 6]
# [12, 14, 38, 37, 9, 47]
# [20, 83, 47, 79, 19, 96]
# 3.5476190476190474
# Game 70
# Round 55, Num_ = 1, kill_keys = ssssssssssdsaasd, kill_plans_score[res] = 0.0
# Round 55, Num_ = 2, kill_keys = aaaaasssaassaaassaaawassd, kill_plans_score[res] = -0.9615384615384616
# Total time: 3.803989887237549
# Part time: 0
# 0.0
# 150
# [1.8571428571428572, 3.9285714285714284, 4.642857142857143, 3.7857142857142856, 3.2142857142857144, 3.5714285714285716]
# [0, 2, 2, 2, 2, 4]
# [24, 43, 25, 22, 21, 0]
# [57, 92, 151, 117, 101, 92]
# 3.4761904761904763
# Game 71
# Round 37, Num_ = 0, kill_keys = wwwwwwaaawassd, kill_plans_score[res] = 0.0
# Round 63, Num_ = 0, kill_keys = waaaaaaaaaawassd, kill_plans_score[res] = 0.0
# Total time: 1.714684009552002
# Part time: 0
# 0.0
# 70
# [5.714285714285714, 1.5, 1.5, 4.857142857142857, 4.0, 3.4285714285714284]
# [4, 0, 0, 2, 2, 2]
# [48, 7, 7, 77, 27, 21]
# [71, 17, 17, 65, 39, 30]
# 2.904761904761905
# Game 72
# Round 18, Num_ = 0, kill_keys = ssdddwdssa, kill_plans_score[res] = 0.0
# Round 24, Num_ = 2, kill_keys = sssssddddwdssa, kill_plans_score[res] = 0.0
# Round 39, Num_ = 2, kill_keys = ddddddwwwwddddddddddwdssa, kill_plans_score[res] = -0.22727272727272727
# Total time: 1.3995957374572754
# Part time: 0
# 0.0
# 59
# [4.214285714285714, 2.0, 6.0, 1.4285714285714286, 3.7142857142857144, 3.642857142857143]
# [2, 0, 4, 0, 0, 2]
# [68, 8, 103, 0, 90, 12]
# [26, 19, 60, 17, 41, 20]
# 4.071428571428572
# Game 73
# Total time: 1.6587393283843994
# Part time: 0
# 0.0
# 66
# [1.9285714285714286, 3.642857142857143, 2.7857142857142856, 4.714285714285714, 6.0, 1.9285714285714286]
# [0, 0, 0, 2, 6, 0]
# [8, 30, 12, 23, 56, 10]
# [23, 32, 29, 66, 67, 18]
# 2.785714285714286
# Game 74
# Total time: 0.7824430465698242
# Part time: 0
# 0.0
# 34
# [3.142857142857143, 1.7142857142857142, 3.7142857142857144, 4.642857142857143, 2.0, 5.785714285714286]
# [2, 0, 0, 4, 0, 4]
# [15, 12, 44, 33, 4, 48]
# [15, 13, 27, 23, 17, 35]
# 2.857142857142857
# Game 75
# Round 19, Num_ = 2, kill_keys = aaawassd, kill_plans_score[res] = 0.0
# Round 24, Num_ = 1, kill_keys = ssssdsaasd, kill_plans_score[res] = -0.25
# Round 52, Num_ = 2, kill_keys = aasssssassssssssdsaasd, kill_plans_score[res] = -0.4074074074074074
# Total time: 2.0318145751953125
# Part time: 0
# 0.0
# 76
# [2.0, 4.0, 5.0, 2.0, 2.0, 6.0]
# [0, 2, 4, 0, 0, 6]
# [19, 31, 53, 26, 11, 60]
# [21, 54, 74, 16, 26, 77]
# 3.6666666666666665
# Game 76
# Round 25, Num_ = 0, kill_keys = sssssssssdsaasd, kill_plans_score[res] = -0.4166666666666667
# Total time: 1.229297399520874
# Part time: 0
# 0.0
# 45
# [5.428571428571429, 1.6428571428571428, 2.2142857142857144, 5.571428571428571, 2.7857142857142856, 3.357142857142857]
# [6, 0, 0, 2, 0, 0]
# [107, 5, 11, 129, 37, 57]
# [45, 12, 15, 46, 20, 27]
# 3.095238095238095
# Game 77
# Round 14, Num_ = 1, kill_keys = wwwddwdssa, kill_plans_score[res] = 0.0
# Round 19, Num_ = 1, kill_keys = wwwwaaawassd, kill_plans_score[res] = 0.0
# Round 57, Num_ = 0, kill_keys = sssssssssawassd, kill_plans_score[res] = -0.19736842105263158
# Total time: 1.441854476928711
# Part time: 0
# 0.0
# 64
# [5.357142857142857, 5.142857142857143, 4.357142857142857, 1.4285714285714286, 2.0, 2.7142857142857144]
# [2, 4, 2, 0, 0, 0]
# [75, 67, 26, 4, 19, 26]
# [65, 32, 59, 8, 16, 21]
# 4.9523809523809526
# Game 78
# Total time: 2.687291145324707
# Part time: 0
# 0.0
# 106
# [1.6428571428571428, 2.7857142857142856, 2.2142857142857144, 4.714285714285714, 6.0, 3.642857142857143]
# [0, 0, 0, 4, 8, 0]
# [6, 16, 7, 37, 66, 64]
# [13, 53, 28, 67, 107, 66]
# 2.2142857142857144
# Game 79
# Round 63, Num_ = 1, kill_keys = sssssssssssaaaaaawd, kill_plans_score[res] = -0.4318181818181818
# Round 66, Num_ = 1, kill_keys = saaaaaaaaaaasssawassd, kill_plans_score[res] = -0.6363636363636364
# Round 66, Num_ = 2, kill_keys = ddddsaasd, kill_plans_score[res] = -0.0989010989010989
# Total time: 2.7502493858337402
# Part time: 0
# 0.0
# 118
# [1.7857142857142858, 5.214285714285714, 4.928571428571429, 4.071428571428571, 3.7857142857142856, 1.2142857142857142]
# [0, 4, 4, 2, 2, 0]
# [15, 56, 30, 64, 31, 13]
# [19, 85, 119, 65, 68, 16]
# 3.9761904761904763
# Game 80
# Round 18, Num_ = 1, kill_keys = awawassd, kill_plans_score[res] = 0.0
# Total time: 2.0059869289398193
# Part time: 0
# 0.0
# 68
# [2.5714285714285716, 4.571428571428571, 1.7142857142857142, 4.785714285714286, 5.357142857142857, 2.0]
# [0, 6, 0, 2, 2, 0]
# [25, 19, 18, 26, 28, 7]
# [15, 58, 13, 63, 69, 20]
# 2.952380952380952
# Game 81
# Round 50, Num_ = 2, kill_keys = wdwwdddddddwdssa, kill_plans_score[res] = -0.15841584158415842
# Total time: 2.65488338470459
# Part time: 0
# 0.0
# 100
# [1.7142857142857142, 2.857142857142857, 5.071428571428571, 5.714285714285714, 2.2857142857142856, 3.357142857142857]
# [0, 0, 2, 4, 0, 2]
# [2, 27, 42, 33, 5, 0]
# [8, 52, 90, 101, 15, 74]
# 3.214285714285714
# Game 82
# Round 21, Num_ = 0, kill_keys = sssssdsss, kill_plans_score[res] = 0.0
# Round 77, Num_ = 0, kill_keys = wdddssddssddddddddddddddsdddddddwdssa, kill_plans_score[res] = -0.925
# Round 77, Num_ = 1, kill_keys = wdsddwdwwwwwwwwddddwdssa, kill_plans_score[res] = -0.7272727272727273
# Total time: 2.9616074562072754
# Part time: 0
# 0.0
# 144
# [4.142857142857143, 3.7142857142857144, 3.142857142857143, 5.142857142857143, 1.7142857142857142, 3.142857142857143]
# [4, 2, 0, 6, 0, 0]
# [4, 9, 18, 17, 8, 57]
# [145, 80, 79, 109, 23, 33]
# 3.6666666666666665
# Game 83
# Round 61, Num_ = 0, kill_keys = ssaaaasssaaaawassd, kill_plans_score[res] = -0.23684210526315788
# Round 61, Num_ = 2, kill_keys = dddddsdddwdssa, kill_plans_score[res] = -0.32558139534883723
# Round 71, Num_ = 2, kill_keys = aaaaaaawassd, kill_plans_score[res] = 0.0
# Total time: 2.5334436893463135
# Part time: 0
# 0.0
# 82
# [4.214285714285714, 1.7857142857142858, 6.0, 4.214285714285714, 1.2142857142857142, 3.5714285714285716]
# [4, 0, 6, 4, 0, 2]
# [58, 8, 89, 12, 7, 81]
# [73, 20, 83, 77, 17, 63]
# 4.0
# Game 84
# Round 19, Num_ = 0, kill_keys = wwawassd, kill_plans_score[res] = 0.0
# Round 63, Num_ = 2, kill_keys = saawassd, kill_plans_score[res] = -0.3076923076923077
# Round 64, Num_ = 0, kill_keys = ddddddddwaawd, kill_plans_score[res] = -0.13978494623655913
# Round 68, Num_ = 0, kill_keys = wwwwwddwwwdddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.31193208694458
# Part time: 0
# 0.0
# 82
# [6.0, 3.357142857142857, 4.428571428571429, 2.2142857142857144, 1.6428571428571428, 3.357142857142857]
# [8, 0, 2, 0, 0, 0]
# [143, 46, 38, 25, 2, 133]
# [83, 66, 70, 21, 10, 65]
# 4.595238095238096
# Game 85
# Round 63, Num_ = 2, kill_keys = sdddddsssssdwdssa, kill_plans_score[res] = -0.3617021276595745
# Total time: 2.953432321548462
# Part time: 0
# 0.0
# 120
# [2.2142857142857144, 3.357142857142857, 5.285714285714286, 3.642857142857143, 2.5, 4.0]
# [0, 0, 2, 0, 0, 4]
# [4, 65, 38, 5, 0, 0]
# [9, 65, 121, 86, 71, 71]
# 3.619047619047619
# Game 86
# Total time: 2.4097108840942383
# Part time: 0
# 0.0
# 132
# [2.642857142857143, 4.928571428571429, 1.9285714285714286, 3.9285714285714284, 2.0714285714285716, 5.5]
# [0, 2, 0, 0, 0, 2]
# [7, 31, 6, 49, 1, 32]
# [21, 111, 15, 87, 21, 133]
# 3.1666666666666665
# Game 87
# Round 33, Num_ = 0, kill_keys = ssasassawassd, kill_plans_score[res] = -0.37142857142857144
# Round 33, Num_ = 2, kill_keys = dddsaasd, kill_plans_score[res] = -0.13114754098360656
# Round 49, Num_ = 2, kill_keys = sddddddssssddwdssa, kill_plans_score[res] = -0.1276595744680851
# Round 61, Num_ = 2, kill_keys = sssssssssawassd, kill_plans_score[res] = 0.0
# Total time: 2.6929402351379395
# Part time: 0
# 0.0
# 78
# [2.5714285714285716, 2.5714285714285716, 5.714285714285714, 2.0, 2.857142857142857, 5.285714285714286]
# [2, 0, 6, 0, 0, 4]
# [16, 34, 90, 40, 48, 62]
# [47, 63, 73, 35, 51, 79]
# 3.619047619047619
# Game 88
# Round 73, Num_ = 0, kill_keys = aassdsaasd, kill_plans_score[res] = -0.47619047619047616
# Round 73, Num_ = 1, kill_keys = ddwwdwwaaaaawwwaaaawassd, kill_plans_score[res] = -0.2727272727272727
# Round 83, Num_ = 1, kill_keys = wwddddwdssa, kill_plans_score[res] = 0.0
# Round 104, Num_ = 1, kill_keys = ssdddddwdssa, kill_plans_score[res] = -0.36363636363636365
# Total time: 2.97737193107605
# Part time: 0
# 0.0
# 111
# [4.0, 6.0, 2.9285714285714284, 4.0, 2.5714285714285716, 1.5]
# [2, 6, 0, 2, 2, 0]
# [19, 39, 33, 10, 0, 9]
# [85, 112, 75, 106, 36, 24]
# 4.309523809523809
# Game 89
# Round 72, Num_ = 0, kill_keys = wdddsddddwdssa, kill_plans_score[res] = 0.0
# Total time: 1.9634745121002197
# Part time: 0
# 0.0
# 86
# [4.714285714285714, 1.7857142857142858, 2.357142857142857, 6.0, 3.642857142857143, 2.5]
# [2, 0, 0, 8, 0, 0]
# [20, 3, 17, 28, 23, 7]
# [78, 15, 15, 87, 74, 18]
# 2.9523809523809526
# Game 90
# Round 45, Num_ = 0, kill_keys = aaaaaaaaawaaaawassd, kill_plans_score[res] = -0.59375
# Round 45, Num_ = 1, kill_keys = aaaaaaawassd, kill_plans_score[res] = -0.21428571428571427
# Round 47, Num_ = 0, kill_keys = wwwdddddwdssa, kill_plans_score[res] = -0.7647058823529411
# Round 52, Num_ = 1, kill_keys = dssssssssssddddddddwdssa, kill_plans_score[res] = -0.2727272727272727
# Round 66, Num_ = 1, kill_keys = ddwwwwwddddddwdssa, kill_plans_score[res] = -0.6206896551724138
# Total time: 2.370412588119507
# Part time: 0
# 0.0
# 78
# [4.071428571428571, 4.928571428571429, 3.9285714285714284, 1.6428571428571428, 3.0714285714285716, 3.357142857142857]
# [6, 6, 0, 0, 0, 0]
# [30, 45, 70, 7, 47, 82]
# [54, 79, 68, 9, 49, 47]
# 4.309523809523809
# Game 91
# Round 75, Num_ = 0, kill_keys = aaawassd, kill_plans_score[res] = -0.10126582278481013
# Total time: 2.184537172317505
# Part time: 0
# 0.0
# 77
# [5.357142857142857, 3.142857142857143, 1.5714285714285714, 2.857142857142857, 2.9285714285714284, 5.142857142857143]
# [2, 0, 0, 0, 2, 8]
# [71, 53, 2, 25, 11, 29]
# [78, 41, 10, 53, 10, 77]
# 3.357142857142857
# Game 92
# Round 56, Num_ = 1, kill_keys = aawwwwwwwwaaaaaaaaaaaaawassd, kill_plans_score[res] = -0.3888888888888889
# Round 69, Num_ = 1, kill_keys = sddddddwwwwwwddddddwds, kill_plans_score[res] = -0.6285714285714286
# Total time: 3.229511022567749
# Part time: 0
# 0.0
# 117
# [1.4285714285714286, 3.642857142857143, 2.5714285714285716, 6.0, 2.5714285714285716, 4.785714285714286]
# [0, 4, 0, 10, 0, 4]
# [4, 6, 52, 69, 31, 66]
# [10, 85, 58, 118, 71, 102]
# 2.5476190476190474
# Game 93
# Total time: 2.313445568084717
# Part time: 0
# 0.0
# 114
# [2.7857142857142856, 1.9285714285714286, 3.9285714285714284, 4.714285714285714, 5.714285714285714, 1.9285714285714286]
# [0, 0, 0, 2, 4, 0]
# [12, 4, 22, 36, 63, 0]
# [26, 13, 115, 69, 83, 19]
# 2.880952380952381
# Game 94
# Round 28, Num_ = 1, kill_keys = ssssssassssssssdsaasd, kill_plans_score[res] = -0.5121951219512195
# Round 86, Num_ = 1, kill_keys = wdddddddddddddddssaaaaaaaasaasd, kill_plans_score[res] = 0.0
# Total time: 2.5195112228393555
# Part time: 0
# 0.0
# 150
# [2.2142857142857144, 5.071428571428571, 2.642857142857143, 5.214285714285714, 1.9285714285714286, 3.9285714285714284]
# [0, 4, 0, 4, 0, 0]
# [17, 33, 33, 57, 19, 95]
# [35, 151, 30, 88, 17, 62]
# 3.3095238095238098
# Game 95
# Total time: 2.727538824081421
# Part time: 0
# 0.0
# 108
# [3.142857142857143, 2.2857142857142856, 1.4285714285714286, 4.857142857142857, 3.7857142857142856, 5.5]
# [0, 0, 0, 2, 4, 4]
# [24, 13, 4, 47, 12, 34]
# [71, 31, 11, 83, 67, 109]
# 2.285714285714286
# Game 96
# Round 56, Num_ = 2, kill_keys = aawwwwwdwaawd, kill_plans_score[res] = -0.16455696202531644
# Total time: 2.5765299797058105
# Part time: 0
# 0.0
# 74
# [4.571428571428571, 1.2142857142857142, 4.285714285714286, 5.142857142857143, 4.0, 1.7857142857142858]
# [4, 0, 2, 2, 2, 0]
# [46, 5, 66, 82, 16, 10]
# [58, 16, 68, 75, 73, 19]
# 3.357142857142857
# Game 97
# Round 31, Num_ = 0, kill_keys = wddwdssa, kill_plans_score[res] = 0.0
# Round 69, Num_ = 2, kill_keys = sdsssdssssssddddddddddwdssa, kill_plans_score[res] = -0.4909090909090909
# Total time: 2.184152126312256
# Part time: 0
# 0.0
# 107
# [5.214285714285714, 1.4285714285714286, 5.5, 3.4285714285714284, 3.142857142857143, 2.2857142857142856]
# [4, 0, 4, 0, 2, 0]
# [93, 8, 84, 46, 32, 16]
# [47, 17, 108, 71, 18, 33]
# 4.0476190476190474
# Game 98
# Round 30, Num_ = 1, kill_keys = wwdddddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.7324705123901367
# Part time: 0
# 0.0
# 138
# [2.5714285714285716, 4.785714285714286, 1.4285714285714286, 2.2857142857142856, 5.714285714285714, 4.214285714285714]
# [0, 2, 0, 0, 6, 2]
# [22, 83, 9, 22, 37, 22]
# [41, 49, 14, 32, 139, 99]
# 2.928571428571429
# Game 99
# Total time: 2.876079797744751
# Part time: 0
# 0.0
# 112
# [4.142857142857143, 2.142857142857143, 2.5714285714285716, 3.5714285714285716, 6.0, 2.5714285714285716]
# [0, 0, 0, 0, 4, 0]
# [30, 0, 1, 9, 36, 0]
# [106, 10, 10, 96, 113, 83]
# 2.9523809523809526
# Game 100
# Round 18, Num_ = 2, kill_keys = asawassd, kill_plans_score[res] = 0.0
# Round 31, Num_ = 2, kill_keys = wwddddddddddddddwwwaaaas, kill_plans_score[res] = 0.0
# Round 48, Num_ = 2, kill_keys = sssssaasaawassd, kill_plans_score[res] = 0.0
# Round 102, Num_ = 0, kill_keys = sassaas, kill_plans_score[res] = -0.15217391304347827
# Total time: 2.3227896690368652
# Part time: 0
# 0.0
# 147
# [5.071428571428571, 2.0, 5.714285714285714, 3.7857142857142856, 3.0, 1.4285714285714286]
# [2, 0, 4, 2, 0, 0]
# [30, 11, 52, 16, 16, 10]
# [148, 24, 104, 33, 50, 20]
# 4.261904761904762
# Game 101
# Round 21, Num_ = 2, kill_keys = saaaaaaawassd, kill_plans_score[res] = 0.0
# Round 29, Num_ = 2, kill_keys = waaaaawwawassd, kill_plans_score[res] = -0.22950819672131148
# Round 60, Num_ = 2, kill_keys = ddsdddddsssssdsaasd, kill_plans_score[res] = -0.24050632911392406
# Total time: 1.9478733539581299
# Part time: 0
# 0.0
# 72
# [2.5714285714285716, 1.7142857142857142, 6.0, 3.642857142857143, 3.642857142857143, 3.4285714285714284]
# [0, 0, 6, 2, 2, 0]
# [7, 3, 96, 0, 8, 90]
# [31, 9, 73, 63, 23, 62]
# 3.4285714285714284
# Game 102
# Round 52, Num_ = 0, kill_keys = ddddddddsddddddddddssdsaasd, kill_plans_score[res] = -0.7297297297297297
# Round 52, Num_ = 1, kill_keys = ddddddddsaasd, kill_plans_score[res] = -0.3170731707317073
# Total time: 3.4179348945617676
# Part time: 0
# 0.0
# 82
# [2.4285714285714284, 3.2857142857142856, 1.8571428571428572, 4.142857142857143, 3.2857142857142856, 6.0]
# [2, 2, 0, 6, 2, 8]
# [16, 31, 72, 19, 80, 87]
# [57, 70, 44, 80, 54, 83]
# 2.5238095238095237
# Game 103
# Total time: 1.2222747802734375
# Part time: 0
# 0.0
# 50
# [3.5714285714285716, 2.4285714285714284, 1.8571428571428572, 6.0, 3.0, 4.142857142857143]
# [0, 0, 0, 10, 0, 0]
# [15, 4, 2, 79, 12, 25]
# [32, 12, 6, 51, 22, 50]
# 2.619047619047619
# Game 104
# Total time: 1.7121920585632324
# Part time: 0
# 0.0
# 72
# [1.9285714285714286, 3.642857142857143, 4.714285714285714, 6.0, 2.5, 2.2142857142857144]
# [0, 0, 2, 6, 0, 0]
# [0, 37, 29, 174, 4, 13]
# [17, 32, 72, 73, 20, 13]
# 3.4285714285714284
# Game 105
# Round 71, Num_ = 0, kill_keys = aaaaaaaaaawassd, kill_plans_score[res] = -0.24193548387096775
# Total time: 3.755664348602295
# Part time: 0
# 0.0
# 123
# [3.857142857142857, 4.285714285714286, 2.2857142857142856, 4.428571428571429, 3.0, 3.142857142857143]
# [2, 0, 0, 2, 2, 0]
# [1, 69, 28, 54, 0, 9]
# [122, 124, 73, 109, 85, 123]
# 3.476190476190476
# Game 106
# Round 60, Num_ = 0, kill_keys = aaaaaaaaaaaaaaaawassd, kill_plans_score[res] = -0.5675675675675675
# Total time: 3.0786030292510986
# Part time: 0
# 0.0
# 84
# [3.5, 1.2142857142857142, 2.357142857142857, 5.0, 2.9285714285714284, 6.0]
# [2, 0, 0, 4, 2, 6]
# [23, 4, 25, 40, 16, 49]
# [77, 11, 62, 81, 68, 85]
# 2.357142857142857
# Game 107
# Round 73, Num_ = 0, kill_keys = aaaaaaaaaaaawassd, kill_plans_score[res] = 0.0
# Total time: 1.8037476539611816
# Part time: 0
# 0.0
# 85
# [5.785714285714286, 3.4285714285714284, 2.0, 1.4285714285714286, 3.142857142857143, 5.214285714285714]
# [4, 2, 0, 0, 0, 4]
# [108, 22, 9, 3, 26, 100]
# [86, 24, 23, 14, 38, 75]
# 3.7380952380952377
# Game 108
# Round 55, Num_ = 1, kill_keys = dssaasssasssssassssssssssaaaaaaawd, kill_plans_score[res] = -0.2125
# Round 56, Num_ = 1, kill_keys = dssassssddddddsssdsdsaasd, kill_plans_score[res] = -0.1893939393939394
# Total time: 2.9905550479888916
# Part time: 0
# 0.0
# 74
# [1.5, 5.214285714285714, 1.5, 3.5, 5.785714285714286, 3.5]
# [0, 4, 0, 2, 4, 2]
# [11, 57, 4, 26, 65, 41]
# [38, 74, 56, 58, 75, 57]
# 2.7380952380952386
# Game 109
# Round 33, Num_ = 0, kill_keys = ssaaawassd, kill_plans_score[res] = 0.0
# Total time: 1.89961838722229
# Part time: 0
# 0.0
# 86
# [5.285714285714286, 5.714285714285714, 3.0714285714285716, 1.9285714285714286, 2.642857142857143, 2.357142857142857]
# [2, 4, 0, 0, 0, 0]
# [52, 38, 12, 8, 16, 8]
# [85, 87, 35, 14, 14, 15]
# 4.690476190476191
# Game 110
# Total time: 1.1501400470733643
# Part time: 0
# 0.0
# 40
# [3.5714285714285716, 1.9285714285714286, 2.2142857142857144, 3.9285714285714284, 3.357142857142857, 6.0]
# [2, 0, 0, 0, 0, 4]
# [12, 7, 15, 40, 22, 120]
# [34, 18, 15, 38, 37, 41]
# 2.5714285714285716
# Game 111
# Round 54, Num_ = 1, kill_keys = ssaaaaaaassssaawasasd, kill_plans_score[res] = -0.2625
# Round 63, Num_ = 1, kill_keys = wwwwwwwaaawwddd, kill_plans_score[res] = -0.5555555555555556
# Round 65, Num_ = 1, kill_keys = dwwwwwwwwddddddddddwdddddds, kill_plans_score[res] = -1.6875
# Total time: 3.2784788608551025
# Part time: 0
# 0.0
# 111
# [1.3571428571428572, 4.642857142857143, 2.2142857142857144, 2.9285714285714284, 5.785714285714286, 4.071428571428571]
# [0, 4, 0, 2, 4, 2]
# [19, 38, 42, 23, 50, 48]
# [56, 94, 56, 65, 112, 67]
# 2.7380952380952386
# Game 112
# Round 32, Num_ = 2, kill_keys = aaaaasaaaasssaaasssawassd, kill_plans_score[res] = -0.36764705882352944
# Round 60, Num_ = 2, kill_keys = sssaaaassssaaaawassd, kill_plans_score[res] = -0.2702702702702703
# Total time: 2.479954481124878
# Part time: 0
# 0.0
# 110
# [2.2142857142857144, 4.642857142857143, 5.5, 4.214285714285714, 2.7857142857142856, 1.6428571428571428]
# [0, 4, 4, 0, 0, 0]
# [9, 33, 103, 51, 18, 7]
# [18, 62, 81, 111, 34, 16]
# 4.1190476190476195
# Game 113
# Round 47, Num_ = 0, kill_keys = sssssssssaaaaaawassd, kill_plans_score[res] = -0.35714285714285715
# Round 77, Num_ = 0, kill_keys = aaaaaawaasds, kill_plans_score[res] = -0.46153846153846156
# Round 77, Num_ = 2, kill_keys = aaaaassawawd, kill_plans_score[res] = -0.48
# Round 94, Num_ = 2, kill_keys = dddwwdwawd, kill_plans_score[res] = -0.45454545454545453
# Total time: 4.139019727706909
# Part time: 0
# 0.0
# 150
# [3.7857142857142856, 2.857142857142857, 5.214285714285714, 2.857142857142857, 2.857142857142857, 3.4285714285714284]
# [4, 0, 4, 0, 0, 2]
# [5, 9, 14, 27, 50, 13]
# [104, 113, 151, 79, 49, 96]
# 3.9523809523809526
# Game 114
# Round 27, Num_ = 2, kill_keys = dddwddddwdwdwdssa, kill_plans_score[res] = -0.25
# Total time: 2.604753017425537
# Part time: 0
# 0.0
# 105
# [1.4285714285714286, 2.2857142857142856, 3.5, 5.714285714285714, 3.0, 5.071428571428571]
# [0, 0, 2, 4, 0, 2]
# [16, 46, 35, 98, 52, 102]
# [24, 29, 63, 106, 63, 81]
# 2.4047619047619047
# Game 115
# Round 68, Num_ = 1, kill_keys = ddwwdwwwdwwwwwwdww, kill_plans_score[res] = -0.32727272727272727
# Total time: 2.45664119720459
# Part time: 0
# 0.0
# 109
# [1.9285714285714286, 5.5, 3.357142857142857, 2.7857142857142856, 5.5, 1.9285714285714286]
# [0, 4, 0, 0, 4, 0]
# [4, 51, 20, 9, 44, 4]
# [15, 90, 70, 45, 110, 15]
# 3.5952380952380953
# Game 116
# Total time: 1.7114503383636475
# Part time: 0
# 0.0
# 82
# [3.9285714285714284, 1.9285714285714286, 3.857142857142857, 3.9285714285714284, 1.9285714285714286, 5.428571428571429]
# [0, 0, 2, 0, 0, 6]
# [56, 6, 20, 34, 8, 43]
# [35, 21, 29, 83, 14, 72]
# 3.2380952380952377
# Game 117
# Round 20, Num_ = 0, kill_keys = sddddwdssa, kill_plans_score[res] = 0.0
# Round 59, Num_ = 1, kill_keys = sssssssaaaaaawassd, kill_plans_score[res] = -0.6428571428571429
# Round 59, Num_ = 2, kill_keys = ssssssssssddddwdssa, kill_plans_score[res] = -0.5135135135135135
# Round 72, Num_ = 1, kill_keys = ddddddddddddwdwdssa, kill_plans_score[res] = -0.9047619047619048
# Total time: 3.4222311973571777
# Part time: 0
# 0.0
# 134
# [3.5714285714285716, 3.4285714285714284, 4.142857142857143, 1.2857142857142858, 5.285714285714286, 3.2857142857142856]
# [2, 4, 2, 0, 8, 2]
# [39, 2, 35, 9, 31, 31]
# [61, 74, 102, 22, 135, 74]
# 3.714285714285714
# Game 118
# Round 78, Num_ = 0, kill_keys = aaaaaawwwwwaaaaawassd, kill_plans_score[res] = -0.42
# Round 78, Num_ = 1, kill_keys = waaaaaaaaawwwwaaaaawassd, kill_plans_score[res] = -0.9230769230769231
# Round 87, Num_ = 0, kill_keys = waawassd, kill_plans_score[res] = 0.0
# ...
# Round 75, Num_ = 1, kill_keys = awwwwwwwaaaaaaaaaaaawaas, kill_plans_score[res] = -0.42857142857142855
# Round 79, Num_ = 1, kill_keys = wwwasaawdw, kill_plans_score[res] = 0.0
# Total time: 2.4286398887634277
# Part time: 0
# 0.0
# 89
# [2.357142857142857, 6.0, 4.428571428571429, 3.9285714285714284, 2.5, 1.7857142857142858]
# [0, 4, 2, 0, 0, 0]
# [0, 46, 25, 38, 6, 0]
# [46, 90, 77, 81, 19, 11]
# 4.261904761904762
# Game 365
# Round 44, Num_ = 2, kill_keys = wwwwdwaawd, kill_plans_score[res] = -0.14285714285714285
# Round 82, Num_ = 1, kill_keys = assaaasaaaaaaasawassd, kill_plans_score[res] = -0.4772727272727273
# Total time: 2.8669583797454834
# Part time: 0
# 0.0
# 121
# [1.7857142857142858, 5.0, 4.357142857142857, 5.142857142857143, 3.5, 1.2142857142857142]
# [0, 4, 2, 6, 2, 0]
# [17, 31, 42, 24, 25, 6]
# [17, 113, 84, 122, 46, 11]
# 3.714285714285714
# Game 366
# Round 70, Num_ = 0, kill_keys = sssdddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.2346129417419434
# Part time: 0
# 0.0
# 72
# [5.571428571428571, 4.142857142857143, 2.7142857142857144, 2.0, 1.7142857142857142, 4.857142857142857]
# [2, 2, 0, 0, 0, 2]
# [136, 21, 22, 0, 5, 22]
# [73, 52, 40, 45, 14, 72]
# 4.142857142857143
# Game 367
# Round 72, Num_ = 0, kill_keys = aasaaaawassd, kill_plans_score[res] = -0.5
# Round 72, Num_ = 1, kill_keys = aaaaaaaaaaaaaaawdwaawd, kill_plans_score[res] = -0.6470588235294118
# Total time: 3.2491750717163086
# Part time: 0
# 0.0
# 110
# [4.0, 5.071428571428571, 2.2857142857142856, 4.0, 1.7142857142857142, 3.9285714285714284]
# [4, 2, 0, 0, 0, 2]
# [13, 33, 18, 50, 14, 27]
# [77, 111, 63, 103, 17, 74]
# 3.785714285714286
# Game 368
# Round 19, Num_ = 1, kill_keys = sssddwdssa, kill_plans_score[res] = 0.0
# Round 35, Num_ = 1, kill_keys = ssaaaaaaaasawassd, kill_plans_score[res] = -0.1440677966101695
# Total time: 1.1679766178131104
# Part time: 0
# 0.0
# 42
# [2.5, 5.785714285714286, 3.9285714285714284, 1.9285714285714286, 4.357142857142857, 2.5]
# [0, 4, 0, 0, 4, 0]
# [17, 124, 69, 5, 40, 2]
# [16, 43, 37, 14, 21, 35]
# 4.071428571428571
# Game 369
# Round 40, Num_ = 0, kill_keys = ddddddsdsddddddddwdssa, kill_plans_score[res] = -0.3384615384615385
# Round 49, Num_ = 2, kill_keys = wwwwwwwwwwwa, kill_plans_score[res] = -0.2857142857142857
# Round 87, Num_ = 0, kill_keys = wwaaaasaaawawwaawwwaaaasd, kill_plans_score[res] = -0.6756756756756757
# Round 87, Num_ = 2, kill_keys = aaaaaawaaaasd, kill_plans_score[res] = -0.3333333333333333
# Round 101, Num_ = 0, kill_keys = wwwwddwwdd, kill_plans_score[res] = 0.0
# Total time: 2.8561198711395264
# Part time: 0
# 0.0
# 116
# [6.0, 1.6428571428571428, 5.0, 2.2142857142857144, 3.357142857142857, 2.7857142857142856]
# [8, 0, 4, 0, 0, 0]
# [45, 7, 40, 19, 27, 26]
# [117, 12, 103, 42, 89, 51]
# 4.214285714285714
# Game 370
# Round 77, Num_ = 0, kill_keys = aaasaasaasaasawaasds, kill_plans_score[res] = -0.8695652173913043
# Round 77, Num_ = 2, kill_keys = asaasassssawaasds, kill_plans_score[res] = -0.6071428571428571
# Total time: 3.139056921005249
# Part time: 0
# 0.0
# 111
# [6.0, 1.4285714285714286, 3.4285714285714284, 2.857142857142857, 2.2857142857142856, 5.0]
# [6, 0, 2, 0, 0, 4]
# [33, 0, 11, 22, 17, 27]
# [112, 15, 82, 79, 25, 89]
# 3.619047619047619
# Game 371
# Total time: 1.8019797801971436
# Part time: 0
# 0.0
# 70
# [1.6428571428571428, 2.2142857142857144, 3.0714285714285716, 6.0, 4.142857142857143, 3.9285714285714284]
# [0, 0, 0, 6, 4, 0]
# [4, 19, 64, 120, 38, 118]
# [7, 23, 37, 71, 43, 59]
# 2.3095238095238098
# Game 372
# Round 27, Num_ = 2, kill_keys = wwddddd, kill_plans_score[res] = 0.0
# Round 29, Num_ = 0, kill_keys = wwwwddddwdwdwdddwdssa, kill_plans_score[res] = -0.29577464788732394
# Total time: 1.9136667251586914
# Part time: 0
# 0.0
# 103
# [5.714285714285714, 2.5714285714285716, 5.071428571428571, 1.4285714285714286, 2.2857142857142856, 3.9285714285714284]
# [4, 0, 2, 0, 0, 2]
# [130, 52, 150, 4, 16, 29]
# [104, 29, 50, 9, 30, 31]
# 4.4523809523809526
# Game 373
# Round 62, Num_ = 0, kill_keys = waaaaaaaaaaaaaaaaaaaasd, kill_plans_score[res] = 0.0
# Round 77, Num_ = 0, kill_keys = ssssaaaaaaaaawassd, kill_plans_score[res] = -0.32727272727272727
# Total time: 2.7559635639190674
# Part time: 0
# 0.0
# 87
# [5.571428571428571, 3.5, 1.2142857142857142, 4.071428571428571, 1.7857142857142858, 4.857142857142857]
# [4, 2, 0, 2, 0, 6]
# [67, 55, 6, 65, 20, 34]
# [88, 64, 11, 70, 26, 79]
# 3.4285714285714284
# Game 374
# Round 27, Num_ = 0, kill_keys = wwaaaaawassd, kill_plans_score[res] = 0.0
# Round 31, Num_ = 0, kill_keys = dddsdddddwdssa, kill_plans_score[res] = -0.15053763440860216
# Round 49, Num_ = 0, kill_keys = sddddddddwdssa, kill_plans_score[res] = 0.0
# Total time: 1.5004396438598633
# Part time: 0
# 0.0
# 53
# [6.0, 1.6428571428571428, 3.642857142857143, 2.5, 4.714285714285714, 2.5]
# [8, 0, 0, 0, 2, 0]
# [79, 7, 38, 14, 73, 19]
# [54, 12, 51, 29, 33, 26]
# 3.7619047619047614
# Game 375
# Round 35, Num_ = 0, kill_keys = saaassawassd, kill_plans_score[res] = -0.41379310344827586
# Round 45, Num_ = 0, kill_keys = dddwwwwaw, kill_plans_score[res] = -0.1267605633802817
# Round 56, Num_ = 2, kill_keys = awwwwwaaawassd, kill_plans_score[res] = 0.0
# Total time: 1.7449982166290283
# Part time: 0
# 0.0
# 58
# [4.571428571428571, 3.4285714285714284, 5.142857142857143, 2.857142857142857, 1.0, 4.0]
# [2, 2, 2, 2, 0, 2]
# [53, 37, 73, 21, 4, 49]
# [58, 37, 59, 17, 13, 47]
# 4.3809523809523805
# Game 376
# Total time: 1.4335918426513672
# Part time: 0
# 0.0
# 86
# [1.9285714285714286, 3.642857142857143, 4.071428571428571, 1.9285714285714286, 5.5, 3.9285714285714284]
# [0, 0, 4, 0, 4, 0]
# [8, 52, 15, 6, 168, 39]
# [10, 36, 13, 12, 64, 87]
# 3.214285714285714
# Game 377
# Round 26, Num_ = 2, kill_keys = ssssdddwdssa, kill_plans_score[res] = 0.0
# Round 77, Num_ = 0, kill_keys = wddddddddddddddddddd, kill_plans_score[res] = -0.5555555555555556
# Round 77, Num_ = 2, kill_keys = ddsddddddddddd, kill_plans_score[res] = -0.4827586206896552
# Total time: 3.0827724933624268
# Part time: 0
# 0.0
# 107
# [5.0, 3.4285714285714284, 5.0, 3.5714285714285716, 1.7142857142857142, 2.2857142857142856]
# [4, 0, 4, 4, 0, 0]
# [21, 26, 24, 0, 5, 9]
# [108, 79, 95, 90, 16, 28]
# 4.476190476190476
# Game 378
# Round 53, Num_ = 1, kill_keys = wwwwwwawassd, kill_plans_score[res] = -0.15584415584415584
# Total time: 2.9462029933929443
# Part time: 0
# 0.0
# 150
# [2.857142857142857, 4.357142857142857, 2.2857142857142856, 1.7142857142857142, 4.571428571428571, 5.214285714285714]
# [0, 4, 0, 0, 2, 4]
# [14, 3, 10, 6, 37, 38]
# [55, 151, 14, 12, 106, 87]
# 3.1666666666666665
# Game 379
# Round 42, Num_ = 2, kill_keys = wwwwwdddwdssa, kill_plans_score[res] = -0.38235294117647056
# Total time: 2.470451831817627
# Part time: 0
# 0.0
# 82
# [1.2142857142857142, 2.642857142857143, 4.714285714285714, 6.0, 4.071428571428571, 2.357142857142857]
# [0, 2, 4, 6, 2, 0]
# [6, 11, 58, 68, 50, 31]
# [15, 16, 63, 83, 70, 44]
# 2.857142857142857
# Game 380
# Round 57, Num_ = 0, kill_keys = aaaaasssaasddsa, kill_plans_score[res] = -0.46875
# Round 65, Num_ = 0, kill_keys = wdddddddddwdddwdssa, kill_plans_score[res] = -0.2375
# Round 66, Num_ = 0, kill_keys = wwwwwwwwwwddddddwdssa, kill_plans_score[res] = -0.3442622950819672
# Total time: 2.8225529193878174
# Part time: 0
# 0.0
# 76
# [6.0, 3.142857142857143, 1.4285714285714286, 2.0, 3.4285714285714284, 5.0]
# [6, 0, 0, 0, 2, 4]
# [69, 22, 10, 11, 21, 60]
# [77, 67, 19, 35, 59, 68]
# 3.5238095238095237
# Game 381
# Round 52, Num_ = 1, kill_keys = dddwdddddddddwdssa, kill_plans_score[res] = -0.13846153846153847
# Total time: 1.6253571510314941
# Part time: 0
# 0.0
# 55
# [3.0714285714285716, 6.0, 3.357142857142857, 2.0714285714285716, 1.7857142857142858, 4.714285714285714]
# [0, 6, 0, 0, 0, 2]
# [25, 112, 81, 10, 10, 31]
# [50, 56, 36, 23, 14, 54]
# 4.142857142857143
# Game 382
# Round 25, Num_ = 1, kill_keys = ssssssaawaasds, kill_plans_score[res] = 0.0
# Round 26, Num_ = 0, kill_keys = wwwdwdssa, kill_plans_score[res] = -0.2727272727272727
# Round 30, Num_ = 2, kill_keys = dddddsddwdssa, kill_plans_score[res] = -0.38235294117647056
# Total time: 1.2694668769836426
# Part time: 0
# 0.0
# 39
# [3.9285714285714284, 3.2142857142857144, 4.785714285714286, 2.0714285714285716, 1.6428571428571428, 5.357142857142857]
# [2, 2, 2, 0, 0, 2]
# [28, 23, 54, 29, 23, 84]
# [32, 30, 36, 27, 28, 40]
# 3.976190476190476
# Game 383
# Round 21, Num_ = 2, kill_keys = ddddwdwddwaawd, kill_plans_score[res] = -0.25925925925925924
# Round 27, Num_ = 1, kill_keys = wwwawassd, kill_plans_score[res] = 0.0
# Round 76, Num_ = 1, kill_keys = sasaaaaawassd, kill_plans_score[res] = -0.41935483870967744
# Round 76, Num_ = 2, kill_keys = ddsddddddddwdssa, kill_plans_score[res] = -0.19047619047619047
# Round 104, Num_ = 2, kill_keys = sdddssds, kill_plans_score[res] = 0.0
# Total time: 2.5742454528808594
# Part time: 0
# 0.0
# 106
# [3.142857142857143, 5.0, 6.0, 1.4285714285714286, 2.2857142857142856, 3.142857142857143]
# [0, 4, 6, 0, 0, 2]
# [30, 36, 45, 8, 16, 22]
# [78, 106, 107, 19, 29, 23]
# 4.714285714285714
# Game 384
# Round 59, Num_ = 2, kill_keys = ddwdssa, kill_plans_score[res] = 0.0
# Total time: 2.6453282833099365
# Part time: 0
# 0.0
# 89
# [3.142857142857143, 2.0714285714285716, 4.0, 1.2142857142857142, 4.571428571428571, 6.0]
# [2, 0, 2, 0, 2, 4]
# [20, 31, 34, 5, 36, 47]
# [61, 31, 86, 16, 87, 90]
# 3.0714285714285716
# Game 385
# Round 48, Num_ = 1, kill_keys = wwwwwwwwwdddsa, kill_plans_score[res] = -0.11864406779661017
# Total time: 1.7709436416625977
# Part time: 0
# 0.0
# 72
# [3.9285714285714284, 5.142857142857143, 1.4285714285714286, 4.928571428571429, 3.4285714285714284, 2.142857142857143]
# [4, 2, 0, 4, 0, 0]
# [16, 198, 5, 17, 46, 16]
# [17, 73, 13, 72, 50, 16]
# 3.5
# Game 386
# Total time: 2.617371082305908
# Part time: 0
# 0.0
# 104
# [1.7142857142857142, 1.7142857142857142, 3.142857142857143, 4.0, 4.642857142857143, 5.785714285714286]
# [0, 0, 0, 2, 4, 4]
# [10, 0, 64, 39, 56, 70]
# [16, 17, 49, 92, 55, 105]
# 2.1904761904761902
# Game 387
# Round 58, Num_ = 2, kill_keys = waaaaaaaaaawaaaas, kill_plans_score[res] = -0.4473684210526316
# Total time: 2.9619414806365967
# Part time: 0
# 0.0
# 76
# [2.5714285714285716, 2.2857142857142856, 4.785714285714286, 2.2857142857142856, 3.0714285714285716, 6.0]
# [0, 0, 2, 0, 2, 6]
# [22, 26, 37, 35, 12, 43]
# [72, 60, 73, 52, 69, 77]
# 3.214285714285714
# Game 388
# Round 46, Num_ = 1, kill_keys = sdsssddsdddddsddddsdsaasd, kill_plans_score[res] = -0.15625
# Round 63, Num_ = 1, kill_keys = dddwwaaaawwwd, kill_plans_score[res] = -0.2549019607843137
# Round 73, Num_ = 1, kill_keys = aasssddddssaaaaaassaaaaaaasd, kill_plans_score[res] = -0.6829268292682927
# Total time: 2.1264591217041016
# Part time: 0
# 0.0
# 96
# [1.7142857142857142, 5.428571428571429, 2.857142857142857, 5.285714285714286, 1.7142857142857142, 4.0]
# [0, 6, 0, 4, 0, 2]
# [5, 33, 25, 60, 6, 53]
# [13, 97, 65, 75, 9, 48]
# 3.3333333333333335
# Game 389
# Round 22, Num_ = 2, kill_keys = ddssssddwdssa, kill_plans_score[res] = -0.34210526315789475
# Round 132, Num_ = 2, kill_keys = aaassssaawaaaaaaawwawwddddwdd, kill_plans_score[res] = -3.2222222222222223
# Round 133, Num_ = 2, kill_keys = sdsdddsssasassdsss, kill_plans_score[res] = 0.0
# Total time: 2.4570388793945312
# Part time: 0
# 0.0
# 150
# [4.428571428571429, 2.7142857142857144, 5.428571428571429, 3.857142857142857, 1.8571428571428572, 2.7142857142857144]
# [0, 0, 8, 0, 0, 0]
# [46, 8, 18, 25, 2, 7]
# [135, 12, 151, 133, 9, 24]
# 4.190476190476191
# Game 390
# Round 57, Num_ = 1, kill_keys = ddddddddwdssa, kill_plans_score[res] = -0.18840579710144928
# Round 99, Num_ = 1, kill_keys = dssaaaawwwaaasaaaaaaaaassawassd, kill_plans_score[res] = -0.7560975609756098
# Total time: 2.7438974380493164
# Part time: 0
# 0.0
# 150
# [3.0714285714285716, 5.142857142857143, 4.214285714285714, 3.0714285714285716, 3.857142857142857, 1.6428571428571428]
# [0, 8, 0, 0, 2, 0]
# [19, 11, 32, 15, 2, 0]
# [19, 151, 101, 59, 92, 14]
# 4.142857142857143
# Game 391
# Round 25, Num_ = 2, kill_keys = ssdsaasd, kill_plans_score[res] = 0.0
# Round 36, Num_ = 1, kill_keys = ddsssssssssssdddd, kill_plans_score[res] = -0.3953488372093023
# Round 57, Num_ = 1, kill_keys = sdddwdssa, kill_plans_score[res] = -0.5
# Total time: 2.428276300430298
# Part time: 0
# 0.0
# 87
# [2.0, 5.428571428571429, 3.642857142857143, 1.4285714285714286, 5.357142857142857, 3.142857142857143]
# [0, 4, 2, 0, 2, 0]
# [14, 27, 15, 2, 34, 23]
# [27, 76, 38, 10, 88, 59]
# 3.6904761904761902
# Game 392
# Round 53, Num_ = 0, kill_keys = aaawaaaaaaaaawwwwwwaaaaaaas, kill_plans_score[res] = -0.48214285714285715
# Round 53, Num_ = 1, kill_keys = ddddddddwwwwwwwwwwwdwddwwwd, kill_plans_score[res] = -0.6428571428571429
# Round 53, Num_ = 2, kill_keys = waaaaaaaaaawaawwwwawwwwd, kill_plans_score[res] = -0.25263157894736843
# Round 66, Num_ = 0, kill_keys = aaaaaaaaasssssssaaasaaawassd, kill_plans_score[res] = -0.875
# Round 66, Num_ = 1, kill_keys = sssssssdddddwdssa, kill_plans_score[res] = -0.3617021276595745
# Round 66, Num_ = 2, kill_keys = aaassssssaaasaaawassd, kill_plans_score[res] = -0.2079207920792079
# Round 81, Num_ = 2, kill_keys = awwaaaawassd, kill_plans_score[res] = -0.17142857142857143
# Total time: 3.109398603439331
# Part time: 0
# 0.0
# 83
# [3.142857142857143, 4.714285714285714, 6.0, 3.5714285714285716, 2.0714285714285716, 1.5]
# [4, 6, 8, 2, 0, 0]
# [6, 39, 58, 46, 22, 13]
# [72, 83, 84, 68, 55, 18]
# 4.6190476190476195
# Game 393
# Round 49, Num_ = 0, kill_keys = wwwaaaaaawwawassd, kill_plans_score[res] = 0.0
# Round 88, Num_ = 0, kill_keys = wddwwdsddddwwwwwaaaaaawassd, kill_plans_score[res] = -0.675
# Total time: 3.3553080558776855
# Part time: 0
# 0.0
# 150
# [4.785714285714286, 1.7142857142857142, 2.857142857142857, 2.2857142857142856, 4.785714285714286, 4.571428571428571]
# [4, 0, 0, 0, 4, 6]
# [42, 15, 26, 23, 45, 8]
# [113, 28, 88, 51, 90, 151]
# 3.119047619047619
# Game 394
# Round 62, Num_ = 0, kill_keys = sddddwdssa, kill_plans_score[res] = 0.0
# Total time: 1.3470842838287354
# Part time: 0
# 0.0
# 71
# [5.714285714285714, 1.7142857142857142, 3.0, 3.142857142857143, 5.285714285714286, 2.142857142857143]
# [6, 0, 2, 0, 4, 0]
# [65, 5, 6, 10, 111, 5]
# [72, 13, 13, 19, 64, 17]
# 3.4761904761904763
# Game 395
# Round 103, Num_ = 0, kill_keys = wwaaawwawwwwwawd, kill_plans_score[res] = 0.0
# Total time: 2.7362380027770996
# Part time: 0
# 0.0
# 150
# [4.857142857142857, 4.0, 4.857142857142857, 4.0, 2.0714285714285716, 1.2142857142857142]
# [4, 2, 2, 2, 0, 0]
# [25, 27, 50, 16, 20, 4]
# [107, 105, 111, 151, 15, 8]
# 4.571428571428572
# Game 396
# Round 13, Num_ = 2, kill_keys = wddddddwdssa, kill_plans_score[res] = 0.0
# Round 69, Num_ = 2, kill_keys = ssassaaaaaaaaaaawaasds, kill_plans_score[res] = -0.5945945945945946
# Round 88, Num_ = 2, kill_keys = ssaaaaasaaaaaaaaaaaaaa, kill_plans_score[res] = 0.0
# Total time: 2.649911403656006
# Part time: 0
# 0.0
# 95
# [2.4285714285714284, 2.7142857142857144, 6.0, 4.5, 1.4285714285714286, 3.9285714285714284]
# [0, 0, 6, 2, 0, 2]
# [27, 27, 47, 37, 5, 25]
# [34, 42, 96, 71, 15, 90]
# 3.714285714285714
# Game 397
# Round 38, Num_ = 1, kill_keys = ssassssssdsaasd, kill_plans_score[res] = -0.1485148514851485
# Total time: 1.3261690139770508
# Part time: 0
# 0.0
# 49
# [1.6428571428571428, 5.142857142857143, 1.3571428571428572, 4.285714285714286, 5.142857142857143, 3.4285714285714284]
# [0, 2, 0, 2, 4, 2]
# [16, 125, 7, 111, 81, 25]
# [14, 50, 14, 37, 40, 24]
# 2.714285714285715
# Game 398
# Round 48, Num_ = 1, kill_keys = sssddwdssa, kill_plans_score[res] = -0.1
# Round 75, Num_ = 1, kill_keys = sssssddddddddddddds, kill_plans_score[res] = 0.0
# Round 97, Num_ = 1, kill_keys = dssdsssddwdwaw, kill_plans_score[res] = 0.0
# Total time: 2.649714469909668
# Part time: 0
# 0.0
# 102
# [2.0, 5.785714285714286, 1.4285714285714286, 4.928571428571429, 2.5714285714285716, 4.285714285714286]
# [0, 6, 0, 6, 0, 4]
# [9, 58, 6, 51, 26, 36]
# [18, 103, 15, 77, 50, 99]
# 3.071428571428571
# Game 399
# Round 15, Num_ = 1, kill_keys = ssaaaawassd, kill_plans_score[res] = 0.0
# Round 79, Num_ = 1, kill_keys = aawwawwwwaaaaaaawwwwwddwwdddwdwa, kill_plans_score[res] = -0.4383561643835616
# Total time: 2.1872878074645996
# Part time: 0
# 0.0
# 81
# [2.2142857142857144, 6.0, 3.7857142857142856, 3.7142857142857144, 2.2142857142857144, 3.0714285714285716]
# [0, 6, 0, 4, 0, 0]
# [5, 41, 34, 0, 6, 10]
# [10, 82, 81, 81, 8, 17]
# 4.0
# [3.53696429 3.51821429 3.52589286 3.52482143 3.39517857 3.49892857]
# Average Score_kill = [1.595 1.68  1.645 1.84  1.535 1.72 ]
# Average Score_len = [33.3675 32.385  31.0075 30.925  28.315  31.56  ]
# Average Score_time = [56.61   57.7375 57.445  57.95   54.2725 55.7325]
# 3.52702380952381

# %%
print(np.std(scores, axis=0))
# Out:
# [1.38119605 1.41057409 1.45143506 1.45636664 1.37744022 1.41892237]
